# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:8]}")
else:
    print("OpenRouter API Key not set")
# Out:
# OpenRouter API Key exists and begins sk-or-v1

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

import os

OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"
openrouter_api_key = os.getenv("OPENROUTER_API_KEY")

openai = OpenAI(base_url=OPENROUTER_BASE_URL, api_key=openrouter_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="xiaomi/mimo-v2.5",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4.
#
# It's a simple arithmetic question, but feel free to ask if you need help with more! 😊

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="deepseek/deepseek-v4-flash",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# What is the missing number in the sequence: 1, 11, 21, 1211, 111221, 312211, 13112221, 1113213211, ?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="openai/gpt-5-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# 31131211131221
#
# This is the look-and-say sequence. Reading 1113213211 aloud: "three 1s, one 3, one 2, one 1, one 3, one 2, two 1s" → 31 13 12 11 13 12 21 → 31131211131221.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# The operations ⊕ and ⊗ follow consistent linear patterns based on the given examples. For ⊕, the pattern is
# \[
# a ⊕ b = \frac{1}{5}a - \frac{72}{5}b + \frac{412}{5},
# \]
# and for ⊗,
# \[
# a ⊗ b = -16a - 23b + 249.
# \]
#
# We need \(x\) such that \(x ⊕ 3 = x ⊗ 3\). Substituting \(b = 3\):
#
# \[
# x ⊕ 3 = \frac{x - 72 \cdot 3 + 412}{5} = \frac{x + 196}{5},
# \]
# \[
# x ⊗ 3 = -16x - 23 \cdot 3 + 249 = -16x + 180.
# \]
#
# Set them equal:
#
# \[
# \frac{x + 196}{5} = -16x + 180.
# \]
#
# Multiply both sides by 5:
#
# \[
# x + 196 = -80x + 900.
# \]
#
# Solve for \(x\):
#
# \[
# x + 80x = 900 - 196 \implies 81x = 704 \implies x = \frac{704}{81}.
# \]
#
# Thus, the value of \(x\) that satisfies both equations is \(\boxed{\frac{704}{81}}\).

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI opportunity."}]

# Then make the first call:

response = openai.chat.completions.create(
    model="deepseek/deepseek-v4-flash",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

print(business_idea)

# And repeat! In the next message, include the business idea within the message

messages = [{"role": "user", "content": f"Please propose a pain-point in the {business_idea} industry."}]

# And make the next call:

response = openai.chat.completions.create(
    model="deepseek/deepseek-v4-flash",
    messages=messages
)

# Then read the pain-point:

pain_point = response.choices[0].message.content

print(pain_point)

# And repeat! In the next message, include the pain-point within the message

messages = [{"role": "user", "content": f"Please propose an Agentic AI solution to the {pain_point} pain-point."}]

# And make the next call:

response = openai.chat.completions.create(
    model="deepseek/deepseek-v4-flash",
    messages=messages
)

# Then read the solution:
solution = response.choices[0].message.content

print(solution)
# Out:
# This is a great question. The key is to find a domain where **process complexity** and **data fragmentation** are high, but the **cost of failure** is moderate—where an AI agent can experiment, learn, and iterate without catastrophic consequences.
#
# Let’s focus on **B2B Procurement and Supply Chain Operations**.
#
# Here’s why this is a prime agentic AI opportunity, and how you could approach it.
#
# ### The Business Area: B2B Procurement (Indirect & Direct Materials)
#
# **The Pain Point:**
# Procurement is still a highly manual, fragmented, and rules-heavy process. It involves:
# - **Sourcing:** Finding suppliers, sending RFQs, comparing quotes.
# - **Purchasing:** Generating POs from requisitions (often with errors), checking budgets, ensuring compliance.
# - **Expediting:** Tracking orders, resolving delays, managing inventory levels.
# - **Invoice & Payment:** Matching POs to invoices to receipts (the "three-way match"), handling discrepancies.
#
# This is a multi-trillion-dollar global market, yet most companies run on spreadsheets, email chains, and legacy ERP systems. It's a **knowledge worker's nightmare** of repetitive, low-cognitive, but high-importance tasks.
#
# ### Why Agentic AI Fits Perfectly
#
# Traditional software (RPA, e-procurement suites) fails because:
# - **Rules change constantly:** Supplier contracts, shipping policies, and internal approval hierarchies are fluid.
# - **Data is unstructured:** Emails, PDF catalogs, handwritten notes, and text in ERP fields.
# - **Exceptions are the norm:** Late shipments, wrong items, budget overrides—most POs require human judgment.
#
# Agentic AI can overcome this by acting as an **autonomous procurement assistant** that:
#
# 1.  **Perceives:** Scans emails, ERP data, supplier portals, and PDFs.
# 2.  **Reasons:** Understands context (e.g., “We need 100 units by Friday, but the preferred supplier is on backorder; find an alternative within 10% of the budget”).
# 3.  **Acts:** Generates POs, sends approval requests, negotiates with suppliers (via API or email), updates ERP entries, and flags anomalies for human review.
#
# ### Specific Opportunity: The "Autonomous PO & Dispute Resolution Agent"
#
# Here’s a concrete product idea:
#
# **Agent Name:** `Procuro-AI`
#
# **Core Function:**
# An AI agent that takes a purchase requisition and autonomously manages the entire lifecycle to a fully matched and approved payment.
#
# **Key Capabilities:**
#
# - **RFQ & Supplier Sourcing:** When a new item is requested, the agent queries internal supplier databases and external catalogs, drafts an RFQ email, and parses PDF quotes to create a comparison table. It uses past pricing data to flag outliers.
# - **PO Generation & Approval Routing:** It generates the PO in the ERP, checks budget against a dynamic rule set (e.g., “Office supplies under $500 don’t need CFO approval”), and routes to the correct approver via email/chat, explaining why the PO is needed in natural language.
# - **Order Expediting & Delay Prediction:** It monitors order status files from suppliers. If a delay is detected, it predicts the impact on production, and autonomously re-routes the order to a backup supplier or adjusts the delivery window, notifying stakeholders.
# - **Three-Way Match & Dispute Handling:** When an invoice arrives that doesn't match the PO or receipt, the agent doesn't just reject it. It investigates the discrepancy: “The supplier sent a substitute item at a higher price. The original requisition allowed substitutions.” If within policy, it approves; if not, it drafts a dispute email with supporting evidence.
#
# ### Why This Is a Killer Use Case
#
# - **Massive ROI:** Each purchase order costs $50–$200 in manual labor. An agent can reduce this by 60-80%.
# - **Clear, Measurable KPIs:** Cycle time (req-to-PO), error rate (failed matches), cost savings (negotiated discounts).
# - **Low-Cognitive, High-Repetition:** It’s not strategic sourcing (which needs human creativity); it's *operational* procurement—the perfect sandbox for an agent.
# - **Ecosystem Integration:** It plugs into popular ERPs (SAP, Oracle, NetSuite) and email (Outlook, Gmail). This makes it a **bolt-on enhancement**, not a rip-and-replace.
#
# ### How to Start (MVP)
#
# 1.  **Pick a Narrow Vertical:** Focus on a specific industry with standardized parts (e.g., **MRO (Maintenance, Repair, Operations)** for manufacturing or **lab supplies for biotech**). The parts are often repeat-buy, making the agent's learning easier.
# 2.  **Start with One Task:** Build an agent that only handles the **three-way match and discrepancy resolution**. This is the #1 pain point in AP.
# 3.  **Use a "Human-in-the-Loop" Paradigm:** When the agent is unsure (e.g., a supplier requests a 25% price increase), it flags the human with a clear summary and recommended action. Over time, the agent learns from the human's decision.
# 4.  **Monetize as a SaaS + Per-Transaction Fee:** A base subscription for the agent, plus a small fee per successfully processed order or resolved dispute. This aligns your incentives with the customer's value.
#
# ### Potential Pitfalls to Avoid
#
# - **Don't over-automate negotiation:** Full price negotiation is a strategic, relationship-based skill. Instead, have the agent only handle *standard* upsells (“We usually get 2% off for early payment”) and escalate the rest.
# - **Guarantee accuracy on data extraction:** Any hallucination in parsing a PDF quote could cost the customer thousands. Use specialized document parsers (like OCR + LLM) and always let the human review critical numbers (unit price, quantity) before committing.
#
# ### Final Verdict
#
# **B2B Procurement** is a sleeper hit for agentic AI. It’s a massive, inefficient market where the work is already digitized (email, ERP) but not automated. An agent that can manage the **operational loop** of buying and paying will deliver immediate, concrete value to businesses of all sizes.
#
# If you can build an agent that handles just *one* step of this process reliably, you’ll have a product that CFOs and CPOs will pay for immediately. That’s a strong signal to explore.
# **Pain Point: The "Three-Way Match" Chaos in Accounts Payable**
#
# Every B2B company struggles with matching purchase orders (POs), receiving documents, and invoices. This process is manual, riddled with exceptions (mismatched prices, quantities, or line items), and consumes hours of finance team time per dispute. Even small discrepancies—like a substituted item or a 5% price variance—require email chains, stakeholder approvals, and manual ERP updates, delaying payments and straining supplier relationships.
#
# Agentic AI can autonomously investigate discrepancies, cross-reference approval policies, and resolve common cases (e.g., pre-authorized substitutions) while escalating only strategic conflicts. The result: 70% fewer manual hours, faster payment cycles, and fewer costly errors.
# ## Agentic AI Solution for "Three-Way Match" Chaos in Accounts Payable
#
# ### Overview
#
# The proposed **AP Autonomous Resolution Agent (AP-ARA)** is a multi-agent AI system that ingests, validates, and resolves three-way match exceptions in real time, without human intervention for the vast majority of cases. The system mimics a senior accounts payable analyst but operates at machine speed—autonomously investigating discrepancies, cross-referencing internal policies and historical approvals, and executing resolutions or escalating only when strategic judgment is needed.
#
# ### Key Capabilities
#
# 1. **Multi-source Data Ingestion**
#    - Connects directly to ERP (e.g., SAP, Oracle NetSuite, Microsoft Dynamics) for POs, goods receipt notes (GRNs), and invoices.
#    - Integrates with email/communication platforms (Outlook, Slack) to read supplier correspondence and approval chains.
#    - Reads scanned PDFs and unstructured attachments via OCR + LLM parsing.
#
# 2. **Autonomous Discrepancy Investigation**
#    - Matches line items across PO, GRN, and invoice using fuzzy logic (item descriptions, partial SKUs, units of measure).
#    - Identifies three-way, two-way, or one-way mismatches (price, quantity, tax, freight, substituted items, rounding errors).
#    - Retrieves past approvals for similar substitutions or variance thresholds from a vector database of historical resolution patterns.
#
# 3. **Policy-Aware Resolution Engine**
#    - Interprets internal approval policies (e.g., “substitutions under 10% price difference auto-approved if vendor is in preferred list”, “quantity over-delivery <5% acceptable”).
#    - Applies rules from a dynamic knowledge graph that combines corporate policy, contract terms, and delegation of authority.
#    - For common exceptions (substituted SKU with same price, minor quantity differences, freight allocation), the agent executes the resolution automatically—e.g., updates the PO line, posts a credit memo, or adjusts the invoice line.
#
# 4. **Escalation & Collaboration Agent**
#    - When resolution requires human judgment (e.g., disputed pricing beyond policy threshold, new unapproved vendor substitution, conflicting receipts), the agent drafts a concise summary, identifies the right stakeholders (buyer, receiving manager, finance approver), and sends a pre-populated approval request.
#    - Tracks escalations via a shared dashboard and auto-follows up after a timeout, reducing email chains.
#
# 5. **ERP & Payment Orchestration**
#    - After resolution, the agent posts the necessary ERP transactions (invoice hold release, PO amendment, credit memo) and triggers the payment workflow.
#    - Logs every action with audit trail (agent reasoning, policy references, timestamps) for compliance.
#
# ### Architecture & Agent Roles
#
# The solution uses a **coordinator + specialist agents** architecture:
#
# - **Orchestrator Agent** – Receives all incoming invoice–PO–GRN triplets. Classifies match status (perfect match, minor exception, major exception). Routes to the appropriate specialist.
# - **Match Agent** – Performs fuzzy multi-field matching and flags discrepancies.
# - **Policy Agent** – Queries the knowledge graph of rules, past approvals, and contract data. Returns resolution options with confidence scores.
# - **Resolution Agent** – Executes the chosen action (auto-adjust, create note, escalate).
# - **Communication Agent** – Handles email drafting, approval workflow routing, and supplier notifications.
# - **Human-in-the-loop Interface** – A simple dashboard where human AP analysts can review escalated cases, approve/reject, and provide feedback that trains the system.
#
# ### Workflow Example: Substituted Item with 8% Price Variance
#
# 1. **Input**: Invoice for “Widget A (XYZ-100)” at $12/unit. PO has “Widget A (XYZ-100)” at $11/unit. GRN shows “Widget A (XYZ-200)” received.
# 2. **Match Agent** detects:
#    - SKU mismatch (XYZ-100 vs XYZ-200) → fuzzy match suggests substitution.
#    - Price variance 8% (within 10% policy threshold for preferred vendor).
# 3. **Policy Agent** retrieves:
#    - Vendor is in “platinum” tier → substitutions up to 10% auto-approved for same functional item.
#    - Historical data: same substitution approved 3 times in last 6 months.
# 4. **Resolution Agent**:
#    - Updates PO line to XYZ-200 with price $12.
#    - Posts invoice for payment.
#    - Logs: “Substitution auto-resolved per Platinum Vendor Policy #A-12. Price variance $1/unit, total $100 extra, within 10% threshold.”
# 5. **Human interaction**: None. Payment released same day.
#
# ### Expected Results & Metrics
#
# | Metric | Before (Manual) | After (AP-ARA) |
# |--------|----------------|----------------|
# | Manual hours per 100 invoices | ~40 hours | ~12 hours (70% reduction) |
# | Average time to resolve exceptions | 5 days | 2 hours (auto) / 1 day (escalated) |
# | Supplier payment cycle | 45 days | 30 days (faster approvals) |
# | Discrepancy detection rate | ~85% (miss many small mismatches) | >98% (fuzzy matching + policy) |
# | Audit compliance | Inconsistent | Full automated trace |
#
# ### Integration & Deployment
#
# - **ERP Connector**: Pre-built adapters for SAP, Oracle, NetSuite, Microsoft Dynamics, and open APIs for custom ERPs.
# - **Deployment**: Cloud-native (AWS/Azure) with on-premises option for sensitive data.
# - **Security**: SOC2 Type II, role-based access, data encryption at rest/in transit.
# - **Change Management**: 4-week pilot on 20% of invoices, with human oversight to calibrate policy thresholds and train the system.
#
# ### Why Agentic AI for This Pain Point?
#
# Traditional rule-based tools fail because real-world exceptions are fuzzy—substitutions, partial shipments, bundled pricing. Large language models + retrieval-augmented generation (RAG) enable the AI to **reason** about context (e.g., “Is this substitution reasonable given past behavior?”) and **act** safely by referencing explicit policies and audit logs. The result: finance teams reclaim 70% of their time, suppliers get paid faster, and the “three-way match chaos” becomes a three-minute silent process.
