# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
#from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

# openai_api_key = os.getenv('OPENAI_API_KEY')
# anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
# google_api_key = os.getenv('GOOGLE_API_KEY')
# deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
# groq_api_key = os.getenv('GROQ_API_KEY')

openrouter_api_key = os.getenv('OPENROUTER_API_KEY')
OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:    print("OpenRouter API Key not set (and this is optional)")

# if openai_api_key:
#     print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
# else:
#     print("OpenAI API Key not set")
    
# if anthropic_api_key:
#     print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
# else:
#     print("Anthropic API Key not set (and this is optional)")

# if google_api_key:
#     print(f"Google API Key exists and begins {google_api_key[:2]}")
# else:
#     print("Google API Key not set (and this is optional)")

# if deepseek_api_key:
#     print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
# else:
#     print("DeepSeek API Key not set (and this is optional)")

# if groq_api_key:
#     print(f"Groq API Key exists and begins {groq_api_key[:4]}")
# else:
#     print("Groq API Key not set (and this is optional)")
# Out:
# OpenRouter API Key exists and begins sk-

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI(base_url=OPENROUTER_BASE_URL, api_key=openrouter_api_key)
response = openai.chat.completions.create(
    model="openai/gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# Imagine you are advising the government of a diverse island nation of 1.2 million people facing three simultaneous crises: a projected 40% loss of habitable land to sea‑level rise within 30 years, a fragile economy reliant on tourism and small‑scale fishing, and a polarized society with a significant indigenous minority whose sacred coastal sites are threatened. The government has $5 billion in immediate funds, can raise an additional $1 billion per year through bonds if markets allow, and estimates a 60% chance of receiving modest international aid over the next decade. Within these constraints, propose a prioritized 30‑year adaptation strategy that balances engineered defenses, managed retreat, economic transition, social cohesion, and protection of cultural sites. For each major decision in your plan: (1) estimate expected costs and benefits and assign a probability of success and of failure (with brief justification), (2) identify clear metrics to monitor progress and trigger contingencies, (3) explain how you would engage stakeholders and adjudicate conflicts between economic, safety, and cultural priorities, (4) specify what additional data you would request (and why) before committing to irreversible actions, and (5) describe how you would update the plan as new information arrives. Explicitly list your assumptions and the key uncertainties that most affect your recommendations, and mark which parts of your answer are speculative versus evidence‑based.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "openai/gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a 30-year, phased adaptation plan tailored to a diverse, tourism- and small-fisheries–based island nation with a 1.2 million population, facing rapid sea‑level rise, economic vulnerability, and a significant indigenous minority with sacred coastal sites at risk. Costs are expressed in USD billions; timescales are indicative. All figures are estimates subject to refinement as data arrive.
#
# Executive overview
# - Core principle: balance engineered defenses, managed retreat where necessary, diversified livelihoods, and strong protection of cultural sites through inclusive governance.
# - Funding frame: $5B immediate; up to $1B/year via bonds if markets permit; ~60% chance of modest international aid over the next decade. Treat budgets as contingent on financing conditions and aid.
# - Phasing: (1) safeguard critical assets and identities; (2) establish retreat-ready pathways and economic diversification; (3) scale up protections and governance; (4) maintain data-led updates and flexible adaptation.
#
# Assumptions (explicit)
# - Population remains near 1.2 million; internal migration within the island is feasible.
# - 40% of habitable land is at high risk of inundation or salinization within ~30 years; rate of sea-level rise is within current projections but with uncertainty.
# - Tourism and small-scale fishing remain important but face climate and ecosystem limits; diversification improves resilience.
# - Indigenous communities have distinct cultural priorities and rights; meaningful participation and consent are required for changes to sacred coastal sites.
# - Financing constraints dominate early years; aid, debt markets, and grant opportunities are uncertain and contingent on global conditions.
# - Technologies and costs will evolve; plan remains adaptable.
#
# Key uncertainties likely to affect decisions
# - Pace and geographic distribution of sea‑level rise and coastal erosion (erosion rates, subsidence, storm surge behavior).
# - Value of protected assets (properties, ports, tourism infrastructure) and cost of land acquisition for retreat.
# - Social acceptability and political feasibility of managed retreat and relocation, particularly around indigenous coastal areas.
# - Availability and terms of international aid and bond markets.
# - Effectiveness and costs of nature-based defenses versus hard infrastructure.
# - Economic response to diversification (timing, labor market fit, supply chains).
# - Legal and governance reforms needed for indigenous co-management and cultural site protection.
#
# Plan components and major decisions (with costs, benefits, and success likelihoods)
#
# Decision 1. Deploy a layered coastal defense program that combines nature-based solutions with targeted engineered protections in priority areas
# - What it includes: mangrove restoration and dune systems where feasible; living shorelines; sea walls and flood barriers in high-value zones (ports, airports, urban cores); auxiliary drainage and flood-proofing; essential climate-resilient infrastructure retrofits.
# - Estimated costs (phased)
#   - Initial package (0–5 years): about $2.5B–$3B for core defenses in the most exposed zones plus NbS; ongoing maintenance funded from bonds later.
#   - 30-year program: potential total $5B–$6B (capable of expanding if additional zones are identified).
# - Expected benefits
#   - Reduces flood/tide- and storm-related damages in high-value areas; protects critical infrastructure and a large portion of the tourism sector; creates co-benefits for biodiversity and shoreline protection.
# - Probability of success and failure
#   - Success probability: 0.6–0.75, depending on design quality, maintenance, and local adherence.
#   - Failure modes: cost overruns, maintenance shortfalls, insufficient protection for rising seas, negative ecological side-effects if poorly designed (e.g., sediment trapping).
# - Monitoring metrics and triggers
#   - Metrics: reduction in flood frequency/intensity in protected zones; annual maintenance completion rates; coastal erosion rates in protected segments; cost adherence.
#   - Triggers: if projected flooding still exceeds targeted thresholds in protected areas after 5–7 years, escalate to protective upgrades or focus more on NbS; if maintenance lag exceeds 12 months, reallocate funds.
# - Stakeholder engagement and conflict adjudication
#   - Engage: coastal communities, port operators, tourism operators, fisheries representatives, local engineers, and indigenous groups with co-design of defenses in areas of cultural importance.
#   - Adjudication: establish a Coastal Defense Governance Committee including representatives from the indigenous council, municipal authorities, and a neutral technical arbiter to resolve conflicts about siting and design choices.
# - Data needed before irreversible action
#   - High-resolution coastal hazard mapping, land ownership and asset valuation, sediment dynamics, anticipated storm surge models, and maintenance cost forecasts.
# - How to adapt with new information
#   - Use adaptive design with modular components; implement pilot segments first; revise siting as hazard maps update; adjust maintenance schedules as local capacity grows.
#
# Speculative vs evidence-based notes
# - Evidence-based: general strategy of layering NbS with engineered protections.
# - Speculative: exact siting, quantities, and maintenance costs until hazard mapping is complete.
#
# Decision 2. Implement a staged managed retreat program for the highest-risk zones, with voluntary buyouts, relocation corridors, and retention of cultural and community anchors
# - What it includes: voluntary buyouts in the most hazard-prone neighborhoods, development of relocation villages in safer inland zones, and investment in housing, job opportunities, and social services for relocated households; preservation of cultural practices near relocated sites and new cultural gathering spaces.
# - Estimated costs
#   - Early phase (0–5 years): $0.6B–$1B for planning, land acquisition options, and early relocations of the smallest clusters.
#   - Medium term (5–15 years): cumulative $4B–$6B, depending on pace and geographic scope.
#   - 30-year horizon: possible total $6B–$9B, contingent on land prices, housing costs, and buyout volumes.
# - Expected benefits
#   - Reduces exposure of people and properties to rising seas; preserves remaining habitable land; creates opportunity to design communities with resilience from the outset.
# - Probability of success and failure
#   - Success probability: 0.5–0.65 (highly contingent on voluntary participation, fair compensation, and employment alternatives).
#   - Failure modes: social resistance, perceived inequity, inadequate inland sites, cultural ties to coast, and political pushback.
# - Monitoring metrics and triggers
#   - Metrics: number of households relocated, time-to-relocation milestones, inland housing quality and affordability, employment outcomes post-relocation, social cohesion indicators.
#   - Triggers: if participation rates fall below a threshold, ramp up incentives and outreach; if inland sites show deterioration or poor livability, pause and renegotiate with communities.
# - Stakeholder engagement and conflict adjudication
#   - Engage: indigenous communities, local elected bodies, community organizations, housing authorities, employers, and NGOs.
#   - Adjudication: establish a Relocation and Cultural Continuity Council to oversee fair compensation, grievance mechanisms, and protection of sacred sites during relocation.
# - Data needed
#   - Comprehensive hazard and risk maps, land availability and suitability for relocation, housing costs and financing options, socioeconomic profiles, potential impacts on indigenous cultural practices, and revenue implications for displaced households.
# - Adaptation plan with new information
#   - Start with small pilots in low-cost areas; expand progressively with transparent benchmarks; adjust compensation schemes based on market conditions; incorporate community-led design of inland relocation spaces.
# - Speculative vs evidence-based notes
#   - Evidence-based: known need for voluntary, well-supported relocation programs in high-risk areas.
#   - Speculative: precise buyout costs and inland site viability until market studies are completed.
#
# Decision 3. Diversify and deepen the economy to reduce climate vulnerability (sustainable tourism, diversified fisheries, aquaculture, renewable energy, digital services)
# - What it includes: program of job training, incentives for private sector investment in resilient tourism products (ecotourism, cultural tourism that highlights indigenous heritage with consent), small-scale eco-friendly fisheries or aquaculture ventures, and renewable energy integration (solar/wind) to reduce energy shocks.
# - Estimated costs
#   - Initial thrust (0–5 years): $1B–$1.5B for training, seed capital, infrastructure upgrades (including digital connectivity) and targeted subsidies.
#   - Ongoing/yearly: incentives and subsidies may require $0.2B–$0.5B/year, potentially funded by bonds if market conditions allow.
# - Expected benefits
#   - Creates more resilient, higher-value jobs; reduces reliance on climate-vulnerable sectors; channels tourism into deeper cultural and environmental experiences; increases local-purchase ecosystems; improves energy resilience.
# - Probability of success and failure
#   - Success probability: 0.5–0.75 depending on demand, global tourism recovery, and effective implementation.
#   - Failure modes: demand risk in tourism (seasonality, global downturns), supply chain fragility for aquaculture, regulatory hurdles.
# - Monitoring metrics and triggers
#   - Metrics: GDP contribution from diversified sectors; tourism occupancy and diversification metrics; fishing yields; employment rates in targeted sectors; energy reliability indicators.
#   - Triggers: if diversification lag persists for 2–3 years, intensify incentives and reduce barriers; if environmental stress on new aquaculture ventures emerges, reallocate to more robust sectors.
# - Stakeholder engagement and conflict adjudication
#   - Engage: business associations, hotel/port operators, coastal communities, indigenous representatives, fisheries cooperatives, banks and microfinance institutions.
#   - Adjudication: establish an Economic Diversification Council with representation from affected communities and a rotating independent chair to mediate conflicts between stakeholders (e.g., between tourism expansion and environmental protections).
# - Data needed
#   - Market analyses for niche tourism products; current and projected tourism demand; fishing and aquaculture viability and market access; grid reliability and renewable energy costs; training capacity and wage expectations.
# - Adaptation plan with new information
#   - Use pilot programs to validate business models; scale up successful ventures; adjust incentives and regulatory environments; improve workforce training aligned with industry demand.
#
# Decision 4. Protect sacred coastal sites and establish Indigenous co-governance over cultural resources
# - What it includes: formal recognition of indigenous rights, co-management frameworks for sacred coastal sites, funding for cultural mapping, sacred site protection, language and cultural restoration programs, and mechanisms for meaningful consent in project siting.
# - Estimated costs
#   - 0–5 years: $0.4B–$0.8B for mapping, legal recognition processes, and governance structures; ongoing support for cultural programs at $0.2B–$0.4B/year in perpetuity or until needs are met.
#   - 30 years: possible total $1.5B–$3B depending on scale and ongoing commitments.
# - Expected benefits
#   - Maintains cultural integrity; reduces risk of social conflict; improves legitimacy of adaptation actions in indigenous communities; creates protected cultural tourism value where consent and stewardship are respected.
# - Probability of success and failure
#   - Success probability: 0.7–0.9 (high if genuine partnership and funding commitments are in place).
#   - Failure modes: tokenistic engagement, governance deadlock, or inadequate funding to implement protections.
# - Monitoring metrics and triggers
#   - Metrics: number of sacred sites protected, co-management agreements signed, participation rates in governance bodies, cultural program uptake, and level of community satisfaction.
#   - Triggers: if consent or engagement falters, renew outreach and adjust governance structures; if protection measures fail to prevent encroachment, escalate to legal protections and enforcement where appropriate.
# - Stakeholder engagement and conflict adjudication
#   - Engage: indigenous leadership, cultural custodians, local government, tourism developers, and conservation groups.
#   - Adjudication: establish a Cultural Heritage and Indigenous Governance Board with veto rights on projects affecting sacred sites; ensure independent mediation and due process.
# - Data needed
#   - Inventory of sacred sites, cultural practices at risk, legal frameworks for co-management, community priorities, and potential economic trade-offs for cultural protections.
# - Adaptation plan with new information
#   - Update co-management agreements as communities express new priorities; incorporate new sacred-site GIS data; adjust protection funding to reflect evolving cultural needs.
# - Speculative vs evidence-based notes
#   - Evidence-based: importance of indigenous co-management for legitimacy and effectiveness.
#   - Speculative: precise governance structures and funding levels until consultations complete.
#
# Decision 5. Invest in data, mapping, and monitoring to inform adaptive management
# - What it includes: high-resolution shoreline change mapping, coastal hazard modeling, land-use inventories, population displacement risk assessments, environmental baseline data, early warning systems, and an integrated decision-support platform.
# - Estimated costs
#   - 0–5 years: about $0.3B–$0.5B for data systems, surveys, and modeling capacity.
#   - Ongoing: $0.1B–$0.2B/year for maintenance and upgrades.
# - Expected benefits
#   - Improves accuracy of risk assessments; enables timely decisions; reduces irreversible missteps; informs all other decisions (defense, retreat, diversification, and governance).
# - Probability of success and failure
#   - Success probability: 0.8–0.9 if sustained funding and local capacity are ensured.
#   - Failure modes: data gaps, interoperability issues, underfunded data stewardship, slow uptake by policymakers.
# - Monitoring metrics and triggers
#   - Metrics: data completeness and timeliness, forecast accuracy, decision latency, system uptime.
#   - Triggers: if data quality degrades or the model predictions diverge from observed outcomes, escalate data audits and update models; if policy lags behind data, trigger rapid-response policy cycles.
# - Stakeholder engagement and conflict adjudication
#   - Engage: scientists, local universities, municipal planners, indigenous data custodians, civil society.
#   - Adjudication: create an independent Data and Ethics Advisory Panel to review data usage, privacy concerns, and consent issues for data collection.
# - Data needed
#   - Shoreline and land-use change data, hazard maps, population distribution and migration risk, cultural site geolocations with sensitivities, and economic impact data for sectors.
# - Adaptation plan with new information
#   - Data-driven updates to siting of defenses and retreat, refine economic plans, and adjust governance structures in light of new evidence.
#
# Decision 6. Strengthen governance, social cohesion, and conflict resolution mechanisms
# - What it includes: multi-stakeholder climate council, citizen juries or deliberative forums for major decisions, transparent cost-benefit analyses, and credible grievance mechanisms; public information campaigns to explain adaptation choices.
# - Estimated costs
#   - 0–5 years: $0.2B–$0.4B to establish structures and first-year operating costs; ongoing $0.05B–$0.2B/year.
# - Expected benefits
#   - Reduces contestation, increases legitimacy and trust, improves policy acceptance, improves resilience outcomes through inclusive decision-making.
# - Probability of success and failure
#   - Success probability: 0.7–0.85 with strong, ongoing participation and clear mandates.
#   - Failure modes: capture by elites, decision paralysis, or shallow participation that fails to alter outcomes.
# - Monitoring metrics and triggers
#   - Metrics: number of decisions with broad stakeholder consent, public trust indices, incident rates of social unrest, and resolution times for disputes.
#   - Triggers: if cooperation declines, intensify outreach and capacity-building; if disputes escalate, trigger external mediation and review processes.
# - Stakeholder engagement and conflict adjudication
#   - Engage: community groups, indigenous representatives, business associations, NGOs, religious and cultural leaders, and youth groups.
#   - Adjudication: establish an independent Climate Governance Tribunal or similar body to resolve conflicts with legitimacy and due process.
# - Data needed
#   - Social indicators, asset ownership data, institutional capacity assessments, and historical grievance records.
# - Adaptation plan with new information
#   - Periodic governance reviews; incorporate lessons from other island states; adjust representation and decision rules for equity and effectiveness.
#
# Decision 7. Financing and fiscal planning to align with phased actions
# - What it includes: optimize use of $5B immediate funds; plan for up to $1B/year bond issuance (subject to market conditions); secure and allocate international aid when available; build a reserve fund for disasters.
# - Estimated costs
#   - Immediate allocation: distribute the $5B across decisions 1–4 (defense, retreat planning, diversification, cultural protections), plus a contingency reserve.
#   - Bond planning: outline a 10–15-year debt plan at modest yields to fund decisions 2–3 at scale; prepare for interest costs and debt service.
#   - International aid: expected (~60% probability of modest aid) to supplement specific programs; plan for worst-case and best-case aid scenarios.
# - Expected benefits
#   - Enables timely implementation; spreads costs over time; creates financial resilience to adapt to changing conditions.
# - Probability of success/failure
#   - Financing success depends on market conditions, macro stability, and aid availability; plan for multiple scenarios with contingency financing.
# - Monitoring metrics and triggers
#   - Metrics: debt service coverage ratio, budget execution rates, grant/aid disbursement timelines, reserve fund levels.
#   - Triggers: if bond markets tighten or aid delays occur, prioritize cheapest, fastest-to-implement actions; increase reliance on NbS and targeted protections rather than large-scale new infrastructure.
# - Stakeholder engagement and conflict adjudication
#   - Engage: financial authorities, planning ministries, local governments, and the public to ensure transparency about costs and trade-offs.
#   - Adjudication: establish a fiscal oversight board to oversee debt issuance and ensure intergenerational equity.
# - Data needed
#   - Macro-economic projections, interest rate scenarios, debt servicing capacity, and risk-adjusted project valuations.
#
# Decision 8. Data governance and continuous learning framework
# - What it includes: formal process to update the plan as new hazard data, tech, or social inputs arrive; scenario planning, and annual or biennial reviews.
# - Estimated costs
#   - Minor ongoing costs: $0.1B–$0.2B/year for convening, data integration, and plan updates.
# - Expected benefits
#   - Maintains plan relevance; reduces lock-in risk; improves outcomes through iterative improvement.
# - Probability of success and failure
#   - Success probability: high with political will and capacity to act on new information.
#   - Failure modes: bureaucratic inertia or slow decision-making.
# - Monitoring metrics and triggers
#   - Metrics: frequency of plan updates, time from data arrival to policy adjustment, stakeholder satisfaction with the adaptation process.
#   - Triggers: major new climate or economic data should trigger a formal plan revision cycle.
#
# Implementation sequencing and budgets (illustrative)
# - Year 0–5 (initial rollout with $5B)
#   - Coastal defense pilot (Decision 1): ~$1.5B
#   - Managed retreat planning and early relocations (Decision 2): ~$0.6–1.0B
#   - Economic diversification startup (Decision 3): ~$0.8–1.0B
#   - Cultural protection and co-governance setup (Decision 4): ~$0.4–0.8B
#   - Data and monitoring setup (Decision 5): ~$0.3–0.5B
#   - Governance and social cohesion (Decision 6): ~$0.2–0.4B
#   - Financing planning and reserves (Decision 7): integrated into overall budgeting
# - Year 6–15 (bond-funded expansion, contingent on markets)
#   - Scale defense and NbS (Decision 1): additional ~$1.5–2B
#   - Expand retreat programs (Decision 2): ~$2–4B
#   - Deepen diversification (Decision 3): ~$1–2B
#   - Cultural protection and governance (Decision 4): ~$0.5–1B
#   - Data system upgrades (Decision 5): ~$0.2–0.5B
#   - Governance and social cohesion (Decision 6): ~$0.2–0.4B
# - Year 15–30 (steady-state adaptive management)
#   - Ongoing maintenance, monitoring, and upgrades; phased retreats or protections as necessary; continued diversification investment.
#
# Monitoring, triggers, and contingency management
# - Core metrics to track across decisions
#   - Physical: coastline protection rates, flood/erosion reductions, relocation progress, inland housing quality, protected sacred sites, habitat and biosphere status.
#   - Economic: GDP contribution by diversified sectors, tourism mix, fishing yields, unemployment rates, and income resilience.
#   - Social: trust and social cohesion indicators, stakeholder participation, incident rates, grievance resolution times.
#   - Governance: plan update frequency, decision transparency, funding disbursement timelines, debt service status.
# - Trigger-based contingencies
#   - If sea-level rise accelerates beyond plan projections, re-prioritize protection in high-value zones and accelerate NbS.
#   - If social consensus for retreat is weak, slow the pace of relocations, increase incentives, and expand inland development with enhanced safeguards for cultural sites.
#   - If aid arrives late or is smaller than expected, scale back high-cost projects and prioritize low-cost, high-impact NbS plus governance strengthening.
#   - If markets for bonds are unfavorable, defer non-critical investments and intensify data-driven prioritization and cost-sharing with communities.
#
# What data to request before irreversible actions (critical inputs)
# - High-resolution hazard and shoreline-change data, including subsidence and storm surge models; updated sea-level rise projections under multiple scenarios.
# - Comprehensive asset inventory and land values in at-risk zones, including critical infrastructure, housing, and cultural sites.
# - Feasibility studies for inland relocation sites, including land availability, infrastructure needs, and social viability.
# - Cultural site inventories with sacred-site coordinates, usage patterns, and community protections; mapping for co-governance needs and consent requirements.
# - Economic baselines and future projections for tourism (including seasonality, climate sensitivity), fisheries (stocks, quotas), and potential diversification trajectories.
# - Indigenous governance structures, consent processes, and preferred models for co-management and data sharing.
# - Financing projections under multiple macroeconomic scenarios, including bond pricing, debt-service capacity, and aid conditionalities.
# - Public sentiment and social cohesion baselines to measure progress and identify risks of conflict.
#
# Data, monitoring, and updating the plan (adaptive management)
# - Establish an annual Climate Adaptation Review: assesses new data, revises hazard maps, and adjusts priorities and budgets.
# - Conduct a decadal strategic review (with interim mid-term reviews at years 10 and 20) to re-balance defense, retreat, and diversification investments given economic and climate changes.
# - Maintain a living, transparent public dashboard showing funding allocations, project progress, risk indicators, and outcomes.
# - Ensure decision pathways include explicit consent and accountability mechanisms for indigenous groups, local communities, and civil society.
#
# Assumptions and uncertainties (summary)
# - Assumptions used for cost ranges and sequencing are intentionally conservative and subject to refinement as data arrive.
# - The most impactful uncertainties:
#   - Actual pace and geographic pattern of sea-level rise and local subsidence.
#   - Economic costs of retreat and the feasibility of inland relocation sites.
#   - Effectiveness and costs of NbS versus hard defenses in the local context.
#   - Public acceptance of relocation and co-management arrangements, particularly among indigenous communities.
#   - Availability and terms of international aid and debt-financing options.
# - Evidentiary basis versus speculation:
#   - Evidence-based: general principles of combining NbS with engineered protections; importance of co-management and inclusive governance; necessity of data-informed decisions.
#   - Speculative: exact cost figures, siting of specific projects, and precise timing of large-scale relocations until hazard and economic data are refined.
#
# Ethical and governance notes
# - This plan emphasizes consent, participation, and rights of the indigenous minority. No forced relocations should occur without clear, free, prior, and informed consent, robust compensation, meaningful alternatives, and culturally sensitive planning.
# - Establish transparent decision-making processes, with independent oversight and clear grievance mechanisms to adjudicate conflicts across economic, safety, and cultural priorities.
# - Ensure that adaptation benefits are equitably distributed and that cultural heritage protections are prioritized alongside economic resilience.
#
# Specifically markable speculative elements
# - Exact cost allocations and procurement timelines are speculative and will adjust with data on hazard extent, land values, and market conditions.
# - Precise siting for retreat corridors and defense installations will be determined by updated hazard models, land availability, and community consultations.
# - The pace and scope of international aid, bond-market access, and demand for diversified livelihoods depend on global financial conditions and political will.
#
# Bottom line
# - A balanced, adaptive approach—protecting critical assets, offering managed retreat where necessary, diversifying the economy, and protecting sacred sites through Indigenous co-governance—offers the best prospect for maintaining safety, livelihoods, and cultural integrity over 30 years.
# - The plan relies on robust data, inclusive governance, and staged financing with clear triggers to adapt to new information. Regular updates and transparent stakeholder engagement are essential to minimize conflict and maximize resilience.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "anthropic/claude-sonnet-4.5"

claude = OpenAI(base_url=OPENROUTER_BASE_URL, api_key=openrouter_api_key)
response = claude.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

# claude = Anthropic()
# response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
# answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# # 30-Year Climate Adaptation Strategy for Island Nation
#
# ## Key Assumptions & Uncertainties
#
# ### Assumptions:
# - Current population: 1.2M (stable growth ~1% annually)
# - 40% land loss = ~300,000-400,000 people require relocation
# - Tourism contributes 30-40% GDP (evidence-based: typical small island developing states)
# - Indigenous minority represents 15-25% of population
# - Sea-level rise accelerates but remains within IPCC RCP 4.5-8.5 projections (speculative timing)
# - Democratic governance with rule of law maintained
#
# ### Critical Uncertainties (High Impact on Strategy):
# 1. **Rate of sea-level rise acceleration** (affects timeline for all decisions)
# 2. **Tourism market resilience** (COVID-19 showed 60-90% collapse possible)
# 3. **Political stability during mass relocation** (historical precedent: 30-40% chance of governance crisis)
# 4. **International aid materialization** (60% probability, but amount unknown)
# 5. **Bond market access** (depends on credit rating through crisis)
#
# ---
#
# ## Phase 1: Foundation & Assessment (Years 0-5)
# **Budget allocation: $2.5B initial + $1B bonds/year**
#
# ### 1A. Emergency Data Acquisition & Planning ($200M)
#
# **Actions:**
# - High-resolution LIDAR mapping of entire coastline
# - Participatory vulnerability mapping with indigenous communities
# - Economic dependency analysis by geography
# - Cultural site documentation and 3D preservation
# - Subsidence monitoring network
# - Storm surge modeling for 1-in-100 year events
#
# **Rationale for data needs:**
# Current global sea-level models have ±15cm uncertainty by 2050; local subsidence could add 10-30cm. Without ground-truth data, we risk either:
# - Over-investing in defenses for land that will subside anyway (waste ~$500M-1B)
# - Under-protecting economically critical areas (loss of $2-3B in assets)
#
# **Metrics:**
# - Complete baseline mapping: 18 months
# - Community consultation: 80% household participation
# - Cultural inventory: 100% documented sacred sites with indigenous verification
#
# **Probability assessment:**
# - Success (actionable data): 85% (evidence-based: standard technical work)
# - Partial failure (delays): 15% (political obstruction, technical issues)
#
# ---
#
# ### 1B. Stakeholder Governance Architecture ($50M)
#
# **Structure:**
# Create three parallel decision-making bodies:
#
# 1. **Technical Adaptation Council** (engineers, climate scientists, economists)
#    - Makes evidence-based recommendations
#    - No veto power, pure advisory
#
# 2. **Cultural Heritage Commission** (indigenous elders, historians, religious leaders)
#    - Veto power over decisions affecting documented sacred sites
#    - Must propose alternatives within 90 days of veto
#    - Funded to hire own technical experts
#
# 3. **Citizens' Assembly** (300 randomly selected residents, rotating yearly)
#    - Reviews major relocation/defense decisions
#    - Binding vote on plans >$500M
#    - Ensures democratic legitimacy
#
# **Conflict adjudication protocol:**
# - Tier 1: Facilitated negotiation (90 days)
# - Tier 2: Independent mediation panel (60 days)
# - Tier 3: Supreme Court review on constitutional grounds only
# - **Deadlock trigger**: If unresolved after 240 days, national referendum (used maximum twice per decade to prevent decision paralysis)
#
# **Probability of governance success:**
# - Maintains legitimacy through crisis: 65%
# - Partial breakdown (delays, protests): 25%
# - Complete failure (authoritarian drift or collapse): 10%
#
# *Justification*: Historical analysis of managed retreat (Isle de Jean Charles, Louisiana; Kiribati) shows governance failure rate of 30-40% without explicit indigenous co-management.
#
# ---
#
# ### 1C. Strategic Defense of Critical Infrastructure (Years 1-5: $2B)
#
# **Prioritize protection for:**
# 1. Primary airport (economic lifeline): $400M seawall + drainage
# 2. Main commercial port: $600M combined defenses
# 3. Capital city core (government, hospitals): $800M levee system
# 4. Water treatment plants: $200M elevation/relocation
#
# **NOT protected at this stage:**
# - Dispersed coastal villages (await relocation plan)
# - Secondary beach areas (tourism transition underway)
# - Agricultural lowlands (begin managed retreat)
#
# **Success probability:**
# - Infrastructure remains functional: 75% (evidence: Dutch/Singaporean engineering standards)
# - Partial failure (2-3 breaches by year 10): 20%
# - Catastrophic failure: 5%
#
# **Failure modes:**
# - Underestimated storm surge intensity
# - Coral reef degradation removes natural wave attenuation
# - Inadequate maintenance funding
#
# **Metrics & triggers:**
# - Annual stress tests
# - Settlement monitoring (<5mm/year acceptable)
# - **Contingency trigger**: If >2 infrastructure failures occur before Year 5, pause construction, reassess entire defense strategy (cost: $300M in delays)
#
# ---
#
# ## Phase 2: Economic Transition & Managed Retreat (Years 3-15)
# **Budget: $5B (remaining initial + bonds + projected aid $600M/year × 60% probability)**
#
# ### 2A. Tourism Economic Model Shift ($1.5B)
#
# **From:** Mass beach tourism → **To:** Climate resilience showcase + eco-cultural tourism
#
# **Components:**
# 1. **Living laboratory**: Partner with universities for climate research stations ($200M)
#    - Revenue: Attract conferences, research grants ($50M/year by year 10)
#
# 2. **Heritage cultural center**: Relocate threatened sacred sites' interpretive functions inland ($300M)
#    - Co-designed with indigenous communities
#    - Revenue: Cultural tourism premium pricing ($80M/year)
#
# 3. **Blue economy investment**: Deep-water aquaculture, ocean thermal energy ($800M)
#    - Probability of commercial viability by Year 15: 55%
#    - Downside risk: Loss of $600M if markets don't develop
#
# 4. **Digital services sector**: Tax incentives, fiber infrastructure ($200M)
#    - Leverage time zone, educated English-speaking population
#
# **Expected ROI:**
# - Base case (65% probability): $200M/year additional GDP by Year 15
# - Optimistic (20%): $400M/year
# - Pessimistic (15%): $50M/year (tourism collapse, tech doesn't scale)
#
# **Metrics:**
# - Tourism receipts per visitor (should increase even as volumes moderate)
# - New economy jobs created (target: 15,000 by Year 10)
# - **Decision gate at Year 8**: If new revenue <$80M/year, reallocate $500M from blue economy to Plan B (remittance economy, skilled labor export)
#
# ---
#
# ### 2B. Phased Managed Retreat ($2.5B)
#
# **Principle**: No forced relocation before Year 5; all moves voluntary until Year 10, then phased mandatory for highest-risk zones.
#
# **Implementation:**
#
# **Years 3-7 (Voluntary Phase):**
# - Purchase coastal properties at 125% pre-crisis market value + relocation stipend ($50k/household)
# - Priority: Areas with <15 years protection horizon
# - Develop 5 new inland settlements with full infrastructure
# - **Target**: Relocate 80,000 people (25% of affected population)
#
# **Predicted uptake**: 60% ± 15%
# - Justification: Buyout programs typically achieve 50-70% voluntary participation (evidence: US floodplain buyouts, Australian cyclone zones)
# - Lower participation likely in areas with indigenous sacred sites
#
# **Years 8-15 (Hybrid Phase):**
# - Mandatory building moratorium in highest-risk zones
# - Continued buyouts at 115% value
# - Rent-to-own programs in new settlements
# - **Target**: Additional 120,000 people relocated
#
# **Cost per person relocated**: ~$20,000 average (range: $8k-35k depending on property values)
#
# **Cultural site protection:**
# - Physical relocation of moveable artifacts/structures: $200M
# - Sacred site protocol: If site cannot be moved and area becomes uninhabitable:
#   - Maintain access via elevated pathways/boats as long as physically possible
#   - Ceremonial compensation process co-designed with Cultural Heritage Commission
#   - Establish inland memorial sites with blessing of traditional owners
#   - **Non-negotiable**: Indigenous communities decide which sites qualify for maximum protection effort (may exceed $50M per site)
#
# **Social cohesion metrics:**
# - Community satisfaction surveys (target: >60% approve of process)
# - Protest intensity (trigger for pause if sustained civil disobedience >5,000 people)
# - Indigenous community approval rating (minimum 50% support required)
# - **Major contingency**: If approval falls below thresholds, 12-month pause for plan revision
#
# **Probability assessment:**
# - Orderly retreat achieving 90%+ relocation by Year 15: 50%
# - Delayed/partial (70-85% relocated): 35%
# - Crisis scenario (major unrest, <65% relocated): 15%
#
# ---
#
# ### 2C. Fishing Sector Transformation ($500M)
#
# **Reality**: Traditional near-shore fisheries will be disrupted by:
# - Sea temperature changes (altering fish populations)
# - Coral bleaching (habitat loss)
# - Coastal infrastructure changes
#
# **Strategy:**
# 1. Upgrade to deeper-water capable vessels: $200M (subsidized loans)
# 2. Aquaculture training and startup grants: $150M
# 3. Fisheries monitoring/management tech: $50M
# 4. Safety net fund for transition: $100M (5-year income support)
#
# **Engagement**:
# - Co-design with fishing cooperatives
# - Guarantee: No fisher worse off than baseline for first 5 years
# - Job retraining if leaving sector
#
# **Metrics:**
# - Fishing income maintained >80% of baseline
# - Stock sustainability scores
# - **Trigger**: If >40% of fishers reject transition by Year 5, shift toward pure income support + alternative jobs
#
# ---
#
# ## Phase 3: Long-term Resilience (Years 15-30)
# **Budget: Remaining bonds + international aid + economic returns from Phase 2**
#
# ### 3A. Adaptive Infrastructure ($3B)
#
# **Speculative component**: Technology and climate trajectory will evolve significantly by Year 15. Strategy must remain flexible.
#
# **Pre-committed decisions:**
# - Retreat boundaries finalized by Year 10 (no further inland development restrictions)
# - Critical infrastructure hardened to Year 2070 projections + 30% safety margin
#
# **Adaptive decisions (await better data):**
# - Extent of nature-based solutions (mangrove restoration, coral gardening): Efficacy uncertain, $500M provisional
# - Floating/amphibious architecture: Unproven at scale, but preserve $800M option value
# - Regional migration agreements: Negotiate safety valve for worst-case population overflow
#
# ### 3B. Plan Update Protocol
#
# **Mandatory comprehensive reviews:**
# - Year 5: Adjust timeline based on observed sea-level rise rate
# - Year 10: Major economic strategy pivot if needed
# - Year 15, 20, 25: Full reassessment
#
# **Annual monitoring:**
# - Sea-level benchmarks (±5cm from projections triggers review)
# - Economic indicators (GDP, employment, inequality)
# - Social cohesion (survey data, election results, protest activity)
# - Cultural heritage preservation status
#
# **Trigger for fundamental strategy change:**
# - Sea-level rise >15cm ahead of central projection: Accelerate retreat, reduce defense spending
# - Economic collapse (GDP down >20%): Prioritize immediate welfare over long-term projects
# - Governance failure: International administration option
# - Major breakthrough (fusion energy, carbon removal): Consider holding more land
#
# ---
#
# ## Financial Structure
#
# **Initial 5-year budget ($7.5B total):**
# - Data & Planning: $200M (3%)
# - Governance: $50M (0.7%)
# - Critical infrastructure defense: $2B (27%)
# - Economic transition seed: $1B (13%)
# - Managed retreat start: $1.5B (20%)
# - Reserve fund: $750M (10%)
# - Ongoing government operations + social services: $2B (27%)
#
# **Risk management:**
# - Reserve fund for emergencies (natural disasters, economic shocks)
# - Bond issuance conditional on maintaining investment-grade rating
# - If aid fails to materialize: Reduce voluntary buyout prices to 100% market value, slower retreat timeline
# - Debt sustainability: Cap total borrowing at 70% GDP
#
# ---
#
# ## Evidence vs. Speculation
#
# **Evidence-based components:**
# - Engineering costs and success rates (extensive precedent)
# - Basic climate projections (IPCC consensus)
# - Governance failure modes (historical analysis)
# - Buyout program participation rates (empirical studies)
#
# **Speculative components:**
# - Exact timing of sea-level impacts (±5-10 year uncertainty)
# - New economic model success (blue economy unproven)
# - International aid amounts and consistency
# - Social cohesion maintenance through mass relocation (limited precedent at this scale)
# - Technology availability after Year 15
#
# **Most uncertain/highest impact:**
# The interaction between economic stress and social cohesion during Years 8-15. Historical precedent (post-disaster relocations, austerity programs) suggests 20-35% chance of political instability severe enough to derail managed retreat. This is the **critical vulnerability** requiring maximum monitoring and adaptive capacity.
#
# ---
#
# ## Ethical Framework for Impossible Choices
#
# **When economic, safety, and cultural priorities conflict irreconcilably:**
#
# 1. **Immediate safety > all**: If lives threatened, temporary overrides permitted (with compensation)
#
# 2. **Cultural survival**: Indigenous communities get veto over sacred sites + right to equivalent alternatives
#    - Exception: Cannot veto safety measures for others' lives
#    - Can accept financial compensation if community decides (their choice, not imposed)
#
# 3. **Economic efficiency secondary**: Will accept 10-15% cost premium to preserve social cohesion and cultural heritage
#
# 4. **Transparency paramount**: All decisions published with full reasoning, minority opinions recorded
#
# **Example hard case:**
# Major port generates 8% of GDP but expansion would destroy sacred burial ground. Indigenous community splits 60-40 against.
# - **Process**:
#   - Offer alternative port location (cost +$200M)
#   - If truly no alternative: Citizens' Assembly decides
#   - Winning margin must exceed 60% for irreversible action
#   - Losing community receives permanent trust fund ($100M) for cultural preservation
#   - Decision recorded as "tragic choice" acknowledging harm
#
# ---
#
# ## Summary: Theory of Success
#
# **This plan succeeds if:**
# 1. Aggressive early action buys time (Years 0-5)
# 2. Economic transition begins showing results by Year 8 (provides hope + funding)
# 3. Voluntary retreat achieves critical mass (reduces coercion needed later)
# 4. Governance maintains legitimacy through transparency and power-sharing
# 5. International community provides modest but sustained support
#
# **Success probability: 45-55%** (speculative estimate)
#
# **Most likely failure mode**: Economic transition underperforms → bond markets close → forced to choose between inadequate defense or coerced relocation without compensation → political instability → state failure
#
# **Mitigation**: Maintain reserve fund, preserve international migration options as safety valve, front-load most expensive infrastructure to early years when funds available.
#
# This is not a plan that "solves" the crisis—that's impossible with these constraints. It's a plan to **preserve community identity and democratic governance through managed decline**, avoiding the worst outcomes while acknowledging some painful losses are unavoidable.

# %%
#gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
gemini = OpenAI(base_url=OPENROUTER_BASE_URL, api_key=openrouter_api_key)
model_name = "google/gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ## 30-Year Adaptation Strategy for the Island Nation: Navigating the Tides of Change (Speculative elements marked with *)
#
# **Assumptions:**
#
# *   **Political Stability:** The government maintains sufficient stability to implement long-term strategies.
# *   **Competent Governance:** There is a baseline level of governmental capacity to execute complex projects.
# *   **Global Warming Trajectory:** The 40% loss of habitable land within 30 years is based on current climate models and trends, acknowledging potential for both faster and slower rates.
# *   **Tourism Demand:** While vulnerable, tourism will remain a viable, if transformed, economic sector for at least part of the 30-year horizon.
# *   **International Cooperation:** Acknowledgment that international aid, even if modest, is a critical component of the financial strategy.
# *   **Social Cohesion:** Despite polarization, a shared sense of urgency regarding national survival can be leveraged for unity.
# *   **Indigenous Resilience:** The indigenous population possesses strong cultural attachment and a willingness to participate in solutions, not just protest.
#
# **Key Uncertainties:**
#
# *   **Pace of Sea-Level Rise:** While 40% in 30 years is projected, the exact rate and regional variations are highly uncertain, impacting the timeline for managed retreat.
# *   **Effectiveness of Engineered Defenses:** The long-term efficacy and maintenance costs of various hard and soft defenses against accelerating sea-level rise are subject to uncertainty.
# *   **Global Market Appetite for Bonds:** Geopolitical events and global economic downturns could significantly impact the ability to raise $1 billion annually.
# *   **Level and Consistency of International Aid:** "Modest" is vague. The timing, conditions, and amount of aid are highly unpredictable.
# *   **Social Acceptance of Managed Retreat:** The willingness of affected populations to relocate, even with incentives, is a major unknown.
# *   **Economic Diversification Success:** The speed and scale at which new economic sectors can be developed and mature.
# *   **Technological Breakthroughs:** Unexpected advancements in climate engineering, sustainable energy, or resilient infrastructure could alter the cost-benefit analysis.
#
# ---
#
# ### Overarching Strategy & Guiding Principles:
#
# Our strategy adopts a **"Defend, Adapt, Diversify, and Unify"** approach, prioritizing rapid, decisive action while fostering long-term resilience. It acknowledges that a full "save-all-land" strategy is financially and physically impossible, necessitating difficult choices.
#
# **Guiding Principles:**
#
# 1.  **Safety First:** Prioritize the safety and well-being of all citizens.
# 2.  **Equity and Justice:** Ensure no community is left behind, paying particular attention to vulnerable populations and indigenous rights.
# 3.  **Cultural Preservation:** Protect and integrate indigenous knowledge and sacred sites into adaptation plans.
# 4.  **Economic Resilience:** Transition towards a diversified, knowledge-based economy less vulnerable to climate shocks.
# 5.  **Data-Driven Decisions:** Continuously monitor, adapt, and refine the plan based on new information.
# 6.  **Transparency and Participation:** Foster trust and shared ownership through open communication and broad stakeholder engagement.
#
# ---
#
# ### Phase 1: Immediate Action & Planning (Years 1-5)
#
# **Financial Allocation:**
#
# *   **Initial $5 Billion:** Allocated as follows:
#     *   **$1.5 Billion:** Immediate Engineered Defenses & Early Warning Systems (Critical Infrastructure Protection)
#     *   **$1 Billion:** Managed Retreat Pilot Programs & Resettlement Infrastructure Acquisition
#     *   **$1 Billion:** Economic Diversification Seed Fund & Workforce Training
#     *   **$1 Billion:** Social Cohesion & Cultural Preservation Programs (including indigenous land mapping)
#     *   **$0.5 Billion:** Research, Monitoring, & Governance (Data collection, modeling, institutional strengthening)
# *   **Annual $1 Billion Bonds & Modest International Aid (if received):** Primarily for scaling up Phase 1 initiatives and preparing for Phase 2.
#
# **A. ENGINEERED DEFENSES: Targeted Protection of Critical Assets**
#
# *   **Decision:** Invest in hard and soft defenses around critical infrastructure (hospitals, government buildings, power plants, key transportation hubs, **select high-value tourism zones**) and *limited, densely populated urban areas* with high economic output. These are temporary measures to buy time.
# *   **(1) Costs/Benefits/Probabilities:**
#     *   **Costs:** $1.5 billion (initial) + $200-$300 million/year for maintenance (bond funds).
#     *   **Benefits:** Protects critical services, maintains some economic activity, provides psychological security, buys time for managed retreat.
#     *   **Probability of Success (Short-term, 5-10 years): High (80%)** for preventing catastrophic failure at protected sites.
#     *   **Probability of Failure (Long-term, >20 years): High (70%)** without significant upgrades and against accelerating SLR; these are not permanent solutions for all areas. Justification: Hard defenses eventually fail or are overtopped; soft defenses require constant replenishment.
# *   **(2) Metrics & Triggers:**
#     *   **Metrics:** Sea-level rise (local tide gauges, satellite data), wave height/storm surge frequency, infrastructure damage reports, cost of repairs.
#     *   **Triggers:** If maintenance costs for engineered defenses exceed initial projections by >20% for two consecutive years, or if protected areas experience significant inundation despite defenses, this triggers a re-evaluation of defense strategies and faster managed retreat in those areas.
# *   **(3) Stakeholder Engagement & Conflict Resolution:** Engineering firms, local community leaders in protected zones, economic sector representatives. Conflicts will arise over which areas are *not* protected. Criteria for protection will be transparent: economic value, population density, critical national function. Open forums, cost-benefit analyses presented clearly. Cultural sites will generally *not* be protected by hard engineering in isolation, unless also critical infrastructure.
# *   **(4) Additional Data:** High-resolution LiDAR mapping of entire coastline (current sea-level, elevation, bathymetry), detailed hydrological modeling of storm surge pathways, geotechnical surveys for foundation stability for proposed defenses, comprehensive ecological impact assessments of defense structures. *Why:* To optimize defense placement, design, and minimize ecological harm.
# *   **(5) Updates:** Annual review of defense integrity, storm impacts, and cost-effectiveness. New climate models (IPCC updates) will be incorporated to re-evaluate protection levels. Funding for upgrades or expansion will be contingent on performance and updated risk assessments.
#
# **B. MANAGED RETREAT: Proactive Relocation Planning**
#
# *   **Decision:** Immediately begin comprehensive land acquisition for resettlement in higher-elevation, safer zones. Launch pilot programs for voluntary relocation with comprehensive support packages.
# *   **(1) Costs/Benefits/Probabilities:**
#     *   **Costs:** $1 billion (initial for land acquisition & pilot) + $300-$500 million/year from bonds (for land acquisition, infrastructure development, relocation subsidies).
#     *   **Benefits:** Saves lives, reduces future disaster costs, creates new, resilient communities, provides long-term security.
#     *   **Probability of Success (Pilots, demonstrating viability): Moderate (60%)** due to high social resistance but strong incentives.
#     *   **Probability of Failure (Widespread acceptance of retreat): High (70%)** without significant societal buy-in, adequate compensation, and appealing resettlement options. Justification: Deep emotional attachment to land, disruption of livelihoods.
# *   **(2) Metrics & Triggers:**
#     *   **Metrics:** Number of families voluntarily relocated, cost per relocation, satisfaction rates of relocated families, progress of new community infrastructure, land acquisition success rate.
#     *   **Triggers:** Low participation in pilot programs (<20% of target) or high dissatisfaction (>30%) triggers a review of incentive packages, communication strategies, and potentially compulsory relocation mechanisms (as a last resort if safety is paramount, but politically risky).
# *   **(3) Stakeholder Engagement & Conflict Resolution:** *Crucial.* Community meetings (town halls), direct consultations with affected households, indigenous leaders, anthropologists, social workers, land developers, legal experts. **Conflict adjudication:** An independent commission with representation from all stakeholder groups (including indigenous) will oversee disputes, focusing on fair compensation, culturally appropriate housing, and access to new livelihoods.
# *   **(4) Additional Data:** Comprehensive land ownership records, detailed demographic surveys of vulnerable coastal areas (including social networks, cultural ties), carrying capacity studies of potential resettlement areas (water, agriculture, infrastructure), psychological impact assessments of forced displacement. *Why:* To design equitable compensation, minimize social disruption, and ensure sustainable new settlements.
# *   **(5) Updates:** Bi-annual review of resettlement progress. Successes and failures of pilot programs are analyzed to refine the full-scale retreat strategy. Incorporate feedback from resettled communities. As new scientific understanding of SLR accelerates, retreat targets may be adjusted.
#
# **C. ECONOMIC DIVERSIFICATION: Building New Foundations**
#
# *   **Decision:** Invest in high-growth, climate-resilient sectors. Prioritize sustainable aquaculture (offshore, land-based), renewable energy production (geothermal, solar), specialized manufacturing (climate-tech, drones for surveillance), and a *reimagined, high-value, eco-tourism* (less coastal-dependent).
# *   **(1) Costs/Benefits/Probabilities:**
#     *   **Costs:** $1 billion (seed fund) + $200-$400 million/year from bonds (incubators, grants, training programs, infrastructure support).
#     *   **Benefits:** Creates new jobs, reduces reliance on vulnerable sectors, attracts foreign investment, builds long-term economic stability.
#     *   **Probability of Success (Initial setup of new industries): Moderate (60%)** Requires significant government support, private sector buy-in, and international partnerships.
#     *   **Probability of Failure (Achieving significant diversification within 10 years): Moderate (50%)** Economic transitions are inherently slow and risky. Justification: Competition, market access, skill gaps.
# *   **(2) Metrics & Triggers:**
#     *   **Metrics:** Number of new businesses created, job creation in new sectors, GDP contribution from diversified sectors, export revenues from new products, foreign direct investment.
#     *   **Triggers:** If growth in diversified sectors is below 5% annually for two consecutive years, or if tourism still dominates >70% of GDP after 5 years, this triggers a re-evaluation of investment priorities and greater incentives for entrepreneurship.
# *   **(3) Stakeholder Engagement & Conflict Resolution:** Business leaders, chambers of commerce, universities/technical schools, international aid organizations, potential investors, local fishing communities (for aquaculture transition). Conflicts: Prioritization of sectors, competition for resources. **Adjudication:** A national economic development council with multi-sector representation, transparent criteria for investment, and a clear appeals process.
# *   **(4) Additional Data:** Detailed market analyses for potential export products/services, skill gap analyses of the current workforce, feasibility studies for specific local renewable energy projects, environmental impact assessments of new industries. *Why:* To ensure investments are strategically sound and aligned with market opportunities.
# *   **(5) Updates:** Annual review of economic indicators and sector performance. Adapt training programs and investment incentives based on market demand and industry growth. Adjust funding allocation among different sectors.
#
# **D. SOCIAL COHESION & CULTURAL PRESERVATION:**
#
# *   **Decision:** Establish a permanent "National Resilience and Reconciliation Commission" with strong indigenous representation. Prioritize the digital and physical preservation of indigenous sacred sites (documentation, mapping, removal of portable artifacts, possible relocation of non-physical sacred practices). Integrate indigenous knowledge into adaptation strategies. Launch national unity campaigns.
# *   **(1) Costs/Benefits/Probabilities:**
#     *   **Costs:** $1 billion (initial for commission, mapping, digital archiving, community-led initiatives) + $100-$200 million/year from bonds.
#     *   **Benefits:** Bridges societal divides, respects human rights, preserves irreplaceable heritage, strengthens national identity, leverages indigenous wisdom for adaptation.
#     *   **Probability of Success (Reducing polarization): Moderate (50%)** Deep-seated issues take time, but a shared existential threat can be a powerful unifying force.
#     *   **Probability of Failure (Achieving full reconciliation): High (70%)** Reconciliation is a continuous process, not a finite achievement. Justification: Generational grievances, mistrust.
# *   **(2) Metrics & Triggers:**
#     *   **Metrics:** Public opinion surveys on national unity, participation rates in reconciliation dialogues, number of indigenous sacred sites documented/preserved, indigenous representation in decision-making bodies, cultural exchange program participation.
#     *   **Triggers:** If polarization indicators worsen (e.g., increased social unrest, low trust scores), or if indigenous leaders indicate lack of meaningful participation, triggers a review of the Commission's mandate, structure, and communication strategies.
# *   **(3) Stakeholder Engagement & Conflict Resolution:** Indigenous elders, youth, community leaders, historians, archaeologists, religious leaders, social scientists, government representatives. **Conflicts:** Prioritization of sites for preservation, methods of preservation (in-situ vs. relocation), interpretation of sacredness. Adjudicated by the National Resilience and Reconciliation Commission, with independent cultural experts and dispute resolution mechanisms prioritizing indigenous perspectives and self-determination.
# *   **(4) Additional Data:** Comprehensive ethnographies of indigenous communities, detailed historical mapping of sacred sites, oral history collection, assessments of cultural institutions' capacity for digital archiving and preservation. *Why:* To inform respectful and effective preservation strategies and ensure indigenous leadership.
# *   **(5) Updates:** Regular (quarterly/biannual) meetings of the Commission. Feedback from indigenous communities is paramount. Adapt cultural preservation methods based on new technologies or indigenous preferences.
#
# ---
#
# ### Phase 2: Scaling & Consolidation (Years 6-15)
#
# *   **Financial Allocation:** Primarily from annual ~$1 Billion bonds and any sustained international aid.
#     *   **Managed Retreat & New Community Development:** ~40-50% (main focus as SLR accelerates).
#     *   **Economic Diversification & Research:** ~20-30%.
#     *   **Engineered Defense Maintenance & Strategic Upgrades:** ~10-15%.
#     *   **Social Cohesion & Cultural Preservation:** ~10-15%.
#
# *   **Focus:**
#     *   **Managed Retreat:** Large-scale, organized relocation with established incentives and infrastructure in new, resilient urban centers.
#     *   **Economic Diversification:** Mature new industries, significant job creation, reduced reliance on traditional tourism. Invest in R&D.
#     *   **Engineered Defenses:** Maintain critical defenses, strategically decommission non-essential ones as retreat progresses.
#     *   **Social Cohesion:** Deepen reconciliation efforts, integrate indigenous knowledge into national planning, strengthen community bonds in new settlements.
#     *   **Cultural Preservation:** Continuous digital and physical preservation, potentially establishing a national "Cultural Ark" in a safe zone.
#
# ---
#
# ### Phase 3: Long-Term Resilience & Transformation (Years 16-30)
#
# *   **Financial Allocation:** Primarily from bonds (if markets permit), international climate funds, and robust new domestic tax revenues from diversified economy.
# *   **Focus:**
#     *   **Managed Retreat:** Completion of major population shifts; focus on ecosystem restoration in abandoned coastal areas (where culturally acceptable and feasible).
#     *   **Economic Independence:** Self-sustaining, diversified economy with global market competitiveness.
#     *   **Resilient Infrastructure:** All remaining infrastructure designed for future climate impacts, potentially "floating cities" or other innovative solutions *if technologically and economically viable (*speculative*)*.
#     *   **National Identity:** A strong, unified national identity forged through shared adversity and successful adaptation. A global leader in climate adaptation.
#     *   **Cultural Legacy:** Indigenous heritage fully integrated into national consciousness and protected for future generations.
#
# ---
#
# ### Contingency Planning (Triggered by Metrics & Uncertainties):
#
# 1.  **Accelerated Sea-Level Rise:**
#     *   **Trigger:** If observed SLR consistently exceeds worst-case projections for 3+ years.
#     *   **Contingency:** Accelerate managed retreat timelines, reallocate funds from engineered defenses to retreat, potentially invoke emergency powers for compulsory relocation in high-risk areas (as a last resort). Seek immediate additional international emergency aid.
#
# 2.  **Economic Market Collapse for Bonds:**
#     *   **Trigger:** Inability to raise >50% of projected annual bond funds for 2 consecutive years.
#     *   **Contingency:** Drastically cut non-essential projects. Prioritize critical engineered defenses (only for national security/survival elements), and managed retreat for the most vulnerable. Increase domestic taxation, seek emergency international loans/grants. Delay less urgent infrastructure development in new communities.
#
# 3.  **Low Social Acceptance of Retreat / Increased Polarization:**
#     *   **Trigger:** Consistent low participation in voluntary retreat, significant unrest or violence related to displacement.
#     *   **Contingency:** Increase incentives for relocation, launch intensive public education campaigns, engage more directly with community leaders to co-design solutions. Review and refine the independent commission’s powers for adjudication. Consider a national "resilience tax" on those who resist relocation in critical areas, to fund resettlement for others (highly controversial, *speculative*).
#
# 4.  **Failure of Economic Diversification:**
#     *   **Trigger:** Stagnant growth in new sectors, continued high reliance on declining traditional sectors.
#     *   **Contingency:** Aggressive retraining programs, tax holidays for foreign direct investment in *proven* successful new sectors, national innovation challenge funds, direct government investment/ownership in strategic industries to jumpstart growth.
#
# ---
#
# ### Ongoing Data Requirements (Beyond Initial Needs):
#
# *   **Continuous High-Resolution Coastal Monitoring:** Drones, satellite imagery, ground-based sensors for real-time inundation mapping and erosion rates.
# *   **Socio-Demographic Tracking:** Longitudinal studies of relocated populations, including mental health impacts, economic integration, cultural retention.
# *   **Economic Impact Assessments:** Regular, independent evaluations of the performance of new economic sectors and the overall economic transition.
# *   **Climate Modeling Updates:** Incorporate latest IPCC reports, regional downscaling models, and local observational data to refine SLR projections and extreme weather event frequencies.
# *   **Ecological Monitoring:** Tracking the health of marine and terrestrial ecosystems, particularly in areas impacted by defenses or retreat, and in new settlement areas.
# *   **Public Opinion and Sentiment Analysis:** Regular surveys and qualitative studies to gauge public support, identify emerging conflicts, and understand adaptation challenges from the citizen's perspective.
#
# ---
#
# ### Conclusion:
#
# This 30-year adaptation strategy is a living document, designed to be flexible and responsive to an uncertain future. It attempts to balance the immediate existential threat with the long-term vision of a resilient, unified, and culturally rich island nation. The emphasis on immediate data collection, transparent governance, and continuous stakeholder engagement is crucial for navigating the immense challenges ahead. Success will hinge on the government's ability to forge unity from diversity, make difficult choices decisively, and foster a national spirit of adaptation and innovation. The cost is immense, but the cost of inaction is the demise of the nation.

# %%
#deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
deepseek = OpenAI(base_url=OPENROUTER_BASE_URL, api_key=openrouter_api_key)
model_name = "deepseek/deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ### **Prioritized 30-Year Adaptation Strategy**
#
# The proposed strategy balances immediate action with long-term adaptation, focusing on five pillars: engineered defenses, managed retreat, economic transition, social cohesion, and cultural site protection. The plan is phased, adaptable, and incorporates stakeholder engagement, monitoring, and contingency planning.
#
# ---
#
# ### **Pillar 1: Engineered Defenses**
# #### **Actions:**
# - **Short-term (<5 years):** Construct seawalls and mangrove restoration in high-risk areas.
# - **Medium-term (5-15 years):** Invest in permeable breakwaters and raising critical infrastructure.
# - **Long-term (15-30 years):** Develop hybrid solutions (e.g., offshore artificial reefs).
#
# #### **Costs & Benefits:**
# - **Costs:** $2 billion over 30 years.
# - **Benefits:** Protects 50% of currently habitable land, preserves tourism infrastructure.
# - **Success Probability:** 70% (engineered defenses have proven efficacy in similar contexts).
# - **Failure Probability:** 30% (uncertainty about sea-level rise pace and extreme weather events).
#
# #### **Monitoring Metrics:**
# - Coastal erosion rates, flood frequency, and infrastructure damage reports.
#
# #### **Stakeholder Engagement:**
# - Work with local communities and environmental groups to minimize ecological disruption.
# - Conflict adjudication: Prioritize areas with high economic value and population density.
#
# #### **Additional Data Request:**
# - Detailed coastal topography and hydrology studies to optimize defense placements.
#
# ---
#
# ### **Pillar 2: Managed Retreat**
# #### **Actions:**
# - **Short-term:** Identify relocation zones and incentivize voluntary migration from high-risk areas.
# - **Medium-term:** Develop new inland communities with adequate infrastructure.
# - **Long-term:** Enforce gradual relocation policies.
#
# #### **Costs & Benefits:**
# - **Costs:** $1.5 billion over 30 years.
# - **Benefits:** Reduces exposure to sea-level rise, allows for re-naturalization of coastal areas.
# - **Success Probability:** 60% (depends on community buy-in and funding availability).
# - **Failure Probability:** 40% (potential resistance from affected communities).
#
# #### **Monitoring Metrics:**
# - Population migration rates, land use changes, and community satisfaction surveys.
#
# #### **Stakeholder Engagement:**
# - Collaborate with indigenous leaders and community organizers to ensure cultural sensitivity.
# - Conflict adjudication: Prioritize safety while compensating relocated communities.
#
# #### **Additional Data Request:**
# - Demographic projections and land ownership records to plan relocation.
#
# ---
#
# ### **Pillar 3: Economic Transition**
# #### **Actions:**
# - **Short-term:** Invest in eco-tourism and aquaculture to diversify the economy.
# - **Medium-term:** Develop renewable energy (e.g., solar, wind) and tech education programs.
# - **Long-term:** Transition to a knowledge-based economy.
#
# #### **Costs & Benefits:**
# - **Costs:** $1 billion upfront, $500 million annually for 10 years.
# - **Benefits:** Reduces reliance on tourism and fishing, creates jobs in resilient sectors.
# - **Success Probability:** 65% (economic diversification has worked in other small island nations).
# - **Failure Probability:** 35% (global market volatility and skill gaps).
#
# #### **Monitoring Metrics:**
# - GDP growth, unemployment rates, and sectoral employment statistics.
#
# #### **Stakeholder Engagement:**
# - Partner with businesses, unions, and educators to align training with market needs.
# - Conflict adjudication: Prioritize sectors with high job creation potential.
#
# #### **Additional Data Request:**
# - Market analysis of emerging industries and skills assessments.
#
# ---
#
# ### **Pillar 4: Social Cohesion**
# #### **Actions:**
# - **Short-term:** Launch national dialogues and cultural heritage preservation programs.
# - **Medium-term:** Implement equity-focused policies (e.g., housing, education).
# - **Long-term:** Strengthen social safety nets and community resilience programs.
#
# #### **Costs & Benefits:**
# - **Costs:** $500 million over 30 years.
# - **Benefits:** Reduces societal polarization, fosters collective action.
# - **Success Probability:** 55% (long-term social programs face implementation challenges).
# - **Failure Probability:** 45% (potential resistance from polarized groups).
#
# #### **Monitoring Metrics:**
# - Social cohesion indices, crime rates, and public trust in government.
#
# #### **Stakeholder Engagement:**
# - Regular town halls and collaboration with civil society organizations.
# - Conflict adjudication: Ensure equal representation of diverse voices.
#
# #### **Additional Data Request:**
# - Sociological studies on sources of polarization and trust-building mechanisms.
#
# ---
#
# ### **Pillar 5: Cultural Site Protection**
# #### **Actions:**
# - **Short-term:** Document and digitize sacred sites.
# - **Medium-term:** Develop protective barriers and relocate movable artifacts.
# - **Long-term:** Integrate cultural heritage into national education and tourism.
#
# #### **Costs & Benefits:**
# - **Costs:** $500 million over 30 years.
# - **Benefits:** Preserves cultural identity, enhances tourism appeal.
# - **Success Probability:** 75% (technological solutions can effectively protect sites).
# - **Failure Probability:** 25% (physical site loss due to extreme events).
#
# #### **Monitoring Metrics:**
# - Site condition reports, visitor numbers, and community satisfaction.
#
# #### **Stakeholder Engagement:**
# - Collaborate with indigenous leaders and cultural experts.
# - Conflict adjudication: Cultural preservation prioritized over economic gains where feasible.
#
# #### **Additional Data Request:**
# - Detailed site inventories and risk assessments.
#
# ---
#
# ### **Monitoring & Contingency Planning**
# - Establish a Climate Adaptation Task Force to oversee implementation.
# - Use adaptive management: review progress every 5 years and adjust strategies based on data.
# - Trigger contingencies if key metrics deviate >20% from projections (e.g., faster sea-level rise, economic collapse).
#
# ---
#
# ### **Assumptions & Uncertainties**
# #### **Assumptions:**
# - Sea-level rise projections are accurate to within ±10%.
# - International aid will be modest and disbursed over 10 years.
# - Global economic conditions remain stable enough to issue bonds.
#
# #### **Key Uncertainties:**
# - Pace of sea-level rise exacerbating land loss.
# - Availability of international aid and bond market conditions.
# - Political will and public support for long-term policies.
#
# ---
#
# ### **Speculative vs. Evidence-Based**
# - **Speculative:** Assumptions about international aid availability and bond market conditions.
# - **Evidence-Based:** Engineered defenses and economic diversification strategies derived from case studies in similar contexts.
#
# This plan is adaptive, participatory, and designed to evolve as new information becomes available.

# %%
# Updated with the latest Open Source model from OpenAI

#groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
groq = OpenAI(base_url=OPENROUTER_BASE_URL, api_key=openrouter_api_key)
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ## 1.  Assumptions (the “ground‑rules” on which the whole plan is built)
#
# | # | Assumption | Why it matters |
# |---|------------|----------------|
# | A1 | **Population = 1.2 M, with 15 % Indigenous (≈180 k).** | Determines the scale of shelter, relocation, and cultural‑site protection. |
# | A2 | **Sea‑level‑rise (SLR) trajectory = +0.6 m by 2050, +1.1 m by 2080 (IPCC AR6 RCP 4.5).** | Drives the timing of loss of low‑lying land (≈40 % in 30 y). |
# | A3 | **Current GDP ≈ US$4.5 bn; tourism ≈ 45 % of GDP, small‑scale fisheries ≈ 12 %.** | Sets the economic baseline that must be defended or diversified. |
# | A4 | **$5 bn cash now, plus $1 bn per year via sovereign bonds if markets stay “stable”.** | Provides the fiscal envelope for capital‑intensive works. |
# | A5 | **60 % probability of receiving “modest” (≈ US$0.5‑1 bn total) multilateral aid over 10 y.** | Adds a contingent resource that can be earmarked for climate‑specific projects. |
# | A6 | **Bond issuance cost = 0.5 % of principal per year; debt service = 2 % of GDP for the first 15 y, then 1 % thereafter.** | Limits the realistic annual borrowing capacity. |
# | A7 | **Legal framework allows “managed retreat” if a democratic vote (≥ 2/3 of affected community) is obtained.** | Determines the political feasibility of relocation. |
# | A8 | **Indigenous people have a constitutionally‑protected right to “free, prior and informed consent” (FPIC) over sacred sites.** | Sets the minimum procedural requirement for any action affecting cultural heritage. |
# | A9 | **Engineering standards = 100‑year design life, with 5 % safety margin for extreme events.** | Determines design loads for sea‑walls, levees, etc. |
# | A10| **All cost figures are in 2026 US$ (no inflation adjustment for simplicity).** | Keeps the numbers comparable. |
#
# > **Evidence‑based**: A2, A3, A9 (based on published IPCC scenarios, World Bank data, engineering codes).
# > **Speculative**: A5 (aid probability is an expert judgement), A6 (bond cost and debt‑service assumptions), A7–A8 (legal‑political context may shift).
#
# ---
#
# ## 2.  Key Uncertainties that drive the analysis
#
# | Uncertainty | Impact on plan | Range of plausible values |
# |-------------|----------------|-----------------------------|
# | **U1 – SLR rate & extreme‑storm frequency** | Timing of when and where defenses become inadequate. | +0.5 m to +1.2 m by 2050; 1‑3× increase in storm surge height. |
# | **U2 – Bond market conditions** | Ability to raise $1 bn/yr. | 0 bn – $2 bn/yr (depending on sovereign rating, global rates). |
# | **U3 – International aid amount & timing** | Whether to rely on external financing for large “non‑core” projects. | 0 bn – $1.5 bn over 10 y. |
# | **U4 – Tourist demand elasticity to climate risk** | Revenue projections for tourism‑based ROI of coastal infrastructure. | 0.5 × – 2 ×  current levels. |
# | **U5 – Indigenous community willingness to relocate (when needed)** | Feasibility of managed retreat for specific villages. | 60 % – 100 % acceptance when FPIC is respected. |
# | **U6 – Effectiveness of “green” nature‑based solutions (e.g., mangrove restoration)** | Cost‑benefit of low‑tech options versus hard engineering. | 30 % – 80 % of projected wave attenuation. |
#
# *The plan is deliberately staged so that each major decision can be re‑evaluated when the next tranche of data (e.g., new SLR projections, bond market reports) becomes available.*
#
# ---
#
# ## 3.  Overall 30‑Year Adaptive‑Management Roadmap
#
# | Phase (Years) | Primary Goal | Core Activities (ordered by priority) | Funding Mix (USD) |
# |---------------|--------------|----------------------------------------|-------------------|
# | **0‑5** | **Resilience baseline & “no‑regret” measures** | 1️⃣ **Nationwide vulnerability & exposure mapping** (LiDAR, bathymetry).<br>2️⃣ **Rapid “green buffer” pilot** – restore 150 km of mangroves around 3 critical estuaries.<br>3️⃣ **Establish an independent Climate‑Adaptation Council (CAC)** with equal Indigenous and non‑Indigenous representation.<br>4️⃣ **Create a “Climate‑Resilience Trust Fund” (CRT) with the $5 bn seed** – earmark $2 bn for short‑term works, $1 bn for data and planning, $1 bn for socio‑economic transition pilots, $0.5 bn for contingency. | $5 bn (all from cash) |
# | **5‑15** | **Hard protective infrastructure where it buys >10‑yr life** | 5️⃣ **Coastal Protection Zones (CPZs)** – 3–5 high‑value “core tourism” strips (≈30 km total) protected with hybrid seawall‑/revetment‑systems (concrete + bio‑breakwater).<br>6️⃣ **Upgrade storm‑drain & flood‑gate networks in coastal towns**.<br>7️⃣ **Begin voluntary managed‑retreat pilots** – relocate 2 km² of settlements (≈8 000 people) to higher ground with full compensation. | $2 bn (cash + first $1 bn bond tranche) |
# | **15‑25** | **Scale‑up retreat & economic diversification** | 8️⃣ **Full‑scale Managed‑Retreat Program** – target 25 % of at‑risk population (≈150 000) for relocation to inland “Resilience Communities” (new housing, utilities, schools).<br>9️⃣ **Economic Transition Fund (ETF)** – re‑skill 30 % of tourism workforce into eco‑tourism, renewable‑energy services, and digital‑economy jobs.<br>🔟 **Cultural‑Site Protection** – acquire, legally protect, and physically buffer all identified sacred coastal sites (≈120 sites).<br>1️⃣1️⃣ **Expand nature‑based defenses** – 1 500 km of mangrove/reef restoration, 300 ha of coastal wetlands. | $2 bn (bond proceeds 2‑3 yr, plus $0.5 bn aid contingent) |
# | **25‑30** | **Fine‑tune, monitor, and “exit” or “hold” decisions** | 1️⃣2️⃣ **Re‑assessment of all CPZs** – decide whether to upgrade, de‑commission, or hand‑over to community‑managed eco‑barriers.<br>1️⃣3️⃣ **Finalize “Climate‑Locked‑In” land‑use zoning** – lock‑in land‑use rules for the next 50 y based on projected SLR.<br>1️⃣4️⃣ **Long‑term financing plan** – issue “climate‑bond” series indexed to SLR indicators to fund maintenance. | $1 bn (remaining cash, plus any remaining aid) |
#
# *All phases are *contingent* – i.e., each step can be halted or accelerated when trigger metrics (see Section 4) indicate a shift in the underlying uncertainties.*
#
# ---
#
# ## 4.  Decision‑Level Detail (Cost‑Benefit, Success Probabilities, Metrics, Stakeholder Process, Data Needs, Adaptive Loop)
#
# Below are the **nine** “major decisions” that together compose the whole strategy.  For each, the table lists (1) expected cost & benefit, (2) probability of success/failure, (3) progress metrics & trigger points, (4) stakeholder engagement & conflict adjudication, (5) additional data required before a point‑of‑no‑return, and (6) how the decision will be revisited.
#
# > **Legend** – **E** = Evidence‑based; **S** = Speculative (clearly marked).
#
# ### 4.1 Decision 1 – Nationwide High‑Resolution Exposure Mapping
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $120 M (LiDAR, aerial photogrammetry, bathymetric surveys, GIS integration). |
# | **Benefit** | Reduces future “over‑building” risk by 15 % (estimated $300 M avoided damages over 30 y). |
# | **Success Probability** | 0.95 – technology and expertise are available; failure mainly due to data‑sharing bottlenecks. |
# | **Failure Impact** | 0.05 × $120 M = $6 M wasted; also delays downstream planning. |
# | **Metrics / Triggers** | • % of coastline surveyed (target = 100 %).<br>• Data accuracy validated against tide‑gauge benchmarks (RMSE < 0.15 m). |
# | **Stakeholder Process** | • CAC commissions an independent “Mapping Review Committee” (incl. university, Indigenous land‑rights NGOs).<br>• Public portal for community uploads of local knowledge (e.g., historic shoreline markers). |
# | **Data Needed Before Next Step** | • High‑resolution DEM (≤ 0.5 m vertical).<br>• Updated population density grids. |
# | **Adaptive Update** | Review after Year 2; if coverage < 90 % or data quality < E, inject additional budget (up to $30 M) and re‑schedule. |
# | **Evidence‑Based / Speculative** | E (costs from similar projects in the Caribbean). |
#
# ---
#
# ### 4.2 Decision 2 – Pilot Mangrove Restoration (150 km)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $45 M (seedlings, community labor, monitoring). |
# | **Benefit** | Expected wave attenuation 30‑40 % (equivalent to $60 M avoided flood damages over 20 y) + carbon sequestration ≈ 0.9 Mt CO₂e (≈ $12 M credit). |
# | **Success Probabilities** | **Success** 0.70 – depends on survival > 70 % after 3 y (based on regional pilot data).<br>**Failure** 0.30 – e.g., due to storm damage or poor nursery practices. |
# | **Metrics / Triggers** | • Survival rate of planted saplings after 2 y (target ≥ 70 %).<br>• Measured reduction in wave height at 5 monitoring stations (≥ 25 %). |
# | **Stakeholder Process** | • Co‑manage with coastal Indigenous groups (traditional ecological knowledge).<br>• Agreements signed on “shared‑benefit” (e.g., fish‑stock enhancement). |
# | **Data Needed** | • Soil salinity and hydrology maps of pilot zones.<br>• Baseline biodiversity surveys. |
# | **Adaptive Loop** | If survival < 50 % after 2 y, re‑evaluate species mix and consider “engineered reef” alternatives; re‑allocate up to $10 M. |
# | **E / S** | E (costs & benefits drawn from published meta‑analyses). |
#
# ---
#
# ### 4.3 Decision 3 – Create Climate‑Adaptation Council (CAC) & Climate‑Resilience Trust (CRT)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $30 M (setup, legal drafting, first‑year staffing). |
# | **Benefit** | Institutional capacity that reduces policy‑implementation lag by ~25 % (valued at $50 M over 30 y in avoided “delay‑costs”). |
# | **Success Probability** | 0.85 – depends on political will; risk of capture by vested interests (15 %). |
# | **Metrics** | • Council diversity index (≥ 40 % Indigenous, ≥ 30 % women).<br>• Time from proposal to decision ≤ 6 mo (target). |
# | **Stakeholder Process** | • Open call for nominations; transparent voting; independent ombudsman for grievances.<br>• All major infrastructure projects must receive CAC approval. |
# | **Data Needed** | • Legal audit of existing statutes to ensure CAC authority is constitutionally sound. |
# | **Adaptive Update** | Annual performance report; if decision lag exceeds 9 mo in two consecutive years, restructure (e.g., introduce “fast‑track” sub‑committee). |
# | **E / S** | S (political feasibility estimate). |
#
# ---
#
# ### 4.4 Decision 4 – Hybrid Seawall‑Revetment in Core Tourism Strips (≈30 km)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $650 M (design, construction, land acquisition). |
# | **Benefit** | Protects ~ $2.3 bn of tourism assets (hotels, ports) for at least 20 y; avoids ~ $800 M in flood losses (based on risk‑model). |
# | **Success Probability** | **High** 0.78 – proven engineering in comparable settings (e.g., Maldives).<br>**Failure** 0.22 – risk of design‑under‑performance under extreme storm surge (> 2 m). |
# | **Metrics** | • Structural integrity inspections (≤ 5 % crack growth per yr).<br>• Post‑storm water level behind wall ≤ 0.5 m above design water line. |
# | **Stakeholder Process** | • Cost‑benefit workshops with tourism operators and Indigenous coastal communities.<br>• “Cultural Impact Assessment” required; any sacred site within 100 m must trigger a mitigation plan (e.g., relocation of artefacts). |
# | **Data Needed** | • Updated extreme‑storm return‑period curves (30‑yr vs 100‑yr).<br>• Geotechnical surveys of foundation soils. |
# | **Adaptive Loop** | After 10 y, conduct “Design‑Life Review”: if sea level + storm surge exceeds designed capacity, allocate $150 M for heightening or transition to nature‑based defense. |
# | **E / S** | E (costs from similar projects; benefit estimates from tourism revenue data). |
#
# ---
#
# ### 4.5 Decision 5 – Upgrade Flood‑Gate Network in Coastal Towns
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $210 M (construction of 12 surge‑gates, automated controls). |
# | **Benefit** | Reduces flood‑damage risk to low‑lying residential zones by ≈ 55 % (≈ $340 M avoided over 30 y). |
# | **Success Probability** | 0.84 – technology mature; risk of maintenance shortfalls (16 %). |
# | **Metrics** | • Gate closure time ≤ 5 min after surge‑warning.<br>• Maintenance compliance: ≥ 95 % of scheduled inspections performed. |
# | **Stakeholder Process** | • Joint technical working group (municipal engineers + Indigenous water‑rights NGOs).<br>• Public “simulation days” to demonstrate gate operation. |
# | **Data Needed** | • Real‑time tide‑gauge network upgrade (cost $12 M). |
# | **Adaptive Loop** | If closure time > 10 min in two successive storms, allocate $30 M for automation upgrade. |
# | **E / S** | E (performance standards based on Dutch and Caribbean best‑practice). |
#
# ---
#
# ### 4.6 Decision 6 – Voluntary Managed‑Retreat Pilot (2 km², ≈ 8 000 people)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $310 M (land purchase, new housing, infrastructure, compensation). |
# | **Benefit** | Demonstrates feasible “exit‑option” for 0.7 % of total population; avoids future $1.2 bn damages on the relocated area (if SLR continues). |
# | **Success Probability** | **Success** 0.65 – depends on achieving **FPIC** and delivering compensation > 115 % of market value.<br>**Failure** 0.35 – could stall due to community dissent or cost overruns. |
# | **Metrics** | • % of affected households signing FPIC (target ≥ 80 %).<br>• Post‑relocation satisfaction index (≥ 70 %). |
# | **Stakeholder Process** | • Dedicated “Retreat Mediation Panel” (legal experts, Indigenous leaders, civil‑society NGOs).<br>• Independent third‑party audit of compensation packages. |
# | **Data Needed** | • Precise elevation maps of pilot area (sub‑meter).<br>• Social‑impact baseline survey (household income, education). |
# | **Adaptive Loop** | If FPIC threshold not met after 18 mo, pause and redesign incentive package (e.g., add community‑owned renewable‑energy micro‑grid). |
# | **E / S** | S (social acceptance estimated from small‑scale studies; financial assumptions contingent on market data). |
#
# ---
#
# ### 4.7 Decision 7 – Full‑Scale Managed‑Retreat Program (≈ 150 000 people)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $2.8 bn (land acquisition, new districts, infrastructure, compensation). |
# | **Benefit** | Avoids an estimated $5.9 bn in future flood & adaptation losses (life‑safety value + economic). |
# | **Success Probability** | **Success** 0.55 – high uncertainty in scaling social consent and financing.<br>**Failure** 0.45 – could result in “partial” retreat, leaving high‑risk pockets. |
# | **Metrics** | • Annual relocation rate (target ≥ 12 000 people/yr after Year 6).<br>• Compliance with **FPIC** for each community (≥ 85 %). |
# | **Stakeholder Process** | • National “Retreat‑Negotiation Forum” (government, Indigenous councils, private developers).<br>• Transparent “benefit‑sharing fund” financed by a tourism levy (2 % of ticket sales). |
# | **Data Needed** | • Updated SLR maps for 2035, 2050, 2070 (to delineate “no‑go” zones).<br>• Comprehensive household asset registers. |
# | **Adaptive Loop** | Review every 3 y; if relocation rate < 50 % of target, shift funds to “in‑situ adaptation” (e.g., elevated houses) for those areas. |
# | **E / S** | S (financial and social scaling risk). |
#
# ---
#
# ### 4.8 Decision 8 – Economic Transition Fund (ETF)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $420 M (re‑skilling, seed‑capital for green‑tourism, renewable‑energy pilot projects). |
# | **Benefit** | Diversifies GDP: + 3 % annual growth in non‑tourism sectors; creates 12 000 new jobs (reducing tourism‑sector vulnerability). |
# | **Success Probability** | 0.72 – based on similar “just‑transition” programmes in Small Island Developing States (SIDS). |
# | **Metrics** | • Number of participants completing certified training (target ≥ 10 000).<br>• Share of GDP from renewable‑energy/eco‑tourism (target ≥ 15 % by Year 20). |
# | **Stakeholder Process** | • Co‑design with labor unions, Indigenous women’s groups, private sector (tourism operators).<br>• Independent advisory board to avoid capture. |
# | **Data Needed** | • Labor‑market skill gaps analysis.<br>• Market feasibility study for renewable‑energy export (e.g., solar‑to‑hydrogen). |
# | **Adaptive Loop** | Quarterly monitoring; re‑allocate up to 15 % of unused ETF budget toward “digital‑nomad” incentives if job creation lags. |
# | **E / S** | E (economic modeling from World Bank’s “SIDS transition” reports). |
#
# ---
#
# ### 4.9 Decision 9 – Protection & Legal Safeguarding of Sacred Coastal Sites
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $95 M (land purchase/easement, archaeological documentation, offshore buffer zones). |
# | **Benefit** | Guarantees cultural continuity; avoids irreversible loss valued at $2 bn in intangible cultural heritage (UNESCO valuation method). |
# | **Success Probability** | 0.88 – if early FPIC and legal registration are done; risk of political reversal (12 %). |
# | **Metrics** | • Number of sites under legal protection (target = 100 % of identified sites).<br>• Annual patrols preventing illegal encroachment (≥ 95 % compliance). |
# | **Stakeholder Process** | • Indigenous Cultural Heritage Committee (ICHC) leads site identification.<br>• Government‑run “Cultural Impact Fund” pays for community‑led stewardship. |
# | **Data Needed** | • High‑resolution GIS of all cultural sites (including oral‑history locations). |
# | **Adaptive Loop** | If any protected site is damaged (detected by satellite or community report), trigger emergency response fund ($5 M) and revise buffer zones. |
# | **E / S** | E (costs based on land‑acquisition prices; benefit valuation from UNESCO). |
#
# ---
#
# ## 5.  Financing Schedule & Contingency Logic
#
# | Year | Core Expenditure | Funding Source | Contingency Trigger |
# |------|----------------|----------------|--------------------|
# | **0‑5** | Mapping, Pilot mangroves, CAC/CRT set‑up, initial data collection | $5 bn cash (≈ 70 % of initial fund) | If **U2** (bond markets) deteriorates > 2 % yield, postpone Phase 2 until market improves. |
# | **5‑10** | CPZ seawalls, flood‑gate upgrades, voluntary retreat pilot | $1 bn/year bonds (expected) + $0.3 bn aid (if secured) | If **U1** shows SLR > 0.8 m by 2035, accelerate seawall heightening (add $150 M). |
# | **10‑15** | Managed‑retreat pilot scaling, nature‑based expansion, ETF launch | Same as above; start “climate‑bond” issuance (green‑label) | If **U3** (aid) does not materialise, raise climate‑bond volume by 30 % and re‑allocate a portion to retreat. |
# | **15‑20** | Full‑scale retreat, large‑scale cultural‑site protection | Bonds + revenue from tourism levy (2 % of tickets) + aid (if any) | If relocation rate < 50 % of target, shift 15 % of retreat budget to “elevated housing” in place (short‑term safety). |
# | **20‑30** | Maintenance of CPZs, final retreat corridors, long‑term monitoring | Bonds (re‑financed at lower rates), modest aid, small “maintenance levy” (0.3 % of tourism receipts) | If **U4** (tourism demand) drops > 30 %, re‑prioritise funds toward renewable‑energy export projects to offset revenue loss. |
#
# *All “contingency triggers” are defined as **hard thresholds** (e.g., SLR > 0.8 m) that automatically launch a pre‑approved “contingency fund” (5 % of the total budget, i.e., $250 M) to cover redesign or acceleration.*
#
# ---
#
# ## 6.  Stakeholder‑Engagement Framework (how conflicts are adjudicated)
#
# 1. **Institutional Layer – Climate‑Adaptation Council (CAC)**
#    *Mandate:* Review all major adaptation projects, ensure FPIC, balance cost‑benefit across sectors.
#    *Decision rule:* Qualified majority (≥ 66 %) of members; if no consensus, an independent **Arbitration Panel** (3 external experts) makes the final call.
#
# 2. **Community‑Level Layer – Village‑Level Advisory Boards (VLABs)**
#    *Composition:* elected local leaders, Indigenous elders, women’s representatives, youth delegate.
#    *Function:* Provide ground‑truth data, voice concerns early, co‑design local mitigation (e.g., mangrove planting).
#
# 3. **Economic‑Sector Layer – Tourism‑Industry Forum (TIF)**
#    *Participants:* hotel chains, local tour operators, Ministry of Tourism, NGOs.
#    *Role:* Develop “tourism‑resilience levy”, propose alternative “eco‑tourism” packages, monitor revenue metrics.
#
# 4. **Cultural‑Heritage Layer – Indigenous Cultural Heritage Committee (ICHC)**
#    *Authority:* Must approve any project that impacts sacred sites (FPIC).
#    *Conflict resolution:* If a development proposal threatens a site, the CAC can approve a **Mitigation‑Exchange** (e.g., funding for a cultural center elsewhere) **only** if ICHC signs a written waiver after a formal impact‑assessment.
#
# 5. **Legal Oversight – Environmental & Heritage Courts**
#    *Fast‑track* (≤ 90 days) jurisdiction over disputes involving safety vs. cultural values, with the possibility of injunctions.
#
# **Adjudication Example:**
# - *Scenario:* A proposed seawall would require seabed dredging that encroaches on a sacred fishing ground.
# - *Process:* VLAB raises objection → CAC commissions a joint **Socio‑Environmental Impact Assessment** → ICHC evaluates cultural loss → If mitigation (e.g., co‑managed marine protected area) is acceptable, CAC approves with conditional monitoring; otherwise, the project is re‑designed or moved.
#
# ---
#
# ## 7.  Data Gaps – What We Must Acquire Before “Irreversible” Actions
#
# | Data Gap | Why Critical | How to Obtain | Timing |
# |----------|--------------|---------------|--------|
# | **High‑resolution (≤ 0.5 m) DEM of entire coastline** | Determines which areas need hard defenses vs. retreat. | Air‑borne LiDAR + satellite interferometry (contract with regional university). | Year 1 (complete before seawall design). |
# | **Updated SLR & storm‑surge probability distributions** (including climate‑model ensembles) | Sets design water levels for defenses. | Collaboration with IPCC‑affiliated climate labs; local tide‑gauge network upgrade. | Year 2 (baseline for Phase 2). |
# | **Comprehensive Indigenous cultural‑site GIS** (including oral‑history coordinates) | Ensures FPIC and legal protection. | Community‑led participatory mapping workshops, digitised archives. | Year 1‑2 (before any coastal construction). |
# | **Socio‑economic baseline of households in high‑risk zones** (assets, income, health) | Basis for fair compensation in retreat. | Household surveys, tax‑record linkage, mobile‑phone data analytics. | Year 2‑3 (before the voluntary retreat pilot). |
# | **Cost‑effectiveness of nature‑based solutions vs. hard walls under future climate scenarios** | Avoids over‑investment in possibly premature hard infrastructure. | Pilot monitoring + Monte‑Carlo benefit‑cost modelling (partner with UNDP). | Year 3 (inform Phase 2 decision). |
# | **Tourism demand elasticity to climate‑risk perception** | Determines ROI of protecting tourism assets. | Visitor‐survey data, econometric analysis of past events (e.g., 2020 cyclone). | Year 4 (inform CPZ sizing). |
# | **Debt‑servicing capacity under different bond‑yield scenarios** | Guarantees fiscal sustainability. | IMF/World Bank debt‑sustainability analysis, multi‑scenario modelling. | Year 5 (pre‑bond issuance). |
#
# *Only after these data sets reach a **minimum‑confidence threshold** (e.g., 95 % CI for SLR) will the government move to “commit‑ment” phases (e.g., full‑scale seawall construction, mass relocation).*
#
# ---
#
# ## 8.  Updating the Plan – Adaptive‑Management Cycle
#
# 1. **Annual Review (Year 1‑30)** – CAC publishes a **State‑of‑Adaptation Report** (SAR) covering all metrics.
#    *If any metric deviates > 20 % from target* → trigger a **Decision‑Adjustment Workshop**.
#
# 2. **Three‑Year “Strategic Check‑point”** – Re‑run cost‑benefit models with the latest data (SLR, economic, social).
#    *If projected net‑present‑value (NPV) of a major component falls below 0* → re‑prioritise (e.g., shift from seawall to mangrove expansion).
#
# 3. **Mid‑Term “Retreat Feasibility Survey” (Year 12 & 22)** – Re‑assess community willingness, demographic shifts, and land‑availability.
#
# 4. **External Audits (Every 5 y)** – Independent auditors evaluate financial integrity, governance compliance, and social‑impact outcomes. Recommendations become binding if **≥ 70 %** of CAC votes for them.
#
# 5. **Learning Loop** – All lessons feed into the **National Climate‑Adaptation Knowledge Base** (open‑source platform) to inform future SIDS worldwide.
#
# ---
#
# ## 9.  Summary of Prioritization (Why this ordering makes sense)
#
# | Rank | Action | Rationale (risk‑reduction + value creation) |
# |------|--------|----------------------------------------------|
# | **1** | Mapping & Institutional set‑up (Dec 1‑3) | *Low cost, high information return; creates decision‑making backbone.* |
# | **2** | Pilot nature‑based solutions (Dec 2) | *No‑regret, improves ecosystem services while buying time.* |
# | **3** | Flood‑gate upgrades (Dec 5) | *High‑impact, protects large residential zones; relatively cheap.* |
# | **4** | Hybrid seawalls in core tourism (Dec 4) | *Protects the economic engine; justified only after we know exactly where sea‑level will hit.* |
# | **5** | Voluntary retreat pilot (Dec 6) | *Proof‑of‑concept for larger retreat; respects FPIC.* |
# | **6** | Managed‑retreat scale‑up (Dec 7) | *Only after pilot demonstrates feasibility & financing path.* |
# | **7** | Economic transition fund (Dec 8) | *Diversifies income, reduces future exposure; can run in parallel with retreat.* |
# | **8** | Cultural‑site protection (Dec 9) | *Legal requirement; relatively low cost; must be locked‑in early to avoid irreversible loss.* |
# | **9** | Maintenance & post‑30 y “exit” decisions (Dec 10) | *Ensures long‑term sustainability; informed by all prior monitoring.* |
#
# ---
#
# ## 10.  What Is Speculative vs. Evidence‑Based?
#
# | Area | Evidence‑Based (E) | Speculative (S) |
# |------|-------------------|-----------------|
# | Sea‑level projections (U1) | IPCC AR6 ensembles (E) | Local amplification due to subsidence (S) |
# | Cost of seawall (Dec 4) | Similar projects in Maldives, Seychelles (E) | Exact design height needed for 2080 scenario (S) |
# | Success rate of mangrove restoration (Dec 2) | Meta‑analysis of tropical mangrove projects (E) | Survival in the nation’s specific salinity regime (S) |
# | Public willingness for managed retreat (Dec 6‑7) | Survey data from other SIDS (E) | Local cultural attachment levels (S) |
# | Tourism elasticity to climate risk (U4) | Global tourism‑risk literature (E) | Nation‑specific branding effect (S) |
# | Debt‑service capacity under bond‑yield swing (U2) | IMF debt‑sustainability models (E) | Future global interest‑rate trajectories (S) |
# | Effectiveness of “green levy” for funding ETF (Dec 8) | Examples from Costa Rica, Belize (E) | Exact revenue generation for this nation (S) |
# | Cultural‑heritage valuation (Dec 9) | UNESCO guidelines (E) | Community’s internal valuation metrics (S) |
#
# The **core of the plan** (mapping, institutional setup, pilot green actions, flood‑gate upgrades) rests on **high‑confidence evidence**. The **large‑scale retreat and economic transition** are **moderately speculative**, requiring continuous monitoring and the ability to pivot.
#
# ---
#
# ## 11.  Final Recommendation to the Government
#
# 1. **Allocate the immediate $5 bn** as follows (see Phase 0‑5 table).
# 2. **Issue the first $1 bn bond tranche** within 12 months, earmarking 70 % for CPZs & flood‑gate upgrades; keep 30 % as a “contingency reserve”.
# 3. **Secure the 60 % aid probability** by submitting a joint “Island Climate Resilience” proposal to the Green Climate Fund (GCF) and the World Bank’s Small Island Adaptation Program (SIAP) **by the end of Year 2**.
# 4. **Activate the Climate‑Adaptation Council** immediately; its first mandate is to approve the detailed design criteria for seawalls **once the SLR model reaches > 0.6 m by 2035** (U1 trigger).
# 5. **Begin the voluntary retreat pilot** only after the **FPIC** process for the target village is completed (expected by Year 4).
#
# By following the **adaptive‑management cycle** (annual SAR, 3‑year strategic checkpoints, and mid‑term retreat feasibility surveys), the nation can **stay within its fiscal envelope**, **protect its most vulnerable communities and cultural heritage**, and **maintain the economic lifeline of tourism** while **building a more diversified, resilient future**.
#
# ---
#
# *Prepared for the Government of the Island Nation – 30‑Year Climate‑Adaptation Strategy (2026‑2056).*

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['openai/gpt-5-nano', 'anthropic/claude-sonnet-4.5', 'google/gemini-2.5-flash', 'deepseek/deepseek-chat', 'openai/gpt-oss-120b']
# ['Below is a 30-year, phased adaptation plan tailored to a diverse, tourism- and small-fisheries–based island nation with a 1.2 million population, facing rapid sea‑level rise, economic vulnerability, and a significant indigenous minority with sacred coastal sites at risk. Costs are expressed in USD billions; timescales are indicative. All figures are estimates subject to refinement as data arrive.\n\nExecutive overview\n- Core principle: balance engineered defenses, managed retreat where necessary, diversified livelihoods, and strong protection of cultural sites through inclusive governance.\n- Funding frame: $5B immediate; up to $1B/year via bonds if markets permit; ~60% chance of modest international aid over the next decade. Treat budgets as contingent on financing conditions and aid.\n- Phasing: (1) safeguard critical assets and identities; (2) establish retreat-ready pathways and economic diversification; (3) scale up protections and governance; (4) maintain data-led updates and flexible adaptation.\n\nAssumptions (explicit)\n- Population remains near 1.2 million; internal migration within the island is feasible.\n- 40% of habitable land is at high risk of inundation or salinization within ~30 years; rate of sea-level rise is within current projections but with uncertainty.\n- Tourism and small-scale fishing remain important but face climate and ecosystem limits; diversification improves resilience.\n- Indigenous communities have distinct cultural priorities and rights; meaningful participation and consent are required for changes to sacred coastal sites.\n- Financing constraints dominate early years; aid, debt markets, and grant opportunities are uncertain and contingent on global conditions.\n- Technologies and costs will evolve; plan remains adaptable.\n\nKey uncertainties likely to affect decisions\n- Pace and geographic distribution of sea‑level rise and coastal erosion (erosion rates, subsidence, storm surge behavior).\n- Value of protected assets (properties, ports, tourism infrastructure) and cost of land acquisition for retreat.\n- Social acceptability and political feasibility of managed retreat and relocation, particularly around indigenous coastal areas.\n- Availability and terms of international aid and bond markets.\n- Effectiveness and costs of nature-based defenses versus hard infrastructure.\n- Economic response to diversification (timing, labor market fit, supply chains).\n- Legal and governance reforms needed for indigenous co-management and cultural site protection.\n\nPlan components and major decisions (with costs, benefits, and success likelihoods)\n\nDecision 1. Deploy a layered coastal defense program that combines nature-based solutions with targeted engineered protections in priority areas\n- What it includes: mangrove restoration and dune systems where feasible; living shorelines; sea walls and flood barriers in high-value zones (ports, airports, urban cores); auxiliary drainage and flood-proofing; essential climate-resilient infrastructure retrofits.\n- Estimated costs (phased)\n  - Initial package (0–5 years): about $2.5B–$3B for core defenses in the most exposed zones plus NbS; ongoing maintenance funded from bonds later.\n  - 30-year program: potential total $5B–$6B (capable of expanding if additional zones are identified).\n- Expected benefits\n  - Reduces flood/tide- and storm-related damages in high-value areas; protects critical infrastructure and a large portion of the tourism sector; creates co-benefits for biodiversity and shoreline protection.\n- Probability of success and failure\n  - Success probability: 0.6–0.75, depending on design quality, maintenance, and local adherence.\n  - Failure modes: cost overruns, maintenance shortfalls, insufficient protection for rising seas, negative ecological side-effects if poorly designed (e.g., sediment trapping).\n- Monitoring metrics and triggers\n  - Metrics: reduction in flood frequency/intensity in protected zones; annual maintenance com ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: openai/gpt-5-nano
#
# Below is a 30-year, phased adaptation plan tailored to a diverse, tourism- and small-fisheries–based island nation with a 1.2 million population, facing rapid sea‑level rise, economic vulnerability, and a significant indigenous minority with sacred coastal sites at risk. Costs are expressed in USD billions; timescales are indicative. All figures are estimates subject to refinement as data arrive.
#
# Executive overview
# - Core principle: balance engineered defenses, managed retreat where necessary, diversified livelihoods, and strong protection of cultural sites through inclusive governance.
# - Funding frame: $5B immediate; up to $1B/year via bonds if markets permit; ~60% chance of modest international aid over the next decade. Treat budgets as contingent on financing conditions and aid.
# - Phasing: (1) safeguard critical assets and identities; (2) establish retreat-ready pathways and economic diversification; (3) scale up protections and governance; (4) maintain data-led updates and flexible adaptation.
#
# Assumptions (explicit)
# - Population remains near 1.2 million; internal migration within the island is feasible.
# - 40% of habitable land is at high risk of inundation or salinization within ~30 years; rate of sea-level rise is within current projections but with uncertainty.
# - Tourism and small-scale fishing remain important but face climate and ecosystem limits; diversification improves resilience.
# - Indigenous communities have distinct cultural priorities and rights; meaningful participation and consent are required for changes to sacred coastal sites.
# - Financing constraints dominate early years; aid, debt markets, and grant opportunities are uncertain and contingent on global conditions.
# - Technologies and costs will evolve; plan remains adaptable.
#
# Key uncertainties likely to affect decisions
# - Pace and geographic distribution of sea‑level rise and coastal erosion (erosion rates, subsidence, storm surge behavior).
# - Value of protected assets (properties, ports, tourism infrastructure) and cost of land acquisition for retreat.
# - Social acceptability and political feasibility of managed retreat and relocation, particularly around indigenous coastal areas.
# - Availability and terms of international aid and bond markets.
# - Effectiveness and costs of nature-based defenses versus hard infrastructure.
# - Economic response to diversification (timing, labor market fit, supply chains).
# - Legal and governance reforms needed for indigenous co-management and cultural site protection.
#
# Plan components and major decisions (with costs, benefits, and success likelihoods)
#
# Decision 1. Deploy a layered coastal defense program that combines nature-based solutions with targeted engineered protections in priority areas
# - What it includes: mangrove restoration and dune systems where feasible; living shorelines; sea walls and flood barriers in high-value zones (ports, airports, urban cores); auxiliary drainage and flood-proofing; essential climate-resilient infrastructure retrofits.
# - Estimated costs (phased)
#   - Initial package (0–5 years): about $2.5B–$3B for core defenses in the most exposed zones plus NbS; ongoing maintenance funded from bonds later.
#   - 30-year program: potential total $5B–$6B (capable of expanding if additional zones are identified).
# - Expected benefits
#   - Reduces flood/tide- and storm-related damages in high-value areas; protects critical infrastructure and a large portion of the tourism sector; creates co-benefits for biodiversity and shoreline protection.
# - Probability of success and failure
#   - Success probability: 0.6–0.75, depending on design quality, maintenance, and local adherence.
#   - Failure modes: cost overruns, maintenance shortfalls, insufficient protection for rising seas, negative ecological side-effects if poorly designed (e.g., sediment trapping).
# - Monitoring metrics and triggers
#   - Metrics: reduction in flood frequency/intensity in protected zones; annual maintenance completion rates; coastal erosion rates in protected segments; cost adherence.
#   - Triggers: if projected flooding still exceeds targeted thresholds in protected areas after 5–7 years, escalate to protective upgrades or focus more on NbS; if maintenance lag exceeds 12 months, reallocate funds.
# - Stakeholder engagement and conflict adjudication
#   - Engage: coastal communities, port operators, tourism operators, fisheries representatives, local engineers, and indigenous groups with co-design of defenses in areas of cultural importance.
#   - Adjudication: establish a Coastal Defense Governance Committee including representatives from the indigenous council, municipal authorities, and a neutral technical arbiter to resolve conflicts about siting and design choices.
# - Data needed before irreversible action
#   - High-resolution coastal hazard mapping, land ownership and asset valuation, sediment dynamics, anticipated storm surge models, and maintenance cost forecasts.
# - How to adapt with new information
#   - Use adaptive design with modular components; implement pilot segments first; revise siting as hazard maps update; adjust maintenance schedules as local capacity grows.
#
# Speculative vs evidence-based notes
# - Evidence-based: general strategy of layering NbS with engineered protections.
# - Speculative: exact siting, quantities, and maintenance costs until hazard mapping is complete.
#
# Decision 2. Implement a staged managed retreat program for the highest-risk zones, with voluntary buyouts, relocation corridors, and retention of cultural and community anchors
# - What it includes: voluntary buyouts in the most hazard-prone neighborhoods, development of relocation villages in safer inland zones, and investment in housing, job opportunities, and social services for relocated households; preservation of cultural practices near relocated sites and new cultural gathering spaces.
# - Estimated costs
#   - Early phase (0–5 years): $0.6B–$1B for planning, land acquisition options, and early relocations of the smallest clusters.
#   - Medium term (5–15 years): cumulative $4B–$6B, depending on pace and geographic scope.
#   - 30-year horizon: possible total $6B–$9B, contingent on land prices, housing costs, and buyout volumes.
# - Expected benefits
#   - Reduces exposure of people and properties to rising seas; preserves remaining habitable land; creates opportunity to design communities with resilience from the outset.
# - Probability of success and failure
#   - Success probability: 0.5–0.65 (highly contingent on voluntary participation, fair compensation, and employment alternatives).
#   - Failure modes: social resistance, perceived inequity, inadequate inland sites, cultural ties to coast, and political pushback.
# - Monitoring metrics and triggers
#   - Metrics: number of households relocated, time-to-relocation milestones, inland housing quality and affordability, employment outcomes post-relocation, social cohesion indicators.
#   - Triggers: if participation rates fall below a threshold, ramp up incentives and outreach; if inland sites show deterioration or poor livability, pause and renegotiate with communities.
# - Stakeholder engagement and conflict adjudication
#   - Engage: indigenous communities, local elected bodies, community organizations, housing authorities, employers, and NGOs.
#   - Adjudication: establish a Relocation and Cultural Continuity Council to oversee fair compensation, grievance mechanisms, and protection of sacred sites during relocation.
# - Data needed
#   - Comprehensive hazard and risk maps, land availability and suitability for relocation, housing costs and financing options, socioeconomic profiles, potential impacts on indigenous cultural practices, and revenue implications for displaced households.
# - Adaptation plan with new information
#   - Start with small pilots in low-cost areas; expand progressively with transparent benchmarks; adjust compensation schemes based on market conditions; incorporate community-led design of inland relocation spaces.
# - Speculative vs evidence-based notes
#   - Evidence-based: known need for voluntary, well-supported relocation programs in high-risk areas.
#   - Speculative: precise buyout costs and inland site viability until market studies are completed.
#
# Decision 3. Diversify and deepen the economy to reduce climate vulnerability (sustainable tourism, diversified fisheries, aquaculture, renewable energy, digital services)
# - What it includes: program of job training, incentives for private sector investment in resilient tourism products (ecotourism, cultural tourism that highlights indigenous heritage with consent), small-scale eco-friendly fisheries or aquaculture ventures, and renewable energy integration (solar/wind) to reduce energy shocks.
# - Estimated costs
#   - Initial thrust (0–5 years): $1B–$1.5B for training, seed capital, infrastructure upgrades (including digital connectivity) and targeted subsidies.
#   - Ongoing/yearly: incentives and subsidies may require $0.2B–$0.5B/year, potentially funded by bonds if market conditions allow.
# - Expected benefits
#   - Creates more resilient, higher-value jobs; reduces reliance on climate-vulnerable sectors; channels tourism into deeper cultural and environmental experiences; increases local-purchase ecosystems; improves energy resilience.
# - Probability of success and failure
#   - Success probability: 0.5–0.75 depending on demand, global tourism recovery, and effective implementation.
#   - Failure modes: demand risk in tourism (seasonality, global downturns), supply chain fragility for aquaculture, regulatory hurdles.
# - Monitoring metrics and triggers
#   - Metrics: GDP contribution from diversified sectors; tourism occupancy and diversification metrics; fishing yields; employment rates in targeted sectors; energy reliability indicators.
#   - Triggers: if diversification lag persists for 2–3 years, intensify incentives and reduce barriers; if environmental stress on new aquaculture ventures emerges, reallocate to more robust sectors.
# - Stakeholder engagement and conflict adjudication
#   - Engage: business associations, hotel/port operators, coastal communities, indigenous representatives, fisheries cooperatives, banks and microfinance institutions.
#   - Adjudication: establish an Economic Diversification Council with representation from affected communities and a rotating independent chair to mediate conflicts between stakeholders (e.g., between tourism expansion and environmental protections).
# - Data needed
#   - Market analyses for niche tourism products; current and projected tourism demand; fishing and aquaculture viability and market access; grid reliability and renewable energy costs; training capacity and wage expectations.
# - Adaptation plan with new information
#   - Use pilot programs to validate business models; scale up successful ventures; adjust incentives and regulatory environments; improve workforce training aligned with industry demand.
#
# Decision 4. Protect sacred coastal sites and establish Indigenous co-governance over cultural resources
# - What it includes: formal recognition of indigenous rights, co-management frameworks for sacred coastal sites, funding for cultural mapping, sacred site protection, language and cultural restoration programs, and mechanisms for meaningful consent in project siting.
# - Estimated costs
#   - 0–5 years: $0.4B–$0.8B for mapping, legal recognition processes, and governance structures; ongoing support for cultural programs at $0.2B–$0.4B/year in perpetuity or until needs are met.
#   - 30 years: possible total $1.5B–$3B depending on scale and ongoing commitments.
# - Expected benefits
#   - Maintains cultural integrity; reduces risk of social conflict; improves legitimacy of adaptation actions in indigenous communities; creates protected cultural tourism value where consent and stewardship are respected.
# - Probability of success and failure
#   - Success probability: 0.7–0.9 (high if genuine partnership and funding commitments are in place).
#   - Failure modes: tokenistic engagement, governance deadlock, or inadequate funding to implement protections.
# - Monitoring metrics and triggers
#   - Metrics: number of sacred sites protected, co-management agreements signed, participation rates in governance bodies, cultural program uptake, and level of community satisfaction.
#   - Triggers: if consent or engagement falters, renew outreach and adjust governance structures; if protection measures fail to prevent encroachment, escalate to legal protections and enforcement where appropriate.
# - Stakeholder engagement and conflict adjudication
#   - Engage: indigenous leadership, cultural custodians, local government, tourism developers, and conservation groups.
#   - Adjudication: establish a Cultural Heritage and Indigenous Governance Board with veto rights on projects affecting sacred sites; ensure independent mediation and due process.
# - Data needed
#   - Inventory of sacred sites, cultural practices at risk, legal frameworks for co-management, community priorities, and potential economic trade-offs for cultural protections.
# - Adaptation plan with new information
#   - Update co-management agreements as communities express new priorities; incorporate new sacred-site GIS data; adjust protection funding to reflect evolving cultural needs.
# - Speculative vs evidence-based notes
#   - Evidence-based: importance of indigenous co-management for legitimacy and effectiveness.
#   - Speculative: precise governance structures and funding levels until consultations complete.
#
# Decision 5. Invest in data, mapping, and monitoring to inform adaptive management
# - What it includes: high-resolution shoreline change mapping, coastal hazard modeling, land-use inventories, population displacement risk assessments, environmental baseline data, early warning systems, and an integrated decision-support platform.
# - Estimated costs
#   - 0–5 years: about $0.3B–$0.5B for data systems, surveys, and modeling capacity.
#   - Ongoing: $0.1B–$0.2B/year for maintenance and upgrades.
# - Expected benefits
#   - Improves accuracy of risk assessments; enables timely decisions; reduces irreversible missteps; informs all other decisions (defense, retreat, diversification, and governance).
# - Probability of success and failure
#   - Success probability: 0.8–0.9 if sustained funding and local capacity are ensured.
#   - Failure modes: data gaps, interoperability issues, underfunded data stewardship, slow uptake by policymakers.
# - Monitoring metrics and triggers
#   - Metrics: data completeness and timeliness, forecast accuracy, decision latency, system uptime.
#   - Triggers: if data quality degrades or the model predictions diverge from observed outcomes, escalate data audits and update models; if policy lags behind data, trigger rapid-response policy cycles.
# - Stakeholder engagement and conflict adjudication
#   - Engage: scientists, local universities, municipal planners, indigenous data custodians, civil society.
#   - Adjudication: create an independent Data and Ethics Advisory Panel to review data usage, privacy concerns, and consent issues for data collection.
# - Data needed
#   - Shoreline and land-use change data, hazard maps, population distribution and migration risk, cultural site geolocations with sensitivities, and economic impact data for sectors.
# - Adaptation plan with new information
#   - Data-driven updates to siting of defenses and retreat, refine economic plans, and adjust governance structures in light of new evidence.
#
# Decision 6. Strengthen governance, social cohesion, and conflict resolution mechanisms
# - What it includes: multi-stakeholder climate council, citizen juries or deliberative forums for major decisions, transparent cost-benefit analyses, and credible grievance mechanisms; public information campaigns to explain adaptation choices.
# - Estimated costs
#   - 0–5 years: $0.2B–$0.4B to establish structures and first-year operating costs; ongoing $0.05B–$0.2B/year.
# - Expected benefits
#   - Reduces contestation, increases legitimacy and trust, improves policy acceptance, improves resilience outcomes through inclusive decision-making.
# - Probability of success and failure
#   - Success probability: 0.7–0.85 with strong, ongoing participation and clear mandates.
#   - Failure modes: capture by elites, decision paralysis, or shallow participation that fails to alter outcomes.
# - Monitoring metrics and triggers
#   - Metrics: number of decisions with broad stakeholder consent, public trust indices, incident rates of social unrest, and resolution times for disputes.
#   - Triggers: if cooperation declines, intensify outreach and capacity-building; if disputes escalate, trigger external mediation and review processes.
# - Stakeholder engagement and conflict adjudication
#   - Engage: community groups, indigenous representatives, business associations, NGOs, religious and cultural leaders, and youth groups.
#   - Adjudication: establish an independent Climate Governance Tribunal or similar body to resolve conflicts with legitimacy and due process.
# - Data needed
#   - Social indicators, asset ownership data, institutional capacity assessments, and historical grievance records.
# - Adaptation plan with new information
#   - Periodic governance reviews; incorporate lessons from other island states; adjust representation and decision rules for equity and effectiveness.
#
# Decision 7. Financing and fiscal planning to align with phased actions
# - What it includes: optimize use of $5B immediate funds; plan for up to $1B/year bond issuance (subject to market conditions); secure and allocate international aid when available; build a reserve fund for disasters.
# - Estimated costs
#   - Immediate allocation: distribute the $5B across decisions 1–4 (defense, retreat planning, diversification, cultural protections), plus a contingency reserve.
#   - Bond planning: outline a 10–15-year debt plan at modest yields to fund decisions 2–3 at scale; prepare for interest costs and debt service.
#   - International aid: expected (~60% probability of modest aid) to supplement specific programs; plan for worst-case and best-case aid scenarios.
# - Expected benefits
#   - Enables timely implementation; spreads costs over time; creates financial resilience to adapt to changing conditions.
# - Probability of success/failure
#   - Financing success depends on market conditions, macro stability, and aid availability; plan for multiple scenarios with contingency financing.
# - Monitoring metrics and triggers
#   - Metrics: debt service coverage ratio, budget execution rates, grant/aid disbursement timelines, reserve fund levels.
#   - Triggers: if bond markets tighten or aid delays occur, prioritize cheapest, fastest-to-implement actions; increase reliance on NbS and targeted protections rather than large-scale new infrastructure.
# - Stakeholder engagement and conflict adjudication
#   - Engage: financial authorities, planning ministries, local governments, and the public to ensure transparency about costs and trade-offs.
#   - Adjudication: establish a fiscal oversight board to oversee debt issuance and ensure intergenerational equity.
# - Data needed
#   - Macro-economic projections, interest rate scenarios, debt servicing capacity, and risk-adjusted project valuations.
#
# Decision 8. Data governance and continuous learning framework
# - What it includes: formal process to update the plan as new hazard data, tech, or social inputs arrive; scenario planning, and annual or biennial reviews.
# - Estimated costs
#   - Minor ongoing costs: $0.1B–$0.2B/year for convening, data integration, and plan updates.
# - Expected benefits
#   - Maintains plan relevance; reduces lock-in risk; improves outcomes through iterative improvement.
# - Probability of success and failure
#   - Success probability: high with political will and capacity to act on new information.
#   - Failure modes: bureaucratic inertia or slow decision-making.
# - Monitoring metrics and triggers
#   - Metrics: frequency of plan updates, time from data arrival to policy adjustment, stakeholder satisfaction with the adaptation process.
#   - Triggers: major new climate or economic data should trigger a formal plan revision cycle.
#
# Implementation sequencing and budgets (illustrative)
# - Year 0–5 (initial rollout with $5B)
#   - Coastal defense pilot (Decision 1): ~$1.5B
#   - Managed retreat planning and early relocations (Decision 2): ~$0.6–1.0B
#   - Economic diversification startup (Decision 3): ~$0.8–1.0B
#   - Cultural protection and co-governance setup (Decision 4): ~$0.4–0.8B
#   - Data and monitoring setup (Decision 5): ~$0.3–0.5B
#   - Governance and social cohesion (Decision 6): ~$0.2–0.4B
#   - Financing planning and reserves (Decision 7): integrated into overall budgeting
# - Year 6–15 (bond-funded expansion, contingent on markets)
#   - Scale defense and NbS (Decision 1): additional ~$1.5–2B
#   - Expand retreat programs (Decision 2): ~$2–4B
#   - Deepen diversification (Decision 3): ~$1–2B
#   - Cultural protection and governance (Decision 4): ~$0.5–1B
#   - Data system upgrades (Decision 5): ~$0.2–0.5B
#   - Governance and social cohesion (Decision 6): ~$0.2–0.4B
# - Year 15–30 (steady-state adaptive management)
#   - Ongoing maintenance, monitoring, and upgrades; phased retreats or protections as necessary; continued diversification investment.
#
# Monitoring, triggers, and contingency management
# - Core metrics to track across decisions
#   - Physical: coastline protection rates, flood/erosion reductions, relocation progress, inland housing quality, protected sacred sites, habitat and biosphere status.
#   - Economic: GDP contribution by diversified sectors, tourism mix, fishing yields, unemployment rates, and income resilience.
#   - Social: trust and social cohesion indicators, stakeholder participation, incident rates, grievance resolution times.
#   - Governance: plan update frequency, decision transparency, funding disbursement timelines, debt service status.
# - Trigger-based contingencies
#   - If sea-level rise accelerates beyond plan projections, re-prioritize protection in high-value zones and accelerate NbS.
#   - If social consensus for retreat is weak, slow the pace of relocations, increase incentives, and expand inland development with enhanced safeguards for cultural sites.
#   - If aid arrives late or is smaller than expected, scale back high-cost projects and prioritize low-cost, high-impact NbS plus governance strengthening.
#   - If markets for bonds are unfavorable, defer non-critical investments and intensify data-driven prioritization and cost-sharing with communities.
#
# What data to request before irreversible actions (critical inputs)
# - High-resolution hazard and shoreline-change data, including subsidence and storm surge models; updated sea-level rise projections under multiple scenarios.
# - Comprehensive asset inventory and land values in at-risk zones, including critical infrastructure, housing, and cultural sites.
# - Feasibility studies for inland relocation sites, including land availability, infrastructure needs, and social viability.
# - Cultural site inventories with sacred-site coordinates, usage patterns, and community protections; mapping for co-governance needs and consent requirements.
# - Economic baselines and future projections for tourism (including seasonality, climate sensitivity), fisheries (stocks, quotas), and potential diversification trajectories.
# - Indigenous governance structures, consent processes, and preferred models for co-management and data sharing.
# - Financing projections under multiple macroeconomic scenarios, including bond pricing, debt-service capacity, and aid conditionalities.
# - Public sentiment and social cohesion baselines to measure progress and identify risks of conflict.
#
# Data, monitoring, and updating the plan (adaptive management)
# - Establish an annual Climate Adaptation Review: assesses new data, revises hazard maps, and adjusts priorities and budgets.
# - Conduct a decadal strategic review (with interim mid-term reviews at years 10 and 20) to re-balance defense, retreat, and diversification investments given economic and climate changes.
# - Maintain a living, transparent public dashboard showing funding allocations, project progress, risk indicators, and outcomes.
# - Ensure decision pathways include explicit consent and accountability mechanisms for indigenous groups, local communities, and civil society.
#
# Assumptions and uncertainties (summary)
# - Assumptions used for cost ranges and sequencing are intentionally conservative and subject to refinement as data arrive.
# - The most impactful uncertainties:
#   - Actual pace and geographic pattern of sea-level rise and local subsidence.
#   - Economic costs of retreat and the feasibility of inland relocation sites.
#   - Effectiveness and costs of NbS versus hard defenses in the local context.
#   - Public acceptance of relocation and co-management arrangements, particularly among indigenous communities.
#   - Availability and terms of international aid and debt-financing options.
# - Evidentiary basis versus speculation:
#   - Evidence-based: general principles of combining NbS with engineered protections; importance of co-management and inclusive governance; necessity of data-informed decisions.
#   - Speculative: exact cost figures, siting of specific projects, and precise timing of large-scale relocations until hazard and economic data are refined.
#
# Ethical and governance notes
# - This plan emphasizes consent, participation, and rights of the indigenous minority. No forced relocations should occur without clear, free, prior, and informed consent, robust compensation, meaningful alternatives, and culturally sensitive planning.
# - Establish transparent decision-making processes, with independent oversight and clear grievance mechanisms to adjudicate conflicts across economic, safety, and cultural priorities.
# - Ensure that adaptation benefits are equitably distributed and that cultural heritage protections are prioritized alongside economic resilience.
#
# Specifically markable speculative elements
# - Exact cost allocations and procurement timelines are speculative and will adjust with data on hazard extent, land values, and market conditions.
# - Precise siting for retreat corridors and defense installations will be determined by updated hazard models, land availability, and community consultations.
# - The pace and scope of international aid, bond-market access, and demand for diversified livelihoods depend on global financial conditions and political will.
#
# Bottom line
# - A balanced, adaptive approach—protecting critical assets, offering managed retreat where necessary, diversifying the economy, and protecting sacred sites through Indigenous co-governance—offers the best prospect for maintaining safety, livelihoods, and cultural integrity over 30 years.
# - The plan relies on robust data, inclusive governance, and staged financing with clear triggers to adapt to new information. Regular updates and transparent stakeholder engagement are essential to minimize conflict and maximize resilience.
# Competitor: anthropic/claude-sonnet-4.5
#
# # 30-Year Climate Adaptation Strategy for Island Nation
#
# ## Key Assumptions & Uncertainties
#
# ### Assumptions:
# - Current population: 1.2M (stable growth ~1% annually)
# - 40% land loss = ~300,000-400,000 people require relocation
# - Tourism contributes 30-40% GDP (evidence-based: typical small island developing states)
# - Indigenous minority represents 15-25% of population
# - Sea-level rise accelerates but remains within IPCC RCP 4.5-8.5 projections (speculative timing)
# - Democratic governance with rule of law maintained
#
# ### Critical Uncertainties (High Impact on Strategy):
# 1. **Rate of sea-level rise acceleration** (affects timeline for all decisions)
# 2. **Tourism market resilience** (COVID-19 showed 60-90% collapse possible)
# 3. **Political stability during mass relocation** (historical precedent: 30-40% chance of governance crisis)
# 4. **International aid materialization** (60% probability, but amount unknown)
# 5. **Bond market access** (depends on credit rating through crisis)
#
# ---
#
# ## Phase 1: Foundation & Assessment (Years 0-5)
# **Budget allocation: $2.5B initial + $1B bonds/year**
#
# ### 1A. Emergency Data Acquisition & Planning ($200M)
#
# **Actions:**
# - High-resolution LIDAR mapping of entire coastline
# - Participatory vulnerability mapping with indigenous communities
# - Economic dependency analysis by geography
# - Cultural site documentation and 3D preservation
# - Subsidence monitoring network
# - Storm surge modeling for 1-in-100 year events
#
# **Rationale for data needs:**
# Current global sea-level models have ±15cm uncertainty by 2050; local subsidence could add 10-30cm. Without ground-truth data, we risk either:
# - Over-investing in defenses for land that will subside anyway (waste ~$500M-1B)
# - Under-protecting economically critical areas (loss of $2-3B in assets)
#
# **Metrics:**
# - Complete baseline mapping: 18 months
# - Community consultation: 80% household participation
# - Cultural inventory: 100% documented sacred sites with indigenous verification
#
# **Probability assessment:**
# - Success (actionable data): 85% (evidence-based: standard technical work)
# - Partial failure (delays): 15% (political obstruction, technical issues)
#
# ---
#
# ### 1B. Stakeholder Governance Architecture ($50M)
#
# **Structure:**
# Create three parallel decision-making bodies:
#
# 1. **Technical Adaptation Council** (engineers, climate scientists, economists)
#    - Makes evidence-based recommendations
#    - No veto power, pure advisory
#
# 2. **Cultural Heritage Commission** (indigenous elders, historians, religious leaders)
#    - Veto power over decisions affecting documented sacred sites
#    - Must propose alternatives within 90 days of veto
#    - Funded to hire own technical experts
#
# 3. **Citizens' Assembly** (300 randomly selected residents, rotating yearly)
#    - Reviews major relocation/defense decisions
#    - Binding vote on plans >$500M
#    - Ensures democratic legitimacy
#
# **Conflict adjudication protocol:**
# - Tier 1: Facilitated negotiation (90 days)
# - Tier 2: Independent mediation panel (60 days)
# - Tier 3: Supreme Court review on constitutional grounds only
# - **Deadlock trigger**: If unresolved after 240 days, national referendum (used maximum twice per decade to prevent decision paralysis)
#
# **Probability of governance success:**
# - Maintains legitimacy through crisis: 65%
# - Partial breakdown (delays, protests): 25%
# - Complete failure (authoritarian drift or collapse): 10%
#
# *Justification*: Historical analysis of managed retreat (Isle de Jean Charles, Louisiana; Kiribati) shows governance failure rate of 30-40% without explicit indigenous co-management.
#
# ---
#
# ### 1C. Strategic Defense of Critical Infrastructure (Years 1-5: $2B)
#
# **Prioritize protection for:**
# 1. Primary airport (economic lifeline): $400M seawall + drainage
# 2. Main commercial port: $600M combined defenses
# 3. Capital city core (government, hospitals): $800M levee system
# 4. Water treatment plants: $200M elevation/relocation
#
# **NOT protected at this stage:**
# - Dispersed coastal villages (await relocation plan)
# - Secondary beach areas (tourism transition underway)
# - Agricultural lowlands (begin managed retreat)
#
# **Success probability:**
# - Infrastructure remains functional: 75% (evidence: Dutch/Singaporean engineering standards)
# - Partial failure (2-3 breaches by year 10): 20%
# - Catastrophic failure: 5%
#
# **Failure modes:**
# - Underestimated storm surge intensity
# - Coral reef degradation removes natural wave attenuation
# - Inadequate maintenance funding
#
# **Metrics & triggers:**
# - Annual stress tests
# - Settlement monitoring (<5mm/year acceptable)
# - **Contingency trigger**: If >2 infrastructure failures occur before Year 5, pause construction, reassess entire defense strategy (cost: $300M in delays)
#
# ---
#
# ## Phase 2: Economic Transition & Managed Retreat (Years 3-15)
# **Budget: $5B (remaining initial + bonds + projected aid $600M/year × 60% probability)**
#
# ### 2A. Tourism Economic Model Shift ($1.5B)
#
# **From:** Mass beach tourism → **To:** Climate resilience showcase + eco-cultural tourism
#
# **Components:**
# 1. **Living laboratory**: Partner with universities for climate research stations ($200M)
#    - Revenue: Attract conferences, research grants ($50M/year by year 10)
#
# 2. **Heritage cultural center**: Relocate threatened sacred sites' interpretive functions inland ($300M)
#    - Co-designed with indigenous communities
#    - Revenue: Cultural tourism premium pricing ($80M/year)
#
# 3. **Blue economy investment**: Deep-water aquaculture, ocean thermal energy ($800M)
#    - Probability of commercial viability by Year 15: 55%
#    - Downside risk: Loss of $600M if markets don't develop
#
# 4. **Digital services sector**: Tax incentives, fiber infrastructure ($200M)
#    - Leverage time zone, educated English-speaking population
#
# **Expected ROI:**
# - Base case (65% probability): $200M/year additional GDP by Year 15
# - Optimistic (20%): $400M/year
# - Pessimistic (15%): $50M/year (tourism collapse, tech doesn't scale)
#
# **Metrics:**
# - Tourism receipts per visitor (should increase even as volumes moderate)
# - New economy jobs created (target: 15,000 by Year 10)
# - **Decision gate at Year 8**: If new revenue <$80M/year, reallocate $500M from blue economy to Plan B (remittance economy, skilled labor export)
#
# ---
#
# ### 2B. Phased Managed Retreat ($2.5B)
#
# **Principle**: No forced relocation before Year 5; all moves voluntary until Year 10, then phased mandatory for highest-risk zones.
#
# **Implementation:**
#
# **Years 3-7 (Voluntary Phase):**
# - Purchase coastal properties at 125% pre-crisis market value + relocation stipend ($50k/household)
# - Priority: Areas with <15 years protection horizon
# - Develop 5 new inland settlements with full infrastructure
# - **Target**: Relocate 80,000 people (25% of affected population)
#
# **Predicted uptake**: 60% ± 15%
# - Justification: Buyout programs typically achieve 50-70% voluntary participation (evidence: US floodplain buyouts, Australian cyclone zones)
# - Lower participation likely in areas with indigenous sacred sites
#
# **Years 8-15 (Hybrid Phase):**
# - Mandatory building moratorium in highest-risk zones
# - Continued buyouts at 115% value
# - Rent-to-own programs in new settlements
# - **Target**: Additional 120,000 people relocated
#
# **Cost per person relocated**: ~$20,000 average (range: $8k-35k depending on property values)
#
# **Cultural site protection:**
# - Physical relocation of moveable artifacts/structures: $200M
# - Sacred site protocol: If site cannot be moved and area becomes uninhabitable:
#   - Maintain access via elevated pathways/boats as long as physically possible
#   - Ceremonial compensation process co-designed with Cultural Heritage Commission
#   - Establish inland memorial sites with blessing of traditional owners
#   - **Non-negotiable**: Indigenous communities decide which sites qualify for maximum protection effort (may exceed $50M per site)
#
# **Social cohesion metrics:**
# - Community satisfaction surveys (target: >60% approve of process)
# - Protest intensity (trigger for pause if sustained civil disobedience >5,000 people)
# - Indigenous community approval rating (minimum 50% support required)
# - **Major contingency**: If approval falls below thresholds, 12-month pause for plan revision
#
# **Probability assessment:**
# - Orderly retreat achieving 90%+ relocation by Year 15: 50%
# - Delayed/partial (70-85% relocated): 35%
# - Crisis scenario (major unrest, <65% relocated): 15%
#
# ---
#
# ### 2C. Fishing Sector Transformation ($500M)
#
# **Reality**: Traditional near-shore fisheries will be disrupted by:
# - Sea temperature changes (altering fish populations)
# - Coral bleaching (habitat loss)
# - Coastal infrastructure changes
#
# **Strategy:**
# 1. Upgrade to deeper-water capable vessels: $200M (subsidized loans)
# 2. Aquaculture training and startup grants: $150M
# 3. Fisheries monitoring/management tech: $50M
# 4. Safety net fund for transition: $100M (5-year income support)
#
# **Engagement**:
# - Co-design with fishing cooperatives
# - Guarantee: No fisher worse off than baseline for first 5 years
# - Job retraining if leaving sector
#
# **Metrics:**
# - Fishing income maintained >80% of baseline
# - Stock sustainability scores
# - **Trigger**: If >40% of fishers reject transition by Year 5, shift toward pure income support + alternative jobs
#
# ---
#
# ## Phase 3: Long-term Resilience (Years 15-30)
# **Budget: Remaining bonds + international aid + economic returns from Phase 2**
#
# ### 3A. Adaptive Infrastructure ($3B)
#
# **Speculative component**: Technology and climate trajectory will evolve significantly by Year 15. Strategy must remain flexible.
#
# **Pre-committed decisions:**
# - Retreat boundaries finalized by Year 10 (no further inland development restrictions)
# - Critical infrastructure hardened to Year 2070 projections + 30% safety margin
#
# **Adaptive decisions (await better data):**
# - Extent of nature-based solutions (mangrove restoration, coral gardening): Efficacy uncertain, $500M provisional
# - Floating/amphibious architecture: Unproven at scale, but preserve $800M option value
# - Regional migration agreements: Negotiate safety valve for worst-case population overflow
#
# ### 3B. Plan Update Protocol
#
# **Mandatory comprehensive reviews:**
# - Year 5: Adjust timeline based on observed sea-level rise rate
# - Year 10: Major economic strategy pivot if needed
# - Year 15, 20, 25: Full reassessment
#
# **Annual monitoring:**
# - Sea-level benchmarks (±5cm from projections triggers review)
# - Economic indicators (GDP, employment, inequality)
# - Social cohesion (survey data, election results, protest activity)
# - Cultural heritage preservation status
#
# **Trigger for fundamental strategy change:**
# - Sea-level rise >15cm ahead of central projection: Accelerate retreat, reduce defense spending
# - Economic collapse (GDP down >20%): Prioritize immediate welfare over long-term projects
# - Governance failure: International administration option
# - Major breakthrough (fusion energy, carbon removal): Consider holding more land
#
# ---
#
# ## Financial Structure
#
# **Initial 5-year budget ($7.5B total):**
# - Data & Planning: $200M (3%)
# - Governance: $50M (0.7%)
# - Critical infrastructure defense: $2B (27%)
# - Economic transition seed: $1B (13%)
# - Managed retreat start: $1.5B (20%)
# - Reserve fund: $750M (10%)
# - Ongoing government operations + social services: $2B (27%)
#
# **Risk management:**
# - Reserve fund for emergencies (natural disasters, economic shocks)
# - Bond issuance conditional on maintaining investment-grade rating
# - If aid fails to materialize: Reduce voluntary buyout prices to 100% market value, slower retreat timeline
# - Debt sustainability: Cap total borrowing at 70% GDP
#
# ---
#
# ## Evidence vs. Speculation
#
# **Evidence-based components:**
# - Engineering costs and success rates (extensive precedent)
# - Basic climate projections (IPCC consensus)
# - Governance failure modes (historical analysis)
# - Buyout program participation rates (empirical studies)
#
# **Speculative components:**
# - Exact timing of sea-level impacts (±5-10 year uncertainty)
# - New economic model success (blue economy unproven)
# - International aid amounts and consistency
# - Social cohesion maintenance through mass relocation (limited precedent at this scale)
# - Technology availability after Year 15
#
# **Most uncertain/highest impact:**
# The interaction between economic stress and social cohesion during Years 8-15. Historical precedent (post-disaster relocations, austerity programs) suggests 20-35% chance of political instability severe enough to derail managed retreat. This is the **critical vulnerability** requiring maximum monitoring and adaptive capacity.
#
# ---
#
# ## Ethical Framework for Impossible Choices
#
# **When economic, safety, and cultural priorities conflict irreconcilably:**
#
# 1. **Immediate safety > all**: If lives threatened, temporary overrides permitted (with compensation)
#
# 2. **Cultural survival**: Indigenous communities get veto over sacred sites + right to equivalent alternatives
#    - Exception: Cannot veto safety measures for others' lives
#    - Can accept financial compensation if community decides (their choice, not imposed)
#
# 3. **Economic efficiency secondary**: Will accept 10-15% cost premium to preserve social cohesion and cultural heritage
#
# 4. **Transparency paramount**: All decisions published with full reasoning, minority opinions recorded
#
# **Example hard case:**
# Major port generates 8% of GDP but expansion would destroy sacred burial ground. Indigenous community splits 60-40 against.
# - **Process**:
#   - Offer alternative port location (cost +$200M)
#   - If truly no alternative: Citizens' Assembly decides
#   - Winning margin must exceed 60% for irreversible action
#   - Losing community receives permanent trust fund ($100M) for cultural preservation
#   - Decision recorded as "tragic choice" acknowledging harm
#
# ---
#
# ## Summary: Theory of Success
#
# **This plan succeeds if:**
# 1. Aggressive early action buys time (Years 0-5)
# 2. Economic transition begins showing results by Year 8 (provides hope + funding)
# 3. Voluntary retreat achieves critical mass (reduces coercion needed later)
# 4. Governance maintains legitimacy through transparency and power-sharing
# 5. International community provides modest but sustained support
#
# **Success probability: 45-55%** (speculative estimate)
#
# **Most likely failure mode**: Economic transition underperforms → bond markets close → forced to choose between inadequate defense or coerced relocation without compensation → political instability → state failure
#
# **Mitigation**: Maintain reserve fund, preserve international migration options as safety valve, front-load most expensive infrastructure to early years when funds available.
#
# This is not a plan that "solves" the crisis—that's impossible with these constraints. It's a plan to **preserve community identity and democratic governance through managed decline**, avoiding the worst outcomes while acknowledging some painful losses are unavoidable.
# Competitor: google/gemini-2.5-flash
#
# ## 30-Year Adaptation Strategy for the Island Nation: Navigating the Tides of Change (Speculative elements marked with *)
#
# **Assumptions:**
#
# *   **Political Stability:** The government maintains sufficient stability to implement long-term strategies.
# *   **Competent Governance:** There is a baseline level of governmental capacity to execute complex projects.
# *   **Global Warming Trajectory:** The 40% loss of habitable land within 30 years is based on current climate models and trends, acknowledging potential for both faster and slower rates.
# *   **Tourism Demand:** While vulnerable, tourism will remain a viable, if transformed, economic sector for at least part of the 30-year horizon.
# *   **International Cooperation:** Acknowledgment that international aid, even if modest, is a critical component of the financial strategy.
# *   **Social Cohesion:** Despite polarization, a shared sense of urgency regarding national survival can be leveraged for unity.
# *   **Indigenous Resilience:** The indigenous population possesses strong cultural attachment and a willingness to participate in solutions, not just protest.
#
# **Key Uncertainties:**
#
# *   **Pace of Sea-Level Rise:** While 40% in 30 years is projected, the exact rate and regional variations are highly uncertain, impacting the timeline for managed retreat.
# *   **Effectiveness of Engineered Defenses:** The long-term efficacy and maintenance costs of various hard and soft defenses against accelerating sea-level rise are subject to uncertainty.
# *   **Global Market Appetite for Bonds:** Geopolitical events and global economic downturns could significantly impact the ability to raise $1 billion annually.
# *   **Level and Consistency of International Aid:** "Modest" is vague. The timing, conditions, and amount of aid are highly unpredictable.
# *   **Social Acceptance of Managed Retreat:** The willingness of affected populations to relocate, even with incentives, is a major unknown.
# *   **Economic Diversification Success:** The speed and scale at which new economic sectors can be developed and mature.
# *   **Technological Breakthroughs:** Unexpected advancements in climate engineering, sustainable energy, or resilient infrastructure could alter the cost-benefit analysis.
#
# ---
#
# ### Overarching Strategy & Guiding Principles:
#
# Our strategy adopts a **"Defend, Adapt, Diversify, and Unify"** approach, prioritizing rapid, decisive action while fostering long-term resilience. It acknowledges that a full "save-all-land" strategy is financially and physically impossible, necessitating difficult choices.
#
# **Guiding Principles:**
#
# 1.  **Safety First:** Prioritize the safety and well-being of all citizens.
# 2.  **Equity and Justice:** Ensure no community is left behind, paying particular attention to vulnerable populations and indigenous rights.
# 3.  **Cultural Preservation:** Protect and integrate indigenous knowledge and sacred sites into adaptation plans.
# 4.  **Economic Resilience:** Transition towards a diversified, knowledge-based economy less vulnerable to climate shocks.
# 5.  **Data-Driven Decisions:** Continuously monitor, adapt, and refine the plan based on new information.
# 6.  **Transparency and Participation:** Foster trust and shared ownership through open communication and broad stakeholder engagement.
#
# ---
#
# ### Phase 1: Immediate Action & Planning (Years 1-5)
#
# **Financial Allocation:**
#
# *   **Initial $5 Billion:** Allocated as follows:
#     *   **$1.5 Billion:** Immediate Engineered Defenses & Early Warning Systems (Critical Infrastructure Protection)
#     *   **$1 Billion:** Managed Retreat Pilot Programs & Resettlement Infrastructure Acquisition
#     *   **$1 Billion:** Economic Diversification Seed Fund & Workforce Training
#     *   **$1 Billion:** Social Cohesion & Cultural Preservation Programs (including indigenous land mapping)
#     *   **$0.5 Billion:** Research, Monitoring, & Governance (Data collection, modeling, institutional strengthening)
# *   **Annual $1 Billion Bonds & Modest International Aid (if received):** Primarily for scaling up Phase 1 initiatives and preparing for Phase 2.
#
# **A. ENGINEERED DEFENSES: Targeted Protection of Critical Assets**
#
# *   **Decision:** Invest in hard and soft defenses around critical infrastructure (hospitals, government buildings, power plants, key transportation hubs, **select high-value tourism zones**) and *limited, densely populated urban areas* with high economic output. These are temporary measures to buy time.
# *   **(1) Costs/Benefits/Probabilities:**
#     *   **Costs:** $1.5 billion (initial) + $200-$300 million/year for maintenance (bond funds).
#     *   **Benefits:** Protects critical services, maintains some economic activity, provides psychological security, buys time for managed retreat.
#     *   **Probability of Success (Short-term, 5-10 years): High (80%)** for preventing catastrophic failure at protected sites.
#     *   **Probability of Failure (Long-term, >20 years): High (70%)** without significant upgrades and against accelerating SLR; these are not permanent solutions for all areas. Justification: Hard defenses eventually fail or are overtopped; soft defenses require constant replenishment.
# *   **(2) Metrics & Triggers:**
#     *   **Metrics:** Sea-level rise (local tide gauges, satellite data), wave height/storm surge frequency, infrastructure damage reports, cost of repairs.
#     *   **Triggers:** If maintenance costs for engineered defenses exceed initial projections by >20% for two consecutive years, or if protected areas experience significant inundation despite defenses, this triggers a re-evaluation of defense strategies and faster managed retreat in those areas.
# *   **(3) Stakeholder Engagement & Conflict Resolution:** Engineering firms, local community leaders in protected zones, economic sector representatives. Conflicts will arise over which areas are *not* protected. Criteria for protection will be transparent: economic value, population density, critical national function. Open forums, cost-benefit analyses presented clearly. Cultural sites will generally *not* be protected by hard engineering in isolation, unless also critical infrastructure.
# ...
# | **Data Needed** | • Real‑time tide‑gauge network upgrade (cost $12 M). |
# | **Adaptive Loop** | If closure time > 10 min in two successive storms, allocate $30 M for automation upgrade. |
# | **E / S** | E (performance standards based on Dutch and Caribbean best‑practice). |
#
# ---
#
# ### 4.6 Decision 6 – Voluntary Managed‑Retreat Pilot (2 km², ≈ 8 000 people)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $310 M (land purchase, new housing, infrastructure, compensation). |
# | **Benefit** | Demonstrates feasible “exit‑option” for 0.7 % of total population; avoids future $1.2 bn damages on the relocated area (if SLR continues). |
# | **Success Probability** | **Success** 0.65 – depends on achieving **FPIC** and delivering compensation > 115 % of market value.<br>**Failure** 0.35 – could stall due to community dissent or cost overruns. |
# | **Metrics** | • % of affected households signing FPIC (target ≥ 80 %).<br>• Post‑relocation satisfaction index (≥ 70 %). |
# | **Stakeholder Process** | • Dedicated “Retreat Mediation Panel” (legal experts, Indigenous leaders, civil‑society NGOs).<br>• Independent third‑party audit of compensation packages. |
# | **Data Needed** | • Precise elevation maps of pilot area (sub‑meter).<br>• Social‑impact baseline survey (household income, education). |
# | **Adaptive Loop** | If FPIC threshold not met after 18 mo, pause and redesign incentive package (e.g., add community‑owned renewable‑energy micro‑grid). |
# | **E / S** | S (social acceptance estimated from small‑scale studies; financial assumptions contingent on market data). |
#
# ---
#
# ### 4.7 Decision 7 – Full‑Scale Managed‑Retreat Program (≈ 150 000 people)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $2.8 bn (land acquisition, new districts, infrastructure, compensation). |
# | **Benefit** | Avoids an estimated $5.9 bn in future flood & adaptation losses (life‑safety value + economic). |
# | **Success Probability** | **Success** 0.55 – high uncertainty in scaling social consent and financing.<br>**Failure** 0.45 – could result in “partial” retreat, leaving high‑risk pockets. |
# | **Metrics** | • Annual relocation rate (target ≥ 12 000 people/yr after Year 6).<br>• Compliance with **FPIC** for each community (≥ 85 %). |
# | **Stakeholder Process** | • National “Retreat‑Negotiation Forum” (government, Indigenous councils, private developers).<br>• Transparent “benefit‑sharing fund” financed by a tourism levy (2 % of ticket sales). |
# | **Data Needed** | • Updated SLR maps for 2035, 2050, 2070 (to delineate “no‑go” zones).<br>• Comprehensive household asset registers. |
# | **Adaptive Loop** | Review every 3 y; if relocation rate < 50 % of target, shift funds to “in‑situ adaptation” (e.g., elevated houses) for those areas. |
# | **E / S** | S (financial and social scaling risk). |
#
# ---
#
# ### 4.8 Decision 8 – Economic Transition Fund (ETF)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $420 M (re‑skilling, seed‑capital for green‑tourism, renewable‑energy pilot projects). |
# | **Benefit** | Diversifies GDP: + 3 % annual growth in non‑tourism sectors; creates 12 000 new jobs (reducing tourism‑sector vulnerability). |
# | **Success Probability** | 0.72 – based on similar “just‑transition” programmes in Small Island Developing States (SIDS). |
# | **Metrics** | • Number of participants completing certified training (target ≥ 10 000).<br>• Share of GDP from renewable‑energy/eco‑tourism (target ≥ 15 % by Year 20). |
# | **Stakeholder Process** | • Co‑design with labor unions, Indigenous women’s groups, private sector (tourism operators).<br>• Independent advisory board to avoid capture. |
# | **Data Needed** | • Labor‑market skill gaps analysis.<br>• Market feasibility study for renewable‑energy export (e.g., solar‑to‑hydrogen). |
# | **Adaptive Loop** | Quarterly monitoring; re‑allocate up to 15 % of unused ETF budget toward “digital‑nomad” incentives if job creation lags. |
# | **E / S** | E (economic modeling from World Bank’s “SIDS transition” reports). |
#
# ---
#
# ### 4.9 Decision 9 – Protection & Legal Safeguarding of Sacred Coastal Sites
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $95 M (land purchase/easement, archaeological documentation, offshore buffer zones). |
# | **Benefit** | Guarantees cultural continuity; avoids irreversible loss valued at $2 bn in intangible cultural heritage (UNESCO valuation method). |
# | **Success Probability** | 0.88 – if early FPIC and legal registration are done; risk of political reversal (12 %). |
# | **Metrics** | • Number of sites under legal protection (target = 100 % of identified sites).<br>• Annual patrols preventing illegal encroachment (≥ 95 % compliance). |
# | **Stakeholder Process** | • Indigenous Cultural Heritage Committee (ICHC) leads site identification.<br>• Government‑run “Cultural Impact Fund” pays for community‑led stewardship. |
# | **Data Needed** | • High‑resolution GIS of all cultural sites (including oral‑history locations). |
# | **Adaptive Loop** | If any protected site is damaged (detected by satellite or community report), trigger emergency response fund ($5 M) and revise buffer zones. |
# | **E / S** | E (costs based on land‑acquisition prices; benefit valuation from UNESCO). |
#
# ---
#
# ## 5.  Financing Schedule & Contingency Logic
#
# | Year | Core Expenditure | Funding Source | Contingency Trigger |
# |------|----------------|----------------|--------------------|
# | **0‑5** | Mapping, Pilot mangroves, CAC/CRT set‑up, initial data collection | $5 bn cash (≈ 70 % of initial fund) | If **U2** (bond markets) deteriorates > 2 % yield, postpone Phase 2 until market improves. |
# | **5‑10** | CPZ seawalls, flood‑gate upgrades, voluntary retreat pilot | $1 bn/year bonds (expected) + $0.3 bn aid (if secured) | If **U1** shows SLR > 0.8 m by 2035, accelerate seawall heightening (add $150 M). |
# | **10‑15** | Managed‑retreat pilot scaling, nature‑based expansion, ETF launch | Same as above; start “climate‑bond” issuance (green‑label) | If **U3** (aid) does not materialise, raise climate‑bond volume by 30 % and re‑allocate a portion to retreat. |
# | **15‑20** | Full‑scale retreat, large‑scale cultural‑site protection | Bonds + revenue from tourism levy (2 % of tickets) + aid (if any) | If relocation rate < 50 % of target, shift 15 % of retreat budget to “elevated housing” in place (short‑term safety). |
# | **20‑30** | Maintenance of CPZs, final retreat corridors, long‑term monitoring | Bonds (re‑financed at lower rates), modest aid, small “maintenance levy” (0.3 % of tourism receipts) | If **U4** (tourism demand) drops > 30 %, re‑prioritise funds toward renewable‑energy export projects to offset revenue loss. |
#
# *All “contingency triggers” are defined as **hard thresholds** (e.g., SLR > 0.8 m) that automatically launch a pre‑approved “contingency fund” (5 % of the total budget, i.e., $250 M) to cover redesign or acceleration.*
#
# ---
#
# ## 6.  Stakeholder‑Engagement Framework (how conflicts are adjudicated)
#
# 1. **Institutional Layer – Climate‑Adaptation Council (CAC)**
#    *Mandate:* Review all major adaptation projects, ensure FPIC, balance cost‑benefit across sectors.
#    *Decision rule:* Qualified majority (≥ 66 %) of members; if no consensus, an independent **Arbitration Panel** (3 external experts) makes the final call.
#
# 2. **Community‑Level Layer – Village‑Level Advisory Boards (VLABs)**
#    *Composition:* elected local leaders, Indigenous elders, women’s representatives, youth delegate.
#    *Function:* Provide ground‑truth data, voice concerns early, co‑design local mitigation (e.g., mangrove planting).
#
# 3. **Economic‑Sector Layer – Tourism‑Industry Forum (TIF)**
#    *Participants:* hotel chains, local tour operators, Ministry of Tourism, NGOs.
#    *Role:* Develop “tourism‑resilience levy”, propose alternative “eco‑tourism” packages, monitor revenue metrics.
#
# 4. **Cultural‑Heritage Layer – Indigenous Cultural Heritage Committee (ICHC)**
#    *Authority:* Must approve any project that impacts sacred sites (FPIC).
#    *Conflict resolution:* If a development proposal threatens a site, the CAC can approve a **Mitigation‑Exchange** (e.g., funding for a cultural center elsewhere) **only** if ICHC signs a written waiver after a formal impact‑assessment.
#
# 5. **Legal Oversight – Environmental & Heritage Courts**
#    *Fast‑track* (≤ 90 days) jurisdiction over disputes involving safety vs. cultural values, with the possibility of injunctions.
#
# **Adjudication Example:**
# - *Scenario:* A proposed seawall would require seabed dredging that encroaches on a sacred fishing ground.
# - *Process:* VLAB raises objection → CAC commissions a joint **Socio‑Environmental Impact Assessment** → ICHC evaluates cultural loss → If mitigation (e.g., co‑managed marine protected area) is acceptable, CAC approves with conditional monitoring; otherwise, the project is re‑designed or moved.
#
# ---
#
# ## 7.  Data Gaps – What We Must Acquire Before “Irreversible” Actions
#
# | Data Gap | Why Critical | How to Obtain | Timing |
# |----------|--------------|---------------|--------|
# | **High‑resolution (≤ 0.5 m) DEM of entire coastline** | Determines which areas need hard defenses vs. retreat. | Air‑borne LiDAR + satellite interferometry (contract with regional university). | Year 1 (complete before seawall design). |
# | **Updated SLR & storm‑surge probability distributions** (including climate‑model ensembles) | Sets design water levels for defenses. | Collaboration with IPCC‑affiliated climate labs; local tide‑gauge network upgrade. | Year 2 (baseline for Phase 2). |
# | **Comprehensive Indigenous cultural‑site GIS** (including oral‑history coordinates) | Ensures FPIC and legal protection. | Community‑led participatory mapping workshops, digitised archives. | Year 1‑2 (before any coastal construction). |
# | **Socio‑economic baseline of households in high‑risk zones** (assets, income, health) | Basis for fair compensation in retreat. | Household surveys, tax‑record linkage, mobile‑phone data analytics. | Year 2‑3 (before the voluntary retreat pilot). |
# | **Cost‑effectiveness of nature‑based solutions vs. hard walls under future climate scenarios** | Avoids over‑investment in possibly premature hard infrastructure. | Pilot monitoring + Monte‑Carlo benefit‑cost modelling (partner with UNDP). | Year 3 (inform Phase 2 decision). |
# | **Tourism demand elasticity to climate‑risk perception** | Determines ROI of protecting tourism assets. | Visitor‐survey data, econometric analysis of past events (e.g., 2020 cyclone). | Year 4 (inform CPZ sizing). |
# | **Debt‑servicing capacity under different bond‑yield scenarios** | Guarantees fiscal sustainability. | IMF/World Bank debt‑sustainability analysis, multi‑scenario modelling. | Year 5 (pre‑bond issuance). |
#
# *Only after these data sets reach a **minimum‑confidence threshold** (e.g., 95 % CI for SLR) will the government move to “commit‑ment” phases (e.g., full‑scale seawall construction, mass relocation).*
#
# ---
#
# ## 8.  Updating the Plan – Adaptive‑Management Cycle
#
# 1. **Annual Review (Year 1‑30)** – CAC publishes a **State‑of‑Adaptation Report** (SAR) covering all metrics.
#    *If any metric deviates > 20 % from target* → trigger a **Decision‑Adjustment Workshop**.
#
# 2. **Three‑Year “Strategic Check‑point”** – Re‑run cost‑benefit models with the latest data (SLR, economic, social).
#    *If projected net‑present‑value (NPV) of a major component falls below 0* → re‑prioritise (e.g., shift from seawall to mangrove expansion).
#
# 3. **Mid‑Term “Retreat Feasibility Survey” (Year 12 & 22)** – Re‑assess community willingness, demographic shifts, and land‑availability.
#
# 4. **External Audits (Every 5 y)** – Independent auditors evaluate financial integrity, governance compliance, and social‑impact outcomes. Recommendations become binding if **≥ 70 %** of CAC votes for them.
#
# 5. **Learning Loop** – All lessons feed into the **National Climate‑Adaptation Knowledge Base** (open‑source platform) to inform future SIDS worldwide.
#
# ---
#
# ## 9.  Summary of Prioritization (Why this ordering makes sense)
#
# | Rank | Action | Rationale (risk‑reduction + value creation) |
# |------|--------|----------------------------------------------|
# | **1** | Mapping & Institutional set‑up (Dec 1‑3) | *Low cost, high information return; creates decision‑making backbone.* |
# | **2** | Pilot nature‑based solutions (Dec 2) | *No‑regret, improves ecosystem services while buying time.* |
# | **3** | Flood‑gate upgrades (Dec 5) | *High‑impact, protects large residential zones; relatively cheap.* |
# | **4** | Hybrid seawalls in core tourism (Dec 4) | *Protects the economic engine; justified only after we know exactly where sea‑level will hit.* |
# | **5** | Voluntary retreat pilot (Dec 6) | *Proof‑of‑concept for larger retreat; respects FPIC.* |
# | **6** | Managed‑retreat scale‑up (Dec 7) | *Only after pilot demonstrates feasibility & financing path.* |
# | **7** | Economic transition fund (Dec 8) | *Diversifies income, reduces future exposure; can run in parallel with retreat.* |
# | **8** | Cultural‑site protection (Dec 9) | *Legal requirement; relatively low cost; must be locked‑in early to avoid irreversible loss.* |
# | **9** | Maintenance & post‑30 y “exit” decisions (Dec 10) | *Ensures long‑term sustainability; informed by all prior monitoring.* |
#
# ---
#
# ## 10.  What Is Speculative vs. Evidence‑Based?
#
# | Area | Evidence‑Based (E) | Speculative (S) |
# |------|-------------------|-----------------|
# | Sea‑level projections (U1) | IPCC AR6 ensembles (E) | Local amplification due to subsidence (S) |
# | Cost of seawall (Dec 4) | Similar projects in Maldives, Seychelles (E) | Exact design height needed for 2080 scenario (S) |
# | Success rate of mangrove restoration (Dec 2) | Meta‑analysis of tropical mangrove projects (E) | Survival in the nation’s specific salinity regime (S) |
# | Public willingness for managed retreat (Dec 6‑7) | Survey data from other SIDS (E) | Local cultural attachment levels (S) |
# | Tourism elasticity to climate risk (U4) | Global tourism‑risk literature (E) | Nation‑specific branding effect (S) |
# | Debt‑service capacity under bond‑yield swing (U2) | IMF debt‑sustainability models (E) | Future global interest‑rate trajectories (S) |
# | Effectiveness of “green levy” for funding ETF (Dec 8) | Examples from Costa Rica, Belize (E) | Exact revenue generation for this nation (S) |
# | Cultural‑heritage valuation (Dec 9) | UNESCO guidelines (E) | Community’s internal valuation metrics (S) |
#
# The **core of the plan** (mapping, institutional setup, pilot green actions, flood‑gate upgrades) rests on **high‑confidence evidence**. The **large‑scale retreat and economic transition** are **moderately speculative**, requiring continuous monitoring and the ability to pivot.
#
# ---
#
# ## 11.  Final Recommendation to the Government
#
# 1. **Allocate the immediate $5 bn** as follows (see Phase 0‑5 table).
# 2. **Issue the first $1 bn bond tranche** within 12 months, earmarking 70 % for CPZs & flood‑gate upgrades; keep 30 % as a “contingency reserve”.
# 3. **Secure the 60 % aid probability** by submitting a joint “Island Climate Resilience” proposal to the Green Climate Fund (GCF) and the World Bank’s Small Island Adaptation Program (SIAP) **by the end of Year 2**.
# 4. **Activate the Climate‑Adaptation Council** immediately; its first mandate is to approve the detailed design criteria for seawalls **once the SLR model reaches > 0.6 m by 2035** (U1 trigger).
# 5. **Begin the voluntary retreat pilot** only after the **FPIC** process for the target village is completed (expected by Year 4).
#
# By following the **adaptive‑management cycle** (annual SAR, 3‑year strategic checkpoints, and mid‑term retreat feasibility surveys), the nation can **stay within its fiscal envelope**, **protect its most vulnerable communities and cultural heritage**, and **maintain the economic lifeline of tourism** while **building a more diversified, resilient future**.
#
# ---
#
# *Prepared for the Government of the Island Nation – 30‑Year Climate‑Adaptation Strategy (2026‑2056).*

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Below is a 30-year, phased adaptation plan tailored to a diverse, tourism- and small-fisheries–based island nation with a 1.2 million population, facing rapid sea‑level rise, economic vulnerability, and a significant indigenous minority with sacred coastal sites at risk. Costs are expressed in USD billions; timescales are indicative. All figures are estimates subject to refinement as data arrive.
#
# Executive overview
# - Core principle: balance engineered defenses, managed retreat where necessary, diversified livelihoods, and strong protection of cultural sites through inclusive governance.
# - Funding frame: $5B immediate; up to $1B/year via bonds if markets permit; ~60% chance of modest international aid over the next decade. Treat budgets as contingent on financing conditions and aid.
# - Phasing: (1) safeguard critical assets and identities; (2) establish retreat-ready pathways and economic diversification; (3) scale up protections and governance; (4) maintain data-led updates and flexible adaptation.
#
# Assumptions (explicit)
# - Population remains near 1.2 million; internal migration within the island is feasible.
# - 40% of habitable land is at high risk of inundation or salinization within ~30 years; rate of sea-level rise is within current projections but with uncertainty.
# - Tourism and small-scale fishing remain important but face climate and ecosystem limits; diversification improves resilience.
# - Indigenous communities have distinct cultural priorities and rights; meaningful participation and consent are required for changes to sacred coastal sites.
# - Financing constraints dominate early years; aid, debt markets, and grant opportunities are uncertain and contingent on global conditions.
# - Technologies and costs will evolve; plan remains adaptable.
#
# Key uncertainties likely to affect decisions
# - Pace and geographic distribution of sea‑level rise and coastal erosion (erosion rates, subsidence, storm surge behavior).
# - Value of protected assets (properties, ports, tourism infrastructure) and cost of land acquisition for retreat.
# - Social acceptability and political feasibility of managed retreat and relocation, particularly around indigenous coastal areas.
# - Availability and terms of international aid and bond markets.
# - Effectiveness and costs of nature-based defenses versus hard infrastructure.
# - Economic response to diversification (timing, labor market fit, supply chains).
# - Legal and governance reforms needed for indigenous co-management and cultural site protection.
#
# Plan components and major decisions (with costs, benefits, and success likelihoods)
#
# Decision 1. Deploy a layered coastal defense program that combines nature-based solutions with targeted engineered protections in priority areas
# - What it includes: mangrove restoration and dune systems where feasible; living shorelines; sea walls and flood barriers in high-value zones (ports, airports, urban cores); auxiliary drainage and flood-proofing; essential climate-resilient infrastructure retrofits.
# - Estimated costs (phased)
#   - Initial package (0–5 years): about $2.5B–$3B for core defenses in the most exposed zones plus NbS; ongoing maintenance funded from bonds later.
#   - 30-year program: potential total $5B–$6B (capable of expanding if additional zones are identified).
# - Expected benefits
#   - Reduces flood/tide- and storm-related damages in high-value areas; protects critical infrastructure and a large portion of the tourism sector; creates co-benefits for biodiversity and shoreline protection.
# - Probability of success and failure
#   - Success probability: 0.6–0.75, depending on design quality, maintenance, and local adherence.
#   - Failure modes: cost overruns, maintenance shortfalls, insufficient protection for rising seas, negative ecological side-effects if poorly designed (e.g., sediment trapping).
# - Monitoring metrics and triggers
#   - Metrics: reduction in flood frequency/intensity in protected zones; annual maintenance completion rates; coastal erosion rates in protected segments; cost adherence.
#   - Triggers: if projected flooding still exceeds targeted thresholds in protected areas after 5–7 years, escalate to protective upgrades or focus more on NbS; if maintenance lag exceeds 12 months, reallocate funds.
# - Stakeholder engagement and conflict adjudication
#   - Engage: coastal communities, port operators, tourism operators, fisheries representatives, local engineers, and indigenous groups with co-design of defenses in areas of cultural importance.
#   - Adjudication: establish a Coastal Defense Governance Committee including representatives from the indigenous council, municipal authorities, and a neutral technical arbiter to resolve conflicts about siting and design choices.
# - Data needed before irreversible action
#   - High-resolution coastal hazard mapping, land ownership and asset valuation, sediment dynamics, anticipated storm surge models, and maintenance cost forecasts.
# - How to adapt with new information
#   - Use adaptive design with modular components; implement pilot segments first; revise siting as hazard maps update; adjust maintenance schedules as local capacity grows.
#
# Speculative vs evidence-based notes
# - Evidence-based: general strategy of layering NbS with engineered protections.
# - Speculative: exact siting, quantities, and maintenance costs until hazard mapping is complete.
#
# Decision 2. Implement a staged managed retreat program for the highest-risk zones, with voluntary buyouts, relocation corridors, and retention of cultural and community anchors
# - What it includes: voluntary buyouts in the most hazard-prone neighborhoods, development of relocation villages in safer inland zones, and investment in housing, job opportunities, and social services for relocated households; preservation of cultural practices near relocated sites and new cultural gathering spaces.
# - Estimated costs
#   - Early phase (0–5 years): $0.6B–$1B for planning, land acquisition options, and early relocations of the smallest clusters.
#   - Medium term (5–15 years): cumulative $4B–$6B, depending on pace and geographic scope.
#   - 30-year horizon: possible total $6B–$9B, contingent on land prices, housing costs, and buyout volumes.
# - Expected benefits
#   - Reduces exposure of people and properties to rising seas; preserves remaining habitable land; creates opportunity to design communities with resilience from the outset.
# - Probability of success and failure
#   - Success probability: 0.5–0.65 (highly contingent on voluntary participation, fair compensation, and employment alternatives).
#   - Failure modes: social resistance, perceived inequity, inadequate inland sites, cultural ties to coast, and political pushback.
# - Monitoring metrics and triggers
#   - Metrics: number of households relocated, time-to-relocation milestones, inland housing quality and affordability, employment outcomes post-relocation, social cohesion indicators.
#   - Triggers: if participation rates fall below a threshold, ramp up incentives and outreach; if inland sites show deterioration or poor livability, pause and renegotiate with communities.
# - Stakeholder engagement and conflict adjudication
#   - Engage: indigenous communities, local elected bodies, community organizations, housing authorities, employers, and NGOs.
#   - Adjudication: establish a Relocation and Cultural Continuity Council to oversee fair compensation, grievance mechanisms, and protection of sacred sites during relocation.
# - Data needed
#   - Comprehensive hazard and risk maps, land availability and suitability for relocation, housing costs and financing options, socioeconomic profiles, potential impacts on indigenous cultural practices, and revenue implications for displaced households.
# - Adaptation plan with new information
#   - Start with small pilots in low-cost areas; expand progressively with transparent benchmarks; adjust compensation schemes based on market conditions; incorporate community-led design of inland relocation spaces.
# - Speculative vs evidence-based notes
#   - Evidence-based: known need for voluntary, well-supported relocation programs in high-risk areas.
#   - Speculative: precise buyout costs and inland site viability until market studies are completed.
#
# Decision 3. Diversify and deepen the economy to reduce climate vulnerability (sustainable tourism, diversified fisheries, aquaculture, renewable energy, digital services)
# - What it includes: program of job training, incentives for private sector investment in resilient tourism products (ecotourism, cultural tourism that highlights indigenous heritage with consent), small-scale eco-friendly fisheries or aquaculture ventures, and renewable energy integration (solar/wind) to reduce energy shocks.
# - Estimated costs
#   - Initial thrust (0–5 years): $1B–$1.5B for training, seed capital, infrastructure upgrades (including digital connectivity) and targeted subsidies.
#   - Ongoing/yearly: incentives and subsidies may require $0.2B–$0.5B/year, potentially funded by bonds if market conditions allow.
# - Expected benefits
#   - Creates more resilient, higher-value jobs; reduces reliance on climate-vulnerable sectors; channels tourism into deeper cultural and environmental experiences; increases local-purchase ecosystems; improves energy resilience.
# - Probability of success and failure
#   - Success probability: 0.5–0.75 depending on demand, global tourism recovery, and effective implementation.
#   - Failure modes: demand risk in tourism (seasonality, global downturns), supply chain fragility for aquaculture, regulatory hurdles.
# - Monitoring metrics and triggers
#   - Metrics: GDP contribution from diversified sectors; tourism occupancy and diversification metrics; fishing yields; employment rates in targeted sectors; energy reliability indicators.
#   - Triggers: if diversification lag persists for 2–3 years, intensify incentives and reduce barriers; if environmental stress on new aquaculture ventures emerges, reallocate to more robust sectors.
# - Stakeholder engagement and conflict adjudication
#   - Engage: business associations, hotel/port operators, coastal communities, indigenous representatives, fisheries cooperatives, banks and microfinance institutions.
#   - Adjudication: establish an Economic Diversification Council with representation from affected communities and a rotating independent chair to mediate conflicts between stakeholders (e.g., between tourism expansion and environmental protections).
# - Data needed
#   - Market analyses for niche tourism products; current and projected tourism demand; fishing and aquaculture viability and market access; grid reliability and renewable energy costs; training capacity and wage expectations.
# - Adaptation plan with new information
#   - Use pilot programs to validate business models; scale up successful ventures; adjust incentives and regulatory environments; improve workforce training aligned with industry demand.
#
# Decision 4. Protect sacred coastal sites and establish Indigenous co-governance over cultural resources
# - What it includes: formal recognition of indigenous rights, co-management frameworks for sacred coastal sites, funding for cultural mapping, sacred site protection, language and cultural restoration programs, and mechanisms for meaningful consent in project siting.
# - Estimated costs
#   - 0–5 years: $0.4B–$0.8B for mapping, legal recognition processes, and governance structures; ongoing support for cultural programs at $0.2B–$0.4B/year in perpetuity or until needs are met.
#   - 30 years: possible total $1.5B–$3B depending on scale and ongoing commitments.
# - Expected benefits
#   - Maintains cultural integrity; reduces risk of social conflict; improves legitimacy of adaptation actions in indigenous communities; creates protected cultural tourism value where consent and stewardship are respected.
# - Probability of success and failure
#   - Success probability: 0.7–0.9 (high if genuine partnership and funding commitments are in place).
#   - Failure modes: tokenistic engagement, governance deadlock, or inadequate funding to implement protections.
# - Monitoring metrics and triggers
#   - Metrics: number of sacred sites protected, co-management agreements signed, participation rates in governance bodies, cultural program uptake, and level of community satisfaction.
#   - Triggers: if consent or engagement falters, renew outreach and adjust governance structures; if protection measures fail to prevent encroachment, escalate to legal protections and enforcement where appropriate.
# - Stakeholder engagement and conflict adjudication
#   - Engage: indigenous leadership, cultural custodians, local government, tourism developers, and conservation groups.
#   - Adjudication: establish a Cultural Heritage and Indigenous Governance Board with veto rights on projects affecting sacred sites; ensure independent mediation and due process.
# - Data needed
#   - Inventory of sacred sites, cultural practices at risk, legal frameworks for co-management, community priorities, and potential economic trade-offs for cultural protections.
# - Adaptation plan with new information
#   - Update co-management agreements as communities express new priorities; incorporate new sacred-site GIS data; adjust protection funding to reflect evolving cultural needs.
# - Speculative vs evidence-based notes
#   - Evidence-based: importance of indigenous co-management for legitimacy and effectiveness.
#   - Speculative: precise governance structures and funding levels until consultations complete.
#
# Decision 5. Invest in data, mapping, and monitoring to inform adaptive management
# - What it includes: high-resolution shoreline change mapping, coastal hazard modeling, land-use inventories, population displacement risk assessments, environmental baseline data, early warning systems, and an integrated decision-support platform.
# - Estimated costs
#   - 0–5 years: about $0.3B–$0.5B for data systems, surveys, and modeling capacity.
#   - Ongoing: $0.1B–$0.2B/year for maintenance and upgrades.
# - Expected benefits
#   - Improves accuracy of risk assessments; enables timely decisions; reduces irreversible missteps; informs all other decisions (defense, retreat, diversification, and governance).
# - Probability of success and failure
#   - Success probability: 0.8–0.9 if sustained funding and local capacity are ensured.
#   - Failure modes: data gaps, interoperability issues, underfunded data stewardship, slow uptake by policymakers.
# - Monitoring metrics and triggers
#   - Metrics: data completeness and timeliness, forecast accuracy, decision latency, system uptime.
#   - Triggers: if data quality degrades or the model predictions diverge from observed outcomes, escalate data audits and update models; if policy lags behind data, trigger rapid-response policy cycles.
# - Stakeholder engagement and conflict adjudication
#   - Engage: scientists, local universities, municipal planners, indigenous data custodians, civil society.
#   - Adjudication: create an independent Data and Ethics Advisory Panel to review data usage, privacy concerns, and consent issues for data collection.
# - Data needed
#   - Shoreline and land-use change data, hazard maps, population distribution and migration risk, cultural site geolocations with sensitivities, and economic impact data for sectors.
# - Adaptation plan with new information
#   - Data-driven updates to siting of defenses and retreat, refine economic plans, and adjust governance structures in light of new evidence.
#
# Decision 6. Strengthen governance, social cohesion, and conflict resolution mechanisms
# - What it includes: multi-stakeholder climate council, citizen juries or deliberative forums for major decisions, transparent cost-benefit analyses, and credible grievance mechanisms; public information campaigns to explain adaptation choices.
# - Estimated costs
#   - 0–5 years: $0.2B–$0.4B to establish structures and first-year operating costs; ongoing $0.05B–$0.2B/year.
# - Expected benefits
#   - Reduces contestation, increases legitimacy and trust, improves policy acceptance, improves resilience outcomes through inclusive decision-making.
# - Probability of success and failure
#   - Success probability: 0.7–0.85 with strong, ongoing participation and clear mandates.
#   - Failure modes: capture by elites, decision paralysis, or shallow participation that fails to alter outcomes.
# - Monitoring metrics and triggers
#   - Metrics: number of decisions with broad stakeholder consent, public trust indices, incident rates of social unrest, and resolution times for disputes.
#   - Triggers: if cooperation declines, intensify outreach and capacity-building; if disputes escalate, trigger external mediation and review processes.
# - Stakeholder engagement and conflict adjudication
#   - Engage: community groups, indigenous representatives, business associations, NGOs, religious and cultural leaders, and youth groups.
#   - Adjudication: establish an independent Climate Governance Tribunal or similar body to resolve conflicts with legitimacy and due process.
# - Data needed
#   - Social indicators, asset ownership data, institutional capacity assessments, and historical grievance records.
# - Adaptation plan with new information
#   - Periodic governance reviews; incorporate lessons from other island states; adjust representation and decision rules for equity and effectiveness.
#
# Decision 7. Financing and fiscal planning to align with phased actions
# - What it includes: optimize use of $5B immediate funds; plan for up to $1B/year bond issuance (subject to market conditions); secure and allocate international aid when available; build a reserve fund for disasters.
# - Estimated costs
#   - Immediate allocation: distribute the $5B across decisions 1–4 (defense, retreat planning, diversification, cultural protections), plus a contingency reserve.
#   - Bond planning: outline a 10–15-year debt plan at modest yields to fund decisions 2–3 at scale; prepare for interest costs and debt service.
#   - International aid: expected (~60% probability of modest aid) to supplement specific programs; plan for worst-case and best-case aid scenarios.
# - Expected benefits
#   - Enables timely implementation; spreads costs over time; creates financial resilience to adapt to changing conditions.
# - Probability of success/failure
#   - Financing success depends on market conditions, macro stability, and aid availability; plan for multiple scenarios with contingency financing.
# - Monitoring metrics and triggers
#   - Metrics: debt service coverage ratio, budget execution rates, grant/aid disbursement timelines, reserve fund levels.
#   - Triggers: if bond markets tighten or aid delays occur, prioritize cheapest, fastest-to-implement actions; increase reliance on NbS and targeted protections rather than large-scale new infrastructure.
# - Stakeholder engagement and conflict adjudication
#   - Engage: financial authorities, planning ministries, local governments, and the public to ensure transparency about costs and trade-offs.
#   - Adjudication: establish a fiscal oversight board to oversee debt issuance and ensure intergenerational equity.
# - Data needed
#   - Macro-economic projections, interest rate scenarios, debt servicing capacity, and risk-adjusted project valuations.
#
# Decision 8. Data governance and continuous learning framework
# - What it includes: formal process to update the plan as new hazard data, tech, or social inputs arrive; scenario planning, and annual or biennial reviews.
# - Estimated costs
#   - Minor ongoing costs: $0.1B–$0.2B/year for convening, data integration, and plan updates.
# - Expected benefits
#   - Maintains plan relevance; reduces lock-in risk; improves outcomes through iterative improvement.
# - Probability of success and failure
#   - Success probability: high with political will and capacity to act on new information.
#   - Failure modes: bureaucratic inertia or slow decision-making.
# - Monitoring metrics and triggers
#   - Metrics: frequency of plan updates, time from data arrival to policy adjustment, stakeholder satisfaction with the adaptation process.
#   - Triggers: major new climate or economic data should trigger a formal plan revision cycle.
#
# Implementation sequencing and budgets (illustrative)
# - Year 0–5 (initial rollout with $5B)
#   - Coastal defense pilot (Decision 1): ~$1.5B
#   - Managed retreat planning and early relocations (Decision 2): ~$0.6–1.0B
#   - Economic diversification startup (Decision 3): ~$0.8–1.0B
#   - Cultural protection and co-governance setup (Decision 4): ~$0.4–0.8B
#   - Data and monitoring setup (Decision 5): ~$0.3–0.5B
#   - Governance and social cohesion (Decision 6): ~$0.2–0.4B
#   - Financing planning and reserves (Decision 7): integrated into overall budgeting
# - Year 6–15 (bond-funded expansion, contingent on markets)
#   - Scale defense and NbS (Decision 1): additional ~$1.5–2B
#   - Expand retreat programs (Decision 2): ~$2–4B
#   - Deepen diversification (Decision 3): ~$1–2B
#   - Cultural protection and governance (Decision 4): ~$0.5–1B
#   - Data system upgrades (Decision 5): ~$0.2–0.5B
#   - Governance and social cohesion (Decision 6): ~$0.2–0.4B
# - Year 15–30 (steady-state adaptive management)
#   - Ongoing maintenance, monitoring, and upgrades; phased retreats or protections as necessary; continued diversification investment.
#
# Monitoring, triggers, and contingency management
# - Core metrics to track across decisions
#   - Physical: coastline protection rates, flood/erosion reductions, relocation progress, inland housing quality, protected sacred sites, habitat and biosphere status.
#   - Economic: GDP contribution by diversified sectors, tourism mix, fishing yields, unemployment rates, and income resilience.
#   - Social: trust and social cohesion indicators, stakeholder participation, incident rates, grievance resolution times.
#   - Governance: plan update frequency, decision transparency, funding disbursement timelines, debt service status.
# - Trigger-based contingencies
#   - If sea-level rise accelerates beyond plan projections, re-prioritize protection in high-value zones and accelerate NbS.
#   - If social consensus for retreat is weak, slow the pace of relocations, increase incentives, and expand inland development with enhanced safeguards for cultural sites.
#   - If aid arrives late or is smaller than expected, scale back high-cost projects and prioritize low-cost, high-impact NbS plus governance strengthening.
#   - If markets for bonds are unfavorable, defer non-critical investments and intensify data-driven prioritization and cost-sharing with communities.
#
# What data to request before irreversible actions (critical inputs)
# - High-resolution hazard and shoreline-change data, including subsidence and storm surge models; updated sea-level rise projections under multiple scenarios.
# - Comprehensive asset inventory and land values in at-risk zones, including critical infrastructure, housing, and cultural sites.
# - Feasibility studies for inland relocation sites, including land availability, infrastructure needs, and social viability.
# - Cultural site inventories with sacred-site coordinates, usage patterns, and community protections; mapping for co-governance needs and consent requirements.
# - Economic baselines and future projections for tourism (including seasonality, climate sensitivity), fisheries (stocks, quotas), and potential diversification trajectories.
# - Indigenous governance structures, consent processes, and preferred models for co-management and data sharing.
# - Financing projections under multiple macroeconomic scenarios, including bond pricing, debt-service capacity, and aid conditionalities.
# - Public sentiment and social cohesion baselines to measure progress and identify risks of conflict.
#
# Data, monitoring, and updating the plan (adaptive management)
# - Establish an annual Climate Adaptation Review: assesses new data, revises hazard maps, and adjusts priorities and budgets.
# - Conduct a decadal strategic review (with interim mid-term reviews at years 10 and 20) to re-balance defense, retreat, and diversification investments given economic and climate changes.
# - Maintain a living, transparent public dashboard showing funding allocations, project progress, risk indicators, and outcomes.
# - Ensure decision pathways include explicit consent and accountability mechanisms for indigenous groups, local communities, and civil society.
#
# Assumptions and uncertainties (summary)
# - Assumptions used for cost ranges and sequencing are intentionally conservative and subject to refinement as data arrive.
# - The most impactful uncertainties:
#   - Actual pace and geographic pattern of sea-level rise and local subsidence.
#   - Economic costs of retreat and the feasibility of inland relocation sites.
#   - Effectiveness and costs of NbS versus hard defenses in the local context.
#   - Public acceptance of relocation and co-management arrangements, particularly among indigenous communities.
#   - Availability and terms of international aid and debt-financing options.
# - Evidentiary basis versus speculation:
#   - Evidence-based: general principles of combining NbS with engineered protections; importance of co-management and inclusive governance; necessity of data-informed decisions.
#   - Speculative: exact cost figures, siting of specific projects, and precise timing of large-scale relocations until hazard and economic data are refined.
#
# Ethical and governance notes
# - This plan emphasizes consent, participation, and rights of the indigenous minority. No forced relocations should occur without clear, free, prior, and informed consent, robust compensation, meaningful alternatives, and culturally sensitive planning.
# - Establish transparent decision-making processes, with independent oversight and clear grievance mechanisms to adjudicate conflicts across economic, safety, and cultural priorities.
# - Ensure that adaptation benefits are equitably distributed and that cultural heritage protections are prioritized alongside economic resilience.
#
# Specifically markable speculative elements
# - Exact cost allocations and procurement timelines are speculative and will adjust with data on hazard extent, land values, and market conditions.
# - Precise siting for retreat corridors and defense installations will be determined by updated hazard models, land availability, and community consultations.
# - The pace and scope of international aid, bond-market access, and demand for diversified livelihoods depend on global financial conditions and political will.
#
# Bottom line
# - A balanced, adaptive approach—protecting critical assets, offering managed retreat where necessary, diversifying the economy, and protecting sacred sites through Indigenous co-governance—offers the best prospect for maintaining safety, livelihoods, and cultural integrity over 30 years.
# - The plan relies on robust data, inclusive governance, and staged financing with clear triggers to adapt to new information. Regular updates and transparent stakeholder engagement are essential to minimize conflict and maximize resilience.
#
# # Response from competitor 2
#
# # 30-Year Climate Adaptation Strategy for Island Nation
#
# ## Key Assumptions & Uncertainties
#
# ### Assumptions:
# - Current population: 1.2M (stable growth ~1% annually)
# - 40% land loss = ~300,000-400,000 people require relocation
# - Tourism contributes 30-40% GDP (evidence-based: typical small island developing states)
# - Indigenous minority represents 15-25% of population
# - Sea-level rise accelerates but remains within IPCC RCP 4.5-8.5 projections (speculative timing)
# - Democratic governance with rule of law maintained
#
# ### Critical Uncertainties (High Impact on Strategy):
# 1. **Rate of sea-level rise acceleration** (affects timeline for all decisions)
# 2. **Tourism market resilience** (COVID-19 showed 60-90% collapse possible)
# 3. **Political stability during mass relocation** (historical precedent: 30-40% chance of governance crisis)
# 4. **International aid materialization** (60% probability, but amount unknown)
# 5. **Bond market access** (depends on credit rating through crisis)
#
# ---
#
# ## Phase 1: Foundation & Assessment (Years 0-5)
# **Budget allocation: $2.5B initial + $1B bonds/year**
#
# ### 1A. Emergency Data Acquisition & Planning ($200M)
#
# **Actions:**
# - High-resolution LIDAR mapping of entire coastline
# - Participatory vulnerability mapping with indigenous communities
# - Economic dependency analysis by geography
# - Cultural site documentation and 3D preservation
# - Subsidence monitoring network
# - Storm surge modeling for 1-in-100 year events
#
# **Rationale for data needs:**
# Current global sea-level models have ±15cm uncertainty by 2050; local subsidence could add 10-30cm. Without ground-truth data, we risk either:
# - Over-investing in defenses for land that will subside anyway (waste ~$500M-1B)
# - Under-protecting economically critical areas (loss of $2-3B in assets)
#
# **Metrics:**
# - Complete baseline mapping: 18 months
# - Community consultation: 80% household participation
# - Cultural inventory: 100% documented sacred sites with indigenous verification
#
# **Probability assessment:**
# - Success (actionable data): 85% (evidence-based: standard technical work)
# - Partial failure (delays): 15% (political obstruction, technical issues)
#
# ---
#
# ### 1B. Stakeholder Governance Architecture ($50M)
#
# **Structure:**
# Create three parallel decision-making bodies:
#
# 1. **Technical Adaptation Council** (engineers, climate scientists, economists)
#    - Makes evidence-based recommendations
#    - No veto power, pure advisory
#
# 2. **Cultural Heritage Commission** (indigenous elders, historians, religious leaders)
#    - Veto power over decisions affecting documented sacred sites
#    - Must propose alternatives within 90 days of veto
#    - Funded to hire own technical experts
#
# 3. **Citizens' Assembly** (300 randomly selected residents, rotating yearly)
#    - Reviews major relocation/defense decisions
#    - Binding vote on plans >$500M
#    - Ensures democratic legitimacy
#
# **Conflict adjudication protocol:**
# - Tier 1: Facilitated negotiation (90 days)
# - Tier 2: Independent mediation panel (60 days)
# - Tier 3: Supreme Court review on constitutional grounds only
# - **Deadlock trigger**: If unresolved after 240 days, national referendum (used maximum twice per decade to prevent decision paralysis)
#
# **Probability of governance success:**
# - Maintains legitimacy through crisis: 65%
# - Partial breakdown (delays, protests): 25%
# - Complete failure (authoritarian drift or collapse): 10%
#
# *Justification*: Historical analysis of managed retreat (Isle de Jean Charles, Louisiana; Kiribati) shows governance failure rate of 30-40% without explicit indigenous co-management.
#
# ---
#
# ### 1C. Strategic Defense of Critical Infrastructure (Years 1-5: $2B)
#
# **Prioritize protection for:**
# 1. Primary airport (economic lifeline): $400M seawall + drainage
# 2. Main commercial port: $600M combined defenses
# 3. Capital city core (government, hospitals): $800M levee system
# 4. Water treatment plants: $200M elevation/relocation
#
# **NOT protected at this stage:**
# - Dispersed coastal villages (await relocation plan)
# - Secondary beach areas (tourism transition underway)
# - Agricultural lowlands (begin managed retreat)
#
# **Success probability:**
# - Infrastructure remains functional: 75% (evidence: Dutch/Singaporean engineering standards)
# - Partial failure (2-3 breaches by year 10): 20%
# - Catastrophic failure: 5%
#
# **Failure modes:**
# - Underestimated storm surge intensity
# - Coral reef degradation removes natural wave attenuation
# - Inadequate maintenance funding
#
# **Metrics & triggers:**
# - Annual stress tests
# - Settlement monitoring (<5mm/year acceptable)
# - **Contingency trigger**: If >2 infrastructure failures occur before Year 5, pause construction, reassess entire defense strategy (cost: $300M in delays)
#
# ---
#
# ## Phase 2: Economic Transition & Managed Retreat (Years 3-15)
# **Budget: $5B (remaining initial + bonds + projected aid $600M/year × 60% probability)**
#
# ### 2A. Tourism Economic Model Shift ($1.5B)
#
# **From:** Mass beach tourism → **To:** Climate resilience showcase + eco-cultural tourism
#
# **Components:**
# 1. **Living laboratory**: Partner with universities for climate research stations ($200M)
#    - Revenue: Attract conferences, research grants ($50M/year by year 10)
#
# 2. **Heritage cultural center**: Relocate threatened sacred sites' interpretive functions inland ($300M)
#    - Co-designed with indigenous communities
#    - Revenue: Cultural tourism premium pricing ($80M/year)
#
# 3. **Blue economy investment**: Deep-water aquaculture, ocean thermal energy ($800M)
#    - Probability of commercial viability by Year 15: 55%
#    - Downside risk: Loss of $600M if markets don't develop
#
# 4. **Digital services sector**: Tax incentives, fiber infrastructure ($200M)
#    - Leverage time zone, educated English-speaking population
#
# **Expected ROI:**
# - Base case (65% probability): $200M/year additional GDP by Year 15
# - Optimistic (20%): $400M/year
# - Pessimistic (15%): $50M/year (tourism collapse, tech doesn't scale)
#
# **Metrics:**
# - Tourism receipts per visitor (should increase even as volumes moderate)
# - New economy jobs created (target: 15,000 by Year 10)
# - **Decision gate at Year 8**: If new revenue <$80M/year, reallocate $500M from blue economy to Plan B (remittance economy, skilled labor export)
#
# ---
#
# ### 2B. Phased Managed Retreat ($2.5B)
#
# **Principle**: No forced relocation before Year 5; all moves voluntary until Year 10, then phased mandatory for highest-risk zones.
#
# **Implementation:**
#
# **Years 3-7 (Voluntary Phase):**
# - Purchase coastal properties at 125% pre-crisis market value + relocation stipend ($50k/household)
# - Priority: Areas with <15 years protection horizon
# - Develop 5 new inland settlements with full infrastructure
# - **Target**: Relocate 80,000 people (25% of affected population)
#
# **Predicted uptake**: 60% ± 15%
# - Justification: Buyout programs typically achieve 50-70% voluntary participation (evidence: US floodplain buyouts, Australian cyclone zones)
# - Lower participation likely in areas with indigenous sacred sites
#
# **Years 8-15 (Hybrid Phase):**
# - Mandatory building moratorium in highest-risk zones
# - Continued buyouts at 115% value
# - Rent-to-own programs in new settlements
# - **Target**: Additional 120,000 people relocated
#
# **Cost per person relocated**: ~$20,000 average (range: $8k-35k depending on property values)
#
# **Cultural site protection:**
# - Physical relocation of moveable artifacts/structures: $200M
# - Sacred site protocol: If site cannot be moved and area becomes uninhabitable:
#   - Maintain access via elevated pathways/boats as long as physically possible
#   - Ceremonial compensation process co-designed with Cultural Heritage Commission
#   - Establish inland memorial sites with blessing of traditional owners
#   - **Non-negotiable**: Indigenous communities decide which sites qualify for maximum protection effort (may exceed $50M per site)
#
# **Social cohesion metrics:**
# - Community satisfaction surveys (target: >60% approve of process)
# - Protest intensity (trigger for pause if sustained civil disobedience >5,000 people)
# - Indigenous community approval rating (minimum 50% support required)
# - **Major contingency**: If approval falls below thresholds, 12-month pause for plan revision
#
# **Probability assessment:**
# - Orderly retreat achieving 90%+ relocation by Year 15: 50%
# - Delayed/partial (70-85% relocated): 35%
# - Crisis scenario (major unrest, <65% relocated): 15%
#
# ---
#
# ### 2C. Fishing Sector Transformation ($500M)
#
# **Reality**: Traditional near-shore fisheries will be disrupted by:
# - Sea temperature changes (altering fish populations)
# - Coral bleaching (habitat loss)
# - Coastal infrastructure changes
#
# **Strategy:**
# 1. Upgrade to deeper-water capable vessels: $200M (subsidized loans)
# 2. Aquaculture training and startup grants: $150M
# 3. Fisheries monitoring/management tech: $50M
# 4. Safety net fund for transition: $100M (5-year income support)
#
# **Engagement**:
# - Co-design with fishing cooperatives
# - Guarantee: No fisher worse off than baseline for first 5 years
# - Job retraining if leaving sector
#
# **Metrics:**
# - Fishing income maintained >80% of baseline
# - Stock sustainability scores
# - **Trigger**: If >40% of fishers reject transition by Year 5, shift toward pure income support + alternative jobs
#
# ---
#
# ## Phase 3: Long-term Resilience (Years 15-30)
# **Budget: Remaining bonds + international aid + economic returns from Phase 2**
#
# ### 3A. Adaptive Infrastructure ($3B)
#
# **Speculative component**: Technology and climate trajectory will evolve significantly by Year 15. Strategy must remain flexible.
#
# **Pre-committed decisions:**
# - Retreat boundaries finalized by Year 10 (no further inland development restrictions)
# - Critical infrastructure hardened to Year 2070 projections + 30% safety margin
#
# **Adaptive decisions (await better data):**
# - Extent of nature-based solutions (mangrove restoration, coral gardening): Efficacy uncertain, $500M provisional
# - Floating/amphibious architecture: Unproven at scale, but preserve $800M option value
# - Regional migration agreements: Negotiate safety valve for worst-case population overflow
#
# ### 3B. Plan Update Protocol
#
# **Mandatory comprehensive reviews:**
# - Year 5: Adjust timeline based on observed sea-level rise rate
# - Year 10: Major economic strategy pivot if needed
# - Year 15, 20, 25: Full reassessment
#
# **Annual monitoring:**
# - Sea-level benchmarks (±5cm from projections triggers review)
# - Economic indicators (GDP, employment, inequality)
# - Social cohesion (survey data, election results, protest activity)
# - Cultural heritage preservation status
#
# **Trigger for fundamental strategy change:**
# - Sea-level rise >15cm ahead of central projection: Accelerate retreat, reduce defense spending
# - Economic collapse (GDP down >20%): Prioritize immediate welfare over long-term projects
# - Governance failure: International administration option
# - Major breakthrough (fusion energy, carbon removal): Consider holding more land
#
# ---
#
# ## Financial Structure
#
# **Initial 5-year budget ($7.5B total):**
# - Data & Planning: $200M (3%)
# - Governance: $50M (0.7%)
# - Critical infrastructure defense: $2B (27%)
# - Economic transition seed: $1B (13%)
# - Managed retreat start: $1.5B (20%)
# - Reserve fund: $750M (10%)
# - Ongoing government operations + social services: $2B (27%)
#
# **Risk management:**
# - Reserve fund for emergencies (natural disasters, economic shocks)
# - Bond issuance conditional on maintaining investment-grade rating
# - If aid fails to materialize: Reduce voluntary buyout prices to 100% market value, slower retreat timeline
# - Debt sustainability: Cap total borrowing at 70% GDP
#
# ---
#
# ## Evidence vs. Speculation
#
# **Evidence-based components:**
# - Engineering costs and success rates (extensive precedent)
# - Basic climate projections (IPCC consensus)
# - Governance failure modes (historical analysis)
# - Buyout program participation rates (empirical studies)
#
# **Speculative components:**
# - Exact timing of sea-level impacts (±5-10 year uncertainty)
# - New economic model success (blue economy unproven)
# - International aid amounts and consistency
# - Social cohesion maintenance through mass relocation (limited precedent at this scale)
# - Technology availability after Year 15
#
# **Most uncertain/highest impact:**
# The interaction between economic stress and social cohesion during Years 8-15. Historical precedent (post-disaster relocations, austerity programs) suggests 20-35% chance of political instability severe enough to derail managed retreat. This is the **critical vulnerability** requiring maximum monitoring and adaptive capacity.
#
# ---
#
# ## Ethical Framework for Impossible Choices
#
# **When economic, safety, and cultural priorities conflict irreconcilably:**
#
# 1. **Immediate safety > all**: If lives threatened, temporary overrides permitted (with compensation)
#
# 2. **Cultural survival**: Indigenous communities get veto over sacred sites + right to equivalent alternatives
#    - Exception: Cannot veto safety measures for others' lives
#    - Can accept financial compensation if community decides (their choice, not imposed)
#
# 3. **Economic efficiency secondary**: Will accept 10-15% cost premium to preserve social cohesion and cultural heritage
#
# 4. **Transparency paramount**: All decisions published with full reasoning, minority opinions recorded
#
# **Example hard case:**
# Major port generates 8% of GDP but expansion would destroy sacred burial ground. Indigenous community splits 60-40 against.
# - **Process**:
#   - Offer alternative port location (cost +$200M)
#   - If truly no alternative: Citizens' Assembly decides
#   - Winning margin must exceed 60% for irreversible action
#   - Losing community receives permanent trust fund ($100M) for cultural preservation
#   - Decision recorded as "tragic choice" acknowledging harm
#
# ---
#
# ## Summary: Theory of Success
#
# **This plan succeeds if:**
# 1. Aggressive early action buys time (Years 0-5)
# 2. Economic transition begins showing results by Year 8 (provides hope + funding)
# 3. Voluntary retreat achieves critical mass (reduces coercion needed later)
# 4. Governance maintains legitimacy through transparency and power-sharing
# 5. International community provides modest but sustained support
#
# **Success probability: 45-55%** (speculative estimate)
#
# **Most likely failure mode**: Economic transition underperforms → bond markets close → forced to choose between inadequate defense or coerced relocation without compensation → political instability → state failure
#
# **Mitigation**: Maintain reserve fund, preserve international migration options as safety valve, front-load most expensive infrastructure to early years when funds available.
#
# This is not a plan that "solves" the crisis—that's impossible with these constraints. It's a plan to **preserve community identity and democratic governance through managed decline**, avoiding the worst outcomes while acknowledging some painful losses are unavoidable.
#
# # Response from competitor 3
#
# ## 30-Year Adaptation Strategy for the Island Nation: Navigating the Tides of Change (Speculative elements marked with *)
#
# **Assumptions:**
#
# *   **Political Stability:** The government maintains sufficient stability to implement long-term strategies.
# *   **Competent Governance:** There is a baseline level of governmental capacity to execute complex projects.
# *   **Global Warming Trajectory:** The 40% loss of habitable land within 30 years is based on current climate models and trends, acknowledging potential for both faster and slower rates.
# *   **Tourism Demand:** While vulnerable, tourism will remain a viable, if transformed, economic sector for at least part of the 30-year horizon.
# *   **International Cooperation:** Acknowledgment that international aid, even if modest, is a critical component of the financial strategy.
# *   **Social Cohesion:** Despite polarization, a shared sense of urgency regarding national survival can be leveraged for unity.
# *   **Indigenous Resilience:** The indigenous population possesses strong cultural attachment and a willingness to participate in solutions, not just protest.
#
# **Key Uncertainties:**
#
# *   **Pace of Sea-Level Rise:** While 40% in 30 years is projected, the exact rate and regional variations are highly uncertain, impacting the timeline for managed retreat.
# *   **Effectiveness of Engineered Defenses:** The long-term efficacy and maintenance costs of various hard and soft defenses against accelerating sea-level rise are subject to uncertainty.
# *   **Global Market Appetite for Bonds:** Geopolitical events and global economic downturns could significantly impact the ability to raise $1 billion annually.
# *   **Level and Consistency of International Aid:** "Modest" is vague. The timing, conditions, and amount of aid are highly unpredictable.
# *   **Social Acceptance of Managed Retreat:** The willingness of affected populations to relocate, even with incentives, is a major unknown.
# *   **Economic Diversification Success:** The speed and scale at which new economic sectors can be developed and mature.
# *   **Technological Breakthroughs:** Unexpected advancements in climate engineering, sustainable energy, or resilient infrastructure could alter the cost-benefit analysis.
#
# ---
#
# ### Overarching Strategy & Guiding Principles:
#
# Our strategy adopts a **"Defend, Adapt, Diversify, and Unify"** approach, prioritizing rapid, decisive action while fostering long-term resilience. It acknowledges that a full "save-all-land" strategy is financially and physically impossible, necessitating difficult choices.
#
# **Guiding Principles:**
#
# 1.  **Safety First:** Prioritize the safety and well-being of all citizens.
# 2.  **Equity and Justice:** Ensure no community is left behind, paying particular attention to vulnerable populations and indigenous rights.
# 3.  **Cultural Preservation:** Protect and integrate indigenous knowledge and sacred sites into adaptation plans.
# 4.  **Economic Resilience:** Transition towards a diversified, knowledge-based economy less vulnerable to climate shocks.
# 5.  **Data-Driven Decisions:** Continuously monitor, adapt, and refine the plan based on new information.
# 6.  **Transparency and Participation:** Foster trust and shared ownership through open communication and broad stakeholder engagement.
#
# ---
#
# ### Phase 1: Immediate Action & Planning (Years 1-5)
#
# **Financial Allocation:**
#
# *   **Initial $5 Billion:** Allocated as follows:
#     *   **$1.5 Billion:** Immediate Engineered Defenses & Early Warning Systems (Critical Infrastructure Protection)
#     *   **$1 Billion:** Managed Retreat Pilot Programs & Resettlement Infrastructure Acquisition
#     *   **$1 Billion:** Economic Diversification Seed Fund & Workforce Training
#     *   **$1 Billion:** Social Cohesion & Cultural Preservation Programs (including indigenous land mapping)
#     *   **$0.5 Billion:** Research, Monitoring, & Governance (Data collection, modeling, institutional strengthening)
# *   **Annual $1 Billion Bonds & Modest International Aid (if received):** Primarily for scaling up Phase 1 initiatives and preparing for Phase 2.
#
# **A. ENGINEERED DEFENSES: Targeted Protection of Critical Assets**
#
# *   **Decision:** Invest in hard and soft defenses around critical infrastructure (hospitals, government buildings, power plants, key transportation hubs, **select high-value tourism zones**) and *limited, densely populated urban areas* with high economic output. These are temporary measures to buy time.
# *   **(1) Costs/Benefits/Probabilities:**
#     *   **Costs:** $1.5 billion (initial) + $200-$300 million/year for maintenance (bond funds).
#     *   **Benefits:** Protects critical services, maintains some economic activity, provides psychological security, buys time for managed retreat.
#     *   **Probability of Success (Short-term, 5-10 years): High (80%)** for preventing catastrophic failure at protected sites.
#     *   **Probability of Failure (Long-term, >20 years): High (70%)** without significant upgrades and against accelerating SLR; these are not permanent solutions for all areas. Justification: Hard defenses eventually fail or are overtopped; soft defenses require constant replenishment.
# *   **(2) Metrics & Triggers:**
#     *   **Metrics:** Sea-level rise (local tide gauges, satellite data), wave height/storm surge frequency, infrastructure damage reports, cost of repairs.
#     *   **Triggers:** If maintenance costs for engineered defenses exceed initial projections by >20% for two consecutive years, or if protected areas experience significant inundation despite defenses, this triggers a re-evaluation of defense strategies and faster managed retreat in those areas.
# *   **(3) Stakeholder Engagement & Conflict Resolution:** Engineering firms, local community leaders in protected zones, economic sector representatives. Conflicts will arise over which areas are *not* protected. Criteria for protection will be transparent: economic value, population density, critical national function. Open forums, cost-benefit analyses presented clearly. Cultural sites will generally *not* be protected by hard engineering in isolation, unless also critical infrastructure.
# ...
# | **Data Needed** | • Real‑time tide‑gauge network upgrade (cost $12 M). |
# | **Adaptive Loop** | If closure time > 10 min in two successive storms, allocate $30 M for automation upgrade. |
# | **E / S** | E (performance standards based on Dutch and Caribbean best‑practice). |
#
# ---
#
# ### 4.6 Decision 6 – Voluntary Managed‑Retreat Pilot (2 km², ≈ 8 000 people)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $310 M (land purchase, new housing, infrastructure, compensation). |
# | **Benefit** | Demonstrates feasible “exit‑option” for 0.7 % of total population; avoids future $1.2 bn damages on the relocated area (if SLR continues). |
# | **Success Probability** | **Success** 0.65 – depends on achieving **FPIC** and delivering compensation > 115 % of market value.<br>**Failure** 0.35 – could stall due to community dissent or cost overruns. |
# | **Metrics** | • % of affected households signing FPIC (target ≥ 80 %).<br>• Post‑relocation satisfaction index (≥ 70 %). |
# | **Stakeholder Process** | • Dedicated “Retreat Mediation Panel” (legal experts, Indigenous leaders, civil‑society NGOs).<br>• Independent third‑party audit of compensation packages. |
# | **Data Needed** | • Precise elevation maps of pilot area (sub‑meter).<br>• Social‑impact baseline survey (household income, education). |
# | **Adaptive Loop** | If FPIC threshold not met after 18 mo, pause and redesign incentive package (e.g., add community‑owned renewable‑energy micro‑grid). |
# | **E / S** | S (social acceptance estimated from small‑scale studies; financial assumptions contingent on market data). |
#
# ---
#
# ### 4.7 Decision 7 – Full‑Scale Managed‑Retreat Program (≈ 150 000 people)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $2.8 bn (land acquisition, new districts, infrastructure, compensation). |
# | **Benefit** | Avoids an estimated $5.9 bn in future flood & adaptation losses (life‑safety value + economic). |
# | **Success Probability** | **Success** 0.55 – high uncertainty in scaling social consent and financing.<br>**Failure** 0.45 – could result in “partial” retreat, leaving high‑risk pockets. |
# | **Metrics** | • Annual relocation rate (target ≥ 12 000 people/yr after Year 6).<br>• Compliance with **FPIC** for each community (≥ 85 %). |
# | **Stakeholder Process** | • National “Retreat‑Negotiation Forum” (government, Indigenous councils, private developers).<br>• Transparent “benefit‑sharing fund” financed by a tourism levy (2 % of ticket sales). |
# | **Data Needed** | • Updated SLR maps for 2035, 2050, 2070 (to delineate “no‑go” zones).<br>• Comprehensive household asset registers. |
# | **Adaptive Loop** | Review every 3 y; if relocation rate < 50 % of target, shift funds to “in‑situ adaptation” (e.g., elevated houses) for those areas. |
# | **E / S** | S (financial and social scaling risk). |
#
# ---
#
# ### 4.8 Decision 8 – Economic Transition Fund (ETF)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $420 M (re‑skilling, seed‑capital for green‑tourism, renewable‑energy pilot projects). |
# | **Benefit** | Diversifies GDP: + 3 % annual growth in non‑tourism sectors; creates 12 000 new jobs (reducing tourism‑sector vulnerability). |
# | **Success Probability** | 0.72 – based on similar “just‑transition” programmes in Small Island Developing States (SIDS). |
# | **Metrics** | • Number of participants completing certified training (target ≥ 10 000).<br>• Share of GDP from renewable‑energy/eco‑tourism (target ≥ 15 % by Year 20). |
# | **Stakeholder Process** | • Co‑design with labor unions, Indigenous women’s groups, private sector (tourism operators).<br>• Independent advisory board to avoid capture. |
# | **Data Needed** | • Labor‑market skill gaps analysis.<br>• Market feasibility study for renewable‑energy export (e.g., solar‑to‑hydrogen). |
# | **Adaptive Loop** | Quarterly monitoring; re‑allocate up to 15 % of unused ETF budget toward “digital‑nomad” incentives if job creation lags. |
# | **E / S** | E (economic modeling from World Bank’s “SIDS transition” reports). |
#
# ---
#
# ### 4.9 Decision 9 – Protection & Legal Safeguarding of Sacred Coastal Sites
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $95 M (land purchase/easement, archaeological documentation, offshore buffer zones). |
# | **Benefit** | Guarantees cultural continuity; avoids irreversible loss valued at $2 bn in intangible cultural heritage (UNESCO valuation method). |
# | **Success Probability** | 0.88 – if early FPIC and legal registration are done; risk of political reversal (12 %). |
# | **Metrics** | • Number of sites under legal protection (target = 100 % of identified sites).<br>• Annual patrols preventing illegal encroachment (≥ 95 % compliance). |
# | **Stakeholder Process** | • Indigenous Cultural Heritage Committee (ICHC) leads site identification.<br>• Government‑run “Cultural Impact Fund” pays for community‑led stewardship. |
# | **Data Needed** | • High‑resolution GIS of all cultural sites (including oral‑history locations). |
# | **Adaptive Loop** | If any protected site is damaged (detected by satellite or community report), trigger emergency response fund ($5 M) and revise buffer zones. |
# | **E / S** | E (costs based on land‑acquisition prices; benefit valuation from UNESCO). |
#
# ---
#
# ## 5.  Financing Schedule & Contingency Logic
#
# | Year | Core Expenditure | Funding Source | Contingency Trigger |
# |------|----------------|----------------|--------------------|
# | **0‑5** | Mapping, Pilot mangroves, CAC/CRT set‑up, initial data collection | $5 bn cash (≈ 70 % of initial fund) | If **U2** (bond markets) deteriorates > 2 % yield, postpone Phase 2 until market improves. |
# | **5‑10** | CPZ seawalls, flood‑gate upgrades, voluntary retreat pilot | $1 bn/year bonds (expected) + $0.3 bn aid (if secured) | If **U1** shows SLR > 0.8 m by 2035, accelerate seawall heightening (add $150 M). |
# | **10‑15** | Managed‑retreat pilot scaling, nature‑based expansion, ETF launch | Same as above; start “climate‑bond” issuance (green‑label) | If **U3** (aid) does not materialise, raise climate‑bond volume by 30 % and re‑allocate a portion to retreat. |
# | **15‑20** | Full‑scale retreat, large‑scale cultural‑site protection | Bonds + revenue from tourism levy (2 % of tickets) + aid (if any) | If relocation rate < 50 % of target, shift 15 % of retreat budget to “elevated housing” in place (short‑term safety). |
# | **20‑30** | Maintenance of CPZs, final retreat corridors, long‑term monitoring | Bonds (re‑financed at lower rates), modest aid, small “maintenance levy” (0.3 % of tourism receipts) | If **U4** (tourism demand) drops > 30 %, re‑prioritise funds toward renewable‑energy export projects to offset revenue loss. |
#
# *All “contingency triggers” are defined as **hard thresholds** (e.g., SLR > 0.8 m) that automatically launch a pre‑approved “contingency fund” (5 % of the total budget, i.e., $250 M) to cover redesign or acceleration.*
#
# ---
#
# ## 6.  Stakeholder‑Engagement Framework (how conflicts are adjudicated)
#
# 1. **Institutional Layer – Climate‑Adaptation Council (CAC)**
#    *Mandate:* Review all major adaptation projects, ensure FPIC, balance cost‑benefit across sectors.
#    *Decision rule:* Qualified majority (≥ 66 %) of members; if no consensus, an independent **Arbitration Panel** (3 external experts) makes the final call.
#
# 2. **Community‑Level Layer – Village‑Level Advisory Boards (VLABs)**
#    *Composition:* elected local leaders, Indigenous elders, women’s representatives, youth delegate.
#    *Function:* Provide ground‑truth data, voice concerns early, co‑design local mitigation (e.g., mangrove planting).
#
# 3. **Economic‑Sector Layer – Tourism‑Industry Forum (TIF)**
#    *Participants:* hotel chains, local tour operators, Ministry of Tourism, NGOs.
#    *Role:* Develop “tourism‑resilience levy”, propose alternative “eco‑tourism” packages, monitor revenue metrics.
#
# 4. **Cultural‑Heritage Layer – Indigenous Cultural Heritage Committee (ICHC)**
#    *Authority:* Must approve any project that impacts sacred sites (FPIC).
#    *Conflict resolution:* If a development proposal threatens a site, the CAC can approve a **Mitigation‑Exchange** (e.g., funding for a cultural center elsewhere) **only** if ICHC signs a written waiver after a formal impact‑assessment.
#
# 5. **Legal Oversight – Environmental & Heritage Courts**
#    *Fast‑track* (≤ 90 days) jurisdiction over disputes involving safety vs. cultural values, with the possibility of injunctions.
#
# **Adjudication Example:**
# - *Scenario:* A proposed seawall would require seabed dredging that encroaches on a sacred fishing ground.
# - *Process:* VLAB raises objection → CAC commissions a joint **Socio‑Environmental Impact Assessment** → ICHC evaluates cultural loss → If mitigation (e.g., co‑managed marine protected area) is acceptable, CAC approves with conditional monitoring; otherwise, the project is re‑designed or moved.
#
# ---
#
# ## 7.  Data Gaps – What We Must Acquire Before “Irreversible” Actions
#
# | Data Gap | Why Critical | How to Obtain | Timing |
# |----------|--------------|---------------|--------|
# | **High‑resolution (≤ 0.5 m) DEM of entire coastline** | Determines which areas need hard defenses vs. retreat. | Air‑borne LiDAR + satellite interferometry (contract with regional university). | Year 1 (complete before seawall design). |
# | **Updated SLR & storm‑surge probability distributions** (including climate‑model ensembles) | Sets design water levels for defenses. | Collaboration with IPCC‑affiliated climate labs; local tide‑gauge network upgrade. | Year 2 (baseline for Phase 2). |
# | **Comprehensive Indigenous cultural‑site GIS** (including oral‑history coordinates) | Ensures FPIC and legal protection. | Community‑led participatory mapping workshops, digitised archives. | Year 1‑2 (before any coastal construction). |
# | **Socio‑economic baseline of households in high‑risk zones** (assets, income, health) | Basis for fair compensation in retreat. | Household surveys, tax‑record linkage, mobile‑phone data analytics. | Year 2‑3 (before the voluntary retreat pilot). |
# | **Cost‑effectiveness of nature‑based solutions vs. hard walls under future climate scenarios** | Avoids over‑investment in possibly premature hard infrastructure. | Pilot monitoring + Monte‑Carlo benefit‑cost modelling (partner with UNDP). | Year 3 (inform Phase 2 decision). |
# | **Tourism demand elasticity to climate‑risk perception** | Determines ROI of protecting tourism assets. | Visitor‐survey data, econometric analysis of past events (e.g., 2020 cyclone). | Year 4 (inform CPZ sizing). |
# | **Debt‑servicing capacity under different bond‑yield scenarios** | Guarantees fiscal sustainability. | IMF/World Bank debt‑sustainability analysis, multi‑scenario modelling. | Year 5 (pre‑bond issuance). |
#
# *Only after these data sets reach a **minimum‑confidence threshold** (e.g., 95 % CI for SLR) will the government move to “commit‑ment” phases (e.g., full‑scale seawall construction, mass relocation).*
#
# ---
#
# ## 8.  Updating the Plan – Adaptive‑Management Cycle
#
# 1. **Annual Review (Year 1‑30)** – CAC publishes a **State‑of‑Adaptation Report** (SAR) covering all metrics.
#    *If any metric deviates > 20 % from target* → trigger a **Decision‑Adjustment Workshop**.
#
# 2. **Three‑Year “Strategic Check‑point”** – Re‑run cost‑benefit models with the latest data (SLR, economic, social).
#    *If projected net‑present‑value (NPV) of a major component falls below 0* → re‑prioritise (e.g., shift from seawall to mangrove expansion).
#
# 3. **Mid‑Term “Retreat Feasibility Survey” (Year 12 & 22)** – Re‑assess community willingness, demographic shifts, and land‑availability.
#
# 4. **External Audits (Every 5 y)** – Independent auditors evaluate financial integrity, governance compliance, and social‑impact outcomes. Recommendations become binding if **≥ 70 %** of CAC votes for them.
#
# 5. **Learning Loop** – All lessons feed into the **National Climate‑Adaptation Knowledge Base** (open‑source platform) to inform future SIDS worldwide.
#
# ---
#
# ## 9.  Summary of Prioritization (Why this ordering makes sense)
#
# | Rank | Action | Rationale (risk‑reduction + value creation) |
# |------|--------|----------------------------------------------|
# | **1** | Mapping & Institutional set‑up (Dec 1‑3) | *Low cost, high information return; creates decision‑making backbone.* |
# | **2** | Pilot nature‑based solutions (Dec 2) | *No‑regret, improves ecosystem services while buying time.* |
# | **3** | Flood‑gate upgrades (Dec 5) | *High‑impact, protects large residential zones; relatively cheap.* |
# | **4** | Hybrid seawalls in core tourism (Dec 4) | *Protects the economic engine; justified only after we know exactly where sea‑level will hit.* |
# | **5** | Voluntary retreat pilot (Dec 6) | *Proof‑of‑concept for larger retreat; respects FPIC.* |
# | **6** | Managed‑retreat scale‑up (Dec 7) | *Only after pilot demonstrates feasibility & financing path.* |
# | **7** | Economic transition fund (Dec 8) | *Diversifies income, reduces future exposure; can run in parallel with retreat.* |
# | **8** | Cultural‑site protection (Dec 9) | *Legal requirement; relatively low cost; must be locked‑in early to avoid irreversible loss.* |
# | **9** | Maintenance & post‑30 y “exit” decisions (Dec 10) | *Ensures long‑term sustainability; informed by all prior monitoring.* |
#
# ---
#
# ## 10.  What Is Speculative vs. Evidence‑Based?
#
# | Area | Evidence‑Based (E) | Speculative (S) |
# |------|-------------------|-----------------|
# | Sea‑level projections (U1) | IPCC AR6 ensembles (E) | Local amplification due to subsidence (S) |
# | Cost of seawall (Dec 4) | Similar projects in Maldives, Seychelles (E) | Exact design height needed for 2080 scenario (S) |
# | Success rate of mangrove restoration (Dec 2) | Meta‑analysis of tropical mangrove projects (E) | Survival in the nation’s specific salinity regime (S) |
# | Public willingness for managed retreat (Dec 6‑7) | Survey data from other SIDS (E) | Local cultural attachment levels (S) |
# | Tourism elasticity to climate risk (U4) | Global tourism‑risk literature (E) | Nation‑specific branding effect (S) |
# | Debt‑service capacity under bond‑yield swing (U2) | IMF debt‑sustainability models (E) | Future global interest‑rate trajectories (S) |
# | Effectiveness of “green levy” for funding ETF (Dec 8) | Examples from Costa Rica, Belize (E) | Exact revenue generation for this nation (S) |
# | Cultural‑heritage valuation (Dec 9) | UNESCO guidelines (E) | Community’s internal valuation metrics (S) |
#
# The **core of the plan** (mapping, institutional setup, pilot green actions, flood‑gate upgrades) rests on **high‑confidence evidence**. The **large‑scale retreat and economic transition** are **moderately speculative**, requiring continuous monitoring and the ability to pivot.
#
# ---
#
# ## 11.  Final Recommendation to the Government
#
# 1. **Allocate the immediate $5 bn** as follows (see Phase 0‑5 table).
# 2. **Issue the first $1 bn bond tranche** within 12 months, earmarking 70 % for CPZs & flood‑gate upgrades; keep 30 % as a “contingency reserve”.
# 3. **Secure the 60 % aid probability** by submitting a joint “Island Climate Resilience” proposal to the Green Climate Fund (GCF) and the World Bank’s Small Island Adaptation Program (SIAP) **by the end of Year 2**.
# 4. **Activate the Climate‑Adaptation Council** immediately; its first mandate is to approve the detailed design criteria for seawalls **once the SLR model reaches > 0.6 m by 2035** (U1 trigger).
# 5. **Begin the voluntary retreat pilot** only after the **FPIC** process for the target village is completed (expected by Year 4).
#
# By following the **adaptive‑management cycle** (annual SAR, 3‑year strategic checkpoints, and mid‑term retreat feasibility surveys), the nation can **stay within its fiscal envelope**, **protect its most vulnerable communities and cultural heritage**, and **maintain the economic lifeline of tourism** while **building a more diversified, resilient future**.
#
# ---
#
# *Prepared for the Government of the Island Nation – 30‑Year Climate‑Adaptation Strategy (2026‑2056).*

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 5 competitors.
# Each model has been given this question:
#
# Imagine you are advising the government of a diverse island nation of 1.2 million people facing three simultaneous crises: a projected 40% loss of habitable land to sea‑level rise within 30 years, a fragile economy reliant on tourism and small‑scale fishing, and a polarized society with a significant indigenous minority whose sacred coastal sites are threatened. The government has $5 billion in immediate funds, can raise an additional $1 billion per year through bonds if markets allow, and estimates a 60% chance of receiving modest international aid over the next decade. Within these constraints, propose a prioritized 30‑year adaptation strategy that balances engineered defenses, managed retreat, economic transition, social cohesion, and protection of cultural sites. For each major decision in your plan: (1) estimate expected costs and benefits and assign a probability of success and of failure (with brief justification), (2) identify clear metrics to monitor progress and trigger contingencies, (3) explain how you would engage stakeholders and adjudicate conflicts between economic, safety, and cultural priorities, (4) specify what additional data you would request (and why) before committing to irreversible actions, and (5) describe how you would update the plan as new information arrives. Explicitly list your assumptions and the key uncertainties that most affect your recommendations, and mark which parts of your answer are speculative versus evidence‑based.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Below is a 30-year, phased adaptation plan tailored to a diverse, tourism- and small-fisheries–based island nation with a 1.2 million population, facing rapid sea‑level rise, economic vulnerability, and a significant indigenous minority with sacred coastal sites at risk. Costs are expressed in USD billions; timescales are indicative. All figures are estimates subject to refinement as data arrive.
#
# Executive overview
# - Core principle: balance engineered defenses, managed retreat where necessary, diversified livelihoods, and strong protection of cultural sites through inclusive governance.
# - Funding frame: $5B immediate; up to $1B/year via bonds if markets permit; ~60% chance of modest international aid over the next decade. Treat budgets as contingent on financing conditions and aid.
# - Phasing: (1) safeguard critical assets and identities; (2) establish retreat-ready pathways and economic diversification; (3) scale up protections and governance; (4) maintain data-led updates and flexible adaptation.
#
# Assumptions (explicit)
# - Population remains near 1.2 million; internal migration within the island is feasible.
# - 40% of habitable land is at high risk of inundation or salinization within ~30 years; rate of sea-level rise is within current projections but with uncertainty.
# - Tourism and small-scale fishing remain important but face climate and ecosystem limits; diversification improves resilience.
# - Indigenous communities have distinct cultural priorities and rights; meaningful participation and consent are required for changes to sacred coastal sites.
# - Financing constraints dominate early years; aid, debt markets, and grant opportunities are uncertain and contingent on global conditions.
# - Technologies and costs will evolve; plan remains adaptable.
#
# Key uncertainties likely to affect decisions
# - Pace and geographic distribution of sea‑level rise and coastal erosion (erosion rates, subsidence, storm surge behavior).
# - Value of protected assets (properties, ports, tourism infrastructure) and cost of land acquisition for retreat.
# - Social acceptability and political feasibility of managed retreat and relocation, particularly around indigenous coastal areas.
# - Availability and terms of international aid and bond markets.
# - Effectiveness and costs of nature-based defenses versus hard infrastructure.
# - Economic response to diversification (timing, labor market fit, supply chains).
# - Legal and governance reforms needed for indigenous co-management and cultural site protection.
#
# Plan components and major decisions (with costs, benefits, and success likelihoods)
#
# Decision 1. Deploy a layered coastal defense program that combines nature-based solutions with targeted engineered protections in priority areas
# - What it includes: mangrove restoration and dune systems where feasible; living shorelines; sea walls and flood barriers in high-value zones (ports, airports, urban cores); auxiliary drainage and flood-proofing; essential climate-resilient infrastructure retrofits.
# - Estimated costs (phased)
#   - Initial package (0–5 years): about $2.5B–$3B for core defenses in the most exposed zones plus NbS; ongoing maintenance funded from bonds later.
#   - 30-year program: potential total $5B–$6B (capable of expanding if additional zones are identified).
# - Expected benefits
#   - Reduces flood/tide- and storm-related damages in high-value areas; protects critical infrastructure and a large portion of the tourism sector; creates co-benefits for biodiversity and shoreline protection.
# - Probability of success and failure
#   - Success probability: 0.6–0.75, depending on design quality, maintenance, and local adherence.
#   - Failure modes: cost overruns, maintenance shortfalls, insufficient protection for rising seas, negative ecological side-effects if poorly designed (e.g., sediment trapping).
# - Monitoring metrics and triggers
#   - Metrics: reduction in flood frequency/intensity in protected zones; annual maintenance completion rates; coastal erosion rates in protected segments; cost adherence.
#   - Triggers: if projected flooding still exceeds targeted thresholds in protected areas after 5–7 years, escalate to protective upgrades or focus more on NbS; if maintenance lag exceeds 12 months, reallocate funds.
# - Stakeholder engagement and conflict adjudication
#   - Engage: coastal communities, port operators, tourism operators, fisheries representatives, local engineers, and indigenous groups with co-design of defenses in areas of cultural importance.
#   - Adjudication: establish a Coastal Defense Governance Committee including representatives from the indigenous council, municipal authorities, and a neutral technical arbiter to resolve conflicts about siting and design choices.
# - Data needed before irreversible action
#   - High-resolution coastal hazard mapping, land ownership and asset valuation, sediment dynamics, anticipated storm surge models, and maintenance cost forecasts.
# - How to adapt with new information
#   - Use adaptive design with modular components; implement pilot segments first; revise siting as hazard maps update; adjust maintenance schedules as local capacity grows.
#
# Speculative vs evidence-based notes
# - Evidence-based: general strategy of layering NbS with engineered protections.
# - Speculative: exact siting, quantities, and maintenance costs until hazard mapping is complete.
#
# Decision 2. Implement a staged managed retreat program for the highest-risk zones, with voluntary buyouts, relocation corridors, and retention of cultural and community anchors
# - What it includes: voluntary buyouts in the most hazard-prone neighborhoods, development of relocation villages in safer inland zones, and investment in housing, job opportunities, and social services for relocated households; preservation of cultural practices near relocated sites and new cultural gathering spaces.
# - Estimated costs
#   - Early phase (0–5 years): $0.6B–$1B for planning, land acquisition options, and early relocations of the smallest clusters.
#   - Medium term (5–15 years): cumulative $4B–$6B, depending on pace and geographic scope.
#   - 30-year horizon: possible total $6B–$9B, contingent on land prices, housing costs, and buyout volumes.
# - Expected benefits
#   - Reduces exposure of people and properties to rising seas; preserves remaining habitable land; creates opportunity to design communities with resilience from the outset.
# - Probability of success and failure
#   - Success probability: 0.5–0.65 (highly contingent on voluntary participation, fair compensation, and employment alternatives).
#   - Failure modes: social resistance, perceived inequity, inadequate inland sites, cultural ties to coast, and political pushback.
# - Monitoring metrics and triggers
#   - Metrics: number of households relocated, time-to-relocation milestones, inland housing quality and affordability, employment outcomes post-relocation, social cohesion indicators.
#   - Triggers: if participation rates fall below a threshold, ramp up incentives and outreach; if inland sites show deterioration or poor livability, pause and renegotiate with communities.
# - Stakeholder engagement and conflict adjudication
#   - Engage: indigenous communities, local elected bodies, community organizations, housing authorities, employers, and NGOs.
#   - Adjudication: establish a Relocation and Cultural Continuity Council to oversee fair compensation, grievance mechanisms, and protection of sacred sites during relocation.
# - Data needed
#   - Comprehensive hazard and risk maps, land availability and suitability for relocation, housing costs and financing options, socioeconomic profiles, potential impacts on indigenous cultural practices, and revenue implications for displaced households.
# - Adaptation plan with new information
#   - Start with small pilots in low-cost areas; expand progressively with transparent benchmarks; adjust compensation schemes based on market conditions; incorporate community-led design of inland relocation spaces.
# - Speculative vs evidence-based notes
#   - Evidence-based: known need for voluntary, well-supported relocation programs in high-risk areas.
#   - Speculative: precise buyout costs and inland site viability until market studies are completed.
#
# Decision 3. Diversify and deepen the economy to reduce climate vulnerability (sustainable tourism, diversified fisheries, aquaculture, renewable energy, digital services)
# - What it includes: program of job training, incentives for private sector investment in resilient tourism products (ecotourism, cultural tourism that highlights indigenous heritage with consent), small-scale eco-friendly fisheries or aquaculture ventures, and renewable energy integration (solar/wind) to reduce energy shocks.
# - Estimated costs
#   - Initial thrust (0–5 years): $1B–$1.5B for training, seed capital, infrastructure upgrades (including digital connectivity) and targeted subsidies.
#   - Ongoing/yearly: incentives and subsidies may require $0.2B–$0.5B/year, potentially funded by bonds if market conditions allow.
# - Expected benefits
#   - Creates more resilient, higher-value jobs; reduces reliance on climate-vulnerable sectors; channels tourism into deeper cultural and environmental experiences; increases local-purchase ecosystems; improves energy resilience.
# - Probability of success and failure
#   - Success probability: 0.5–0.75 depending on demand, global tourism recovery, and effective implementation.
#   - Failure modes: demand risk in tourism (seasonality, global downturns), supply chain fragility for aquaculture, regulatory hurdles.
# - Monitoring metrics and triggers
#   - Metrics: GDP contribution from diversified sectors; tourism occupancy and diversification metrics; fishing yields; employment rates in targeted sectors; energy reliability indicators.
#   - Triggers: if diversification lag persists for 2–3 years, intensify incentives and reduce barriers; if environmental stress on new aquaculture ventures emerges, reallocate to more robust sectors.
# - Stakeholder engagement and conflict adjudication
#   - Engage: business associations, hotel/port operators, coastal communities, indigenous representatives, fisheries cooperatives, banks and microfinance institutions.
#   - Adjudication: establish an Economic Diversification Council with representation from affected communities and a rotating independent chair to mediate conflicts between stakeholders (e.g., between tourism expansion and environmental protections).
# - Data needed
#   - Market analyses for niche tourism products; current and projected tourism demand; fishing and aquaculture viability and market access; grid reliability and renewable energy costs; training capacity and wage expectations.
# - Adaptation plan with new information
#   - Use pilot programs to validate business models; scale up successful ventures; adjust incentives and regulatory environments; improve workforce training aligned with industry demand.
#
# Decision 4. Protect sacred coastal sites and establish Indigenous co-governance over cultural resources
# - What it includes: formal recognition of indigenous rights, co-management frameworks for sacred coastal sites, funding for cultural mapping, sacred site protection, language and cultural restoration programs, and mechanisms for meaningful consent in project siting.
# - Estimated costs
#   - 0–5 years: $0.4B–$0.8B for mapping, legal recognition processes, and governance structures; ongoing support for cultural programs at $0.2B–$0.4B/year in perpetuity or until needs are met.
#   - 30 years: possible total $1.5B–$3B depending on scale and ongoing commitments.
# - Expected benefits
#   - Maintains cultural integrity; reduces risk of social conflict; improves legitimacy of adaptation actions in indigenous communities; creates protected cultural tourism value where consent and stewardship are respected.
# - Probability of success and failure
#   - Success probability: 0.7–0.9 (high if genuine partnership and funding commitments are in place).
#   - Failure modes: tokenistic engagement, governance deadlock, or inadequate funding to implement protections.
# - Monitoring metrics and triggers
#   - Metrics: number of sacred sites protected, co-management agreements signed, participation rates in governance bodies, cultural program uptake, and level of community satisfaction.
#   - Triggers: if consent or engagement falters, renew outreach and adjust governance structures; if protection measures fail to prevent encroachment, escalate to legal protections and enforcement where appropriate.
# - Stakeholder engagement and conflict adjudication
#   - Engage: indigenous leadership, cultural custodians, local government, tourism developers, and conservation groups.
#   - Adjudication: establish a Cultural Heritage and Indigenous Governance Board with veto rights on projects affecting sacred sites; ensure independent mediation and due process.
# - Data needed
#   - Inventory of sacred sites, cultural practices at risk, legal frameworks for co-management, community priorities, and potential economic trade-offs for cultural protections.
# - Adaptation plan with new information
#   - Update co-management agreements as communities express new priorities; incorporate new sacred-site GIS data; adjust protection funding to reflect evolving cultural needs.
# - Speculative vs evidence-based notes
#   - Evidence-based: importance of indigenous co-management for legitimacy and effectiveness.
#   - Speculative: precise governance structures and funding levels until consultations complete.
#
# Decision 5. Invest in data, mapping, and monitoring to inform adaptive management
# - What it includes: high-resolution shoreline change mapping, coastal hazard modeling, land-use inventories, population displacement risk assessments, environmental baseline data, early warning systems, and an integrated decision-support platform.
# - Estimated costs
#   - 0–5 years: about $0.3B–$0.5B for data systems, surveys, and modeling capacity.
#   - Ongoing: $0.1B–$0.2B/year for maintenance and upgrades.
# - Expected benefits
#   - Improves accuracy of risk assessments; enables timely decisions; reduces irreversible missteps; informs all other decisions (defense, retreat, diversification, and governance).
# - Probability of success and failure
#   - Success probability: 0.8–0.9 if sustained funding and local capacity are ensured.
#   - Failure modes: data gaps, interoperability issues, underfunded data stewardship, slow uptake by policymakers.
# - Monitoring metrics and triggers
#   - Metrics: data completeness and timeliness, forecast accuracy, decision latency, system uptime.
#   - Triggers: if data quality degrades or the model predictions diverge from observed outcomes, escalate data audits and update models; if policy lags behind data, trigger rapid-response policy cycles.
# - Stakeholder engagement and conflict adjudication
#   - Engage: scientists, local universities, municipal planners, indigenous data custodians, civil society.
#   - Adjudication: create an independent Data and Ethics Advisory Panel to review data usage, privacy concerns, and consent issues for data collection.
# - Data needed
#   - Shoreline and land-use change data, hazard maps, population distribution and migration risk, cultural site geolocations with sensitivities, and economic impact data for sectors.
# - Adaptation plan with new information
#   - Data-driven updates to siting of defenses and retreat, refine economic plans, and adjust governance structures in light of new evidence.
#
# Decision 6. Strengthen governance, social cohesion, and conflict resolution mechanisms
# - What it includes: multi-stakeholder climate council, citizen juries or deliberative forums for major decisions, transparent cost-benefit analyses, and credible grievance mechanisms; public information campaigns to explain adaptation choices.
# - Estimated costs
#   - 0–5 years: $0.2B–$0.4B to establish structures and first-year operating costs; ongoing $0.05B–$0.2B/year.
# - Expected benefits
#   - Reduces contestation, increases legitimacy and trust, improves policy acceptance, improves resilience outcomes through inclusive decision-making.
# - Probability of success and failure
#   - Success probability: 0.7–0.85 with strong, ongoing participation and clear mandates.
#   - Failure modes: capture by elites, decision paralysis, or shallow participation that fails to alter outcomes.
# - Monitoring metrics and triggers
#   - Metrics: number of decisions with broad stakeholder consent, public trust indices, incident rates of social unrest, and resolution times for disputes.
#   - Triggers: if cooperation declines, intensify outreach and capacity-building; if disputes escalate, trigger external mediation and review processes.
# - Stakeholder engagement and conflict adjudication
#   - Engage: community groups, indigenous representatives, business associations, NGOs, religious and cultural leaders, and youth groups.
#   - Adjudication: establish an independent Climate Governance Tribunal or similar body to resolve conflicts with legitimacy and due process.
# - Data needed
#   - Social indicators, asset ownership data, institutional capacity assessments, and historical grievance records.
# - Adaptation plan with new information
#   - Periodic governance reviews; incorporate lessons from other island states; adjust representation and decision rules for equity and effectiveness.
#
# Decision 7. Financing and fiscal planning to align with phased actions
# - What it includes: optimize use of $5B immediate funds; plan for up to $1B/year bond issuance (subject to market conditions); secure and allocate international aid when available; build a reserve fund for disasters.
# - Estimated costs
#   - Immediate allocation: distribute the $5B across decisions 1–4 (defense, retreat planning, diversification, cultural protections), plus a contingency reserve.
#   - Bond planning: outline a 10–15-year debt plan at modest yields to fund decisions 2–3 at scale; prepare for interest costs and debt service.
#   - International aid: expected (~60% probability of modest aid) to supplement specific programs; plan for worst-case and best-case aid scenarios.
# - Expected benefits
#   - Enables timely implementation; spreads costs over time; creates financial resilience to adapt to changing conditions.
# - Probability of success/failure
#   - Financing success depends on market conditions, macro stability, and aid availability; plan for multiple scenarios with contingency financing.
# - Monitoring metrics and triggers
#   - Metrics: debt service coverage ratio, budget execution rates, grant/aid disbursement timelines, reserve fund levels.
#   - Triggers: if bond markets tighten or aid delays occur, prioritize cheapest, fastest-to-implement actions; increase reliance on NbS and targeted protections rather than large-scale new infrastructure.
# - Stakeholder engagement and conflict adjudication
#   - Engage: financial authorities, planning ministries, local governments, and the public to ensure transparency about costs and trade-offs.
#   - Adjudication: establish a fiscal oversight board to oversee debt issuance and ensure intergenerational equity.
# - Data needed
#   - Macro-economic projections, interest rate scenarios, debt servicing capacity, and risk-adjusted project valuations.
#
# Decision 8. Data governance and continuous learning framework
# - What it includes: formal process to update the plan as new hazard data, tech, or social inputs arrive; scenario planning, and annual or biennial reviews.
# - Estimated costs
#   - Minor ongoing costs: $0.1B–$0.2B/year for convening, data integration, and plan updates.
# - Expected benefits
#   - Maintains plan relevance; reduces lock-in risk; improves outcomes through iterative improvement.
# - Probability of success and failure
#   - Success probability: high with political will and capacity to act on new information.
#   - Failure modes: bureaucratic inertia or slow decision-making.
# - Monitoring metrics and triggers
#   - Metrics: frequency of plan updates, time from data arrival to policy adjustment, stakeholder satisfaction with the adaptation process.
#   - Triggers: major new climate or economic data should trigger a formal plan revision cycle.
#
# Implementation sequencing and budgets (illustrative)
# - Year 0–5 (initial rollout with $5B)
#   - Coastal defense pilot (Decision 1): ~$1.5B
#   - Managed retreat planning and early relocations (Decision 2): ~$0.6–1.0B
#   - Economic diversification startup (Decision 3): ~$0.8–1.0B
#   - Cultural protection and co-governance setup (Decision 4): ~$0.4–0.8B
#   - Data and monitoring setup (Decision 5): ~$0.3–0.5B
#   - Governance and social cohesion (Decision 6): ~$0.2–0.4B
#   - Financing planning and reserves (Decision 7): integrated into overall budgeting
# - Year 6–15 (bond-funded expansion, contingent on markets)
#   - Scale defense and NbS (Decision 1): additional ~$1.5–2B
#   - Expand retreat programs (Decision 2): ~$2–4B
#   - Deepen diversification (Decision 3): ~$1–2B
#   - Cultural protection and governance (Decision 4): ~$0.5–1B
#   - Data system upgrades (Decision 5): ~$0.2–0.5B
#   - Governance and social cohesion (Decision 6): ~$0.2–0.4B
# - Year 15–30 (steady-state adaptive management)
#   - Ongoing maintenance, monitoring, and upgrades; phased retreats or protections as necessary; continued diversification investment.
#
# Monitoring, triggers, and contingency management
# - Core metrics to track across decisions
#   - Physical: coastline protection rates, flood/erosion reductions, relocation progress, inland housing quality, protected sacred sites, habitat and biosphere status.
#   - Economic: GDP contribution by diversified sectors, tourism mix, fishing yields, unemployment rates, and income resilience.
#   - Social: trust and social cohesion indicators, stakeholder participation, incident rates, grievance resolution times.
#   - Governance: plan update frequency, decision transparency, funding disbursement timelines, debt service status.
# - Trigger-based contingencies
#   - If sea-level rise accelerates beyond plan projections, re-prioritize protection in high-value zones and accelerate NbS.
#   - If social consensus for retreat is weak, slow the pace of relocations, increase incentives, and expand inland development with enhanced safeguards for cultural sites.
#   - If aid arrives late or is smaller than expected, scale back high-cost projects and prioritize low-cost, high-impact NbS plus governance strengthening.
#   - If markets for bonds are unfavorable, defer non-critical investments and intensify data-driven prioritization and cost-sharing with communities.
#
# What data to request before irreversible actions (critical inputs)
# - High-resolution hazard and shoreline-change data, including subsidence and storm surge models; updated sea-level rise projections under multiple scenarios.
# - Comprehensive asset inventory and land values in at-risk zones, including critical infrastructure, housing, and cultural sites.
# - Feasibility studies for inland relocation sites, including land availability, infrastructure needs, and social viability.
# - Cultural site inventories with sacred-site coordinates, usage patterns, and community protections; mapping for co-governance needs and consent requirements.
# - Economic baselines and future projections for tourism (including seasonality, climate sensitivity), fisheries (stocks, quotas), and potential diversification trajectories.
# - Indigenous governance structures, consent processes, and preferred models for co-management and data sharing.
# - Financing projections under multiple macroeconomic scenarios, including bond pricing, debt-service capacity, and aid conditionalities.
# - Public sentiment and social cohesion baselines to measure progress and identify risks of conflict.
#
# Data, monitoring, and updating the plan (adaptive management)
# - Establish an annual Climate Adaptation Review: assesses new data, revises hazard maps, and adjusts priorities and budgets.
# - Conduct a decadal strategic review (with interim mid-term reviews at years 10 and 20) to re-balance defense, retreat, and diversification investments given economic and climate changes.
# - Maintain a living, transparent public dashboard showing funding allocations, project progress, risk indicators, and outcomes.
# - Ensure decision pathways include explicit consent and accountability mechanisms for indigenous groups, local communities, and civil society.
#
# Assumptions and uncertainties (summary)
# - Assumptions used for cost ranges and sequencing are intentionally conservative and subject to refinement as data arrive.
# - The most impactful uncertainties:
#   - Actual pace and geographic pattern of sea-level rise and local subsidence.
#   - Economic costs of retreat and the feasibility of inland relocation sites.
#   - Effectiveness and costs of NbS versus hard defenses in the local context.
#   - Public acceptance of relocation and co-management arrangements, particularly among indigenous communities.
#   - Availability and terms of international aid and debt-financing options.
# - Evidentiary basis versus speculation:
#   - Evidence-based: general principles of combining NbS with engineered protections; importance of co-management and inclusive governance; necessity of data-informed decisions.
#   - Speculative: exact cost figures, siting of specific projects, and precise timing of large-scale relocations until hazard and economic data are refined.
#
# Ethical and governance notes
# - This plan emphasizes consent, participation, and rights of the indigenous minority. No forced relocations should occur without clear, free, prior, and informed consent, robust compensation, meaningful alternatives, and culturally sensitive planning.
# - Establish transparent decision-making processes, with independent oversight and clear grievance mechanisms to adjudicate conflicts across economic, safety, and cultural priorities.
# - Ensure that adaptation benefits are equitably distributed and that cultural heritage protections are prioritized alongside economic resilience.
#
# Specifically markable speculative elements
# - Exact cost allocations and procurement timelines are speculative and will adjust with data on hazard extent, land values, and market conditions.
# - Precise siting for retreat corridors and defense installations will be determined by updated hazard models, land availability, and community consultations.
# - The pace and scope of international aid, bond-market access, and demand for diversified livelihoods depend on global financial conditions and political will.
#
# Bottom line
# - A balanced, adaptive approach—protecting critical assets, offering managed retreat where necessary, diversifying the economy, and protecting sacred sites through Indigenous co-governance—offers the best prospect for maintaining safety, livelihoods, and cultural integrity over 30 years.
# - The plan relies on robust data, inclusive governance, and staged financing with clear triggers to adapt to new information. Regular updates and transparent stakeholder engagement are essential to minimize conflict and maximize resilience.
#
# # Response from competitor 2
#
# # 30-Year Climate Adaptation Strategy for Island Nation
#
# ## Key Assumptions & Uncertainties
#
# ### Assumptions:
# - Current population: 1.2M (stable growth ~1% annually)
# - 40% land loss = ~300,000-400,000 people require relocation
# - Tourism contributes 30-40% GDP (evidence-based: typical small island developing states)
# - Indigenous minority represents 15-25% of population
# - Sea-level rise accelerates but remains within IPCC RCP 4.5-8.5 projections (speculative timing)
# - Democratic governance with rule of law maintained
#
# ### Critical Uncertainties (High Impact on Strategy):
# 1. **Rate of sea-level rise acceleration** (affects timeline for all decisions)
# 2. **Tourism market resilience** (COVID-19 showed 60-90% collapse possible)
# 3. **Political stability during mass relocation** (historical precedent: 30-40% chance of governance crisis)
# 4. **International aid materialization** (60% probability, but amount unknown)
# 5. **Bond market access** (depends on credit rating through crisis)
#
# ---
#
# ## Phase 1: Foundation & Assessment (Years 0-5)
# **Budget allocation: $2.5B initial + $1B bonds/year**
#
# ### 1A. Emergency Data Acquisition & Planning ($200M)
#
# **Actions:**
# - High-resolution LIDAR mapping of entire coastline
# - Participatory vulnerability mapping with indigenous communities
# - Economic dependency analysis by geography
# - Cultural site documentation and 3D preservation
# - Subsidence monitoring network
# - Storm surge modeling for 1-in-100 year events
#
# **Rationale for data needs:**
# Current global sea-level models have ±15cm uncertainty by 2050; local subsidence could add 10-30cm. Without ground-truth data, we risk either:
# - Over-investing in defenses for land that will subside anyway (waste ~$500M-1B)
# - Under-protecting economically critical areas (loss of $2-3B in assets)
#
# **Metrics:**
# - Complete baseline mapping: 18 months
# - Community consultation: 80% household participation
# - Cultural inventory: 100% documented sacred sites with indigenous verification
#
# **Probability assessment:**
# - Success (actionable data): 85% (evidence-based: standard technical work)
# - Partial failure (delays): 15% (political obstruction, technical issues)
#
# ---
#
# ### 1B. Stakeholder Governance Architecture ($50M)
#
# **Structure:**
# Create three parallel decision-making bodies:
#
# 1. **Technical Adaptation Council** (engineers, climate scientists, economists)
#    - Makes evidence-based recommendations
#    - No veto power, pure advisory
#
# 2. **Cultural Heritage Commission** (indigenous elders, historians, religious leaders)
#    - Veto power over decisions affecting documented sacred sites
#    - Must propose alternatives within 90 days of veto
#    - Funded to hire own technical experts
#
# 3. **Citizens' Assembly** (300 randomly selected residents, rotating yearly)
#    - Reviews major relocation/defense decisions
#    - Binding vote on plans >$500M
#    - Ensures democratic legitimacy
#
# **Conflict adjudication protocol:**
# - Tier 1: Facilitated negotiation (90 days)
# - Tier 2: Independent mediation panel (60 days)
# - Tier 3: Supreme Court review on constitutional grounds only
# - **Deadlock trigger**: If unresolved after 240 days, national referendum (used maximum twice per decade to prevent decision paralysis)
#
# **Probability of governance success:**
# - Maintains legitimacy through crisis: 65%
# - Partial breakdown (delays, protests): 25%
# - Complete failure (authoritarian drift or collapse): 10%
#
# *Justification*: Historical analysis of managed retreat (Isle de Jean Charles, Louisiana; Kiribati) shows governance failure rate of 30-40% without explicit indigenous co-management.
#
# ---
#
# ### 1C. Strategic Defense of Critical Infrastructure (Years 1-5: $2B)
#
# **Prioritize protection for:**
# 1. Primary airport (economic lifeline): $400M seawall + drainage
# 2. Main commercial port: $600M combined defenses
# 3. Capital city core (government, hospitals): $800M levee system
# 4. Water treatment plants: $200M elevation/relocation
#
# **NOT protected at this stage:**
# - Dispersed coastal villages (await relocation plan)
# - Secondary beach areas (tourism transition underway)
# - Agricultural lowlands (begin managed retreat)
#
# **Success probability:**
# - Infrastructure remains functional: 75% (evidence: Dutch/Singaporean engineering standards)
# - Partial failure (2-3 breaches by year 10): 20%
# - Catastrophic failure: 5%
#
# **Failure modes:**
# - Underestimated storm surge intensity
# - Coral reef degradation removes natural wave attenuation
# - Inadequate maintenance funding
#
# **Metrics & triggers:**
# - Annual stress tests
# - Settlement monitoring (<5mm/year acceptable)
# - **Contingency trigger**: If >2 infrastructure failures occur before Year 5, pause construction, reassess entire defense strategy (cost: $300M in delays)
#
# ---
#
# ## Phase 2: Economic Transition & Managed Retreat (Years 3-15)
# **Budget: $5B (remaining initial + bonds + projected aid $600M/year × 60% probability)**
#
# ### 2A. Tourism Economic Model Shift ($1.5B)
#
# **From:** Mass beach tourism → **To:** Climate resilience showcase + eco-cultural tourism
#
# **Components:**
# 1. **Living laboratory**: Partner with universities for climate research stations ($200M)
#    - Revenue: Attract conferences, research grants ($50M/year by year 10)
#
# 2. **Heritage cultural center**: Relocate threatened sacred sites' interpretive functions inland ($300M)
#    - Co-designed with indigenous communities
#    - Revenue: Cultural tourism premium pricing ($80M/year)
#
# 3. **Blue economy investment**: Deep-water aquaculture, ocean thermal energy ($800M)
#    - Probability of commercial viability by Year 15: 55%
#    - Downside risk: Loss of $600M if markets don't develop
#
# 4. **Digital services sector**: Tax incentives, fiber infrastructure ($200M)
#    - Leverage time zone, educated English-speaking population
#
# **Expected ROI:**
# - Base case (65% probability): $200M/year additional GDP by Year 15
# - Optimistic (20%): $400M/year
# - Pessimistic (15%): $50M/year (tourism collapse, tech doesn't scale)
#
# **Metrics:**
# - Tourism receipts per visitor (should increase even as volumes moderate)
# - New economy jobs created (target: 15,000 by Year 10)
# - **Decision gate at Year 8**: If new revenue <$80M/year, reallocate $500M from blue economy to Plan B (remittance economy, skilled labor export)
#
# ---
#
# ### 2B. Phased Managed Retreat ($2.5B)
#
# **Principle**: No forced relocation before Year 5; all moves voluntary until Year 10, then phased mandatory for highest-risk zones.
#
# **Implementation:**
#
# **Years 3-7 (Voluntary Phase):**
# - Purchase coastal properties at 125% pre-crisis market value + relocation stipend ($50k/household)
# - Priority: Areas with <15 years protection horizon
# - Develop 5 new inland settlements with full infrastructure
# - **Target**: Relocate 80,000 people (25% of affected population)
#
# **Predicted uptake**: 60% ± 15%
# - Justification: Buyout programs typically achieve 50-70% voluntary participation (evidence: US floodplain buyouts, Australian cyclone zones)
# - Lower participation likely in areas with indigenous sacred sites
#
# **Years 8-15 (Hybrid Phase):**
# - Mandatory building moratorium in highest-risk zones
# - Continued buyouts at 115% value
# - Rent-to-own programs in new settlements
# - **Target**: Additional 120,000 people relocated
#
# **Cost per person relocated**: ~$20,000 average (range: $8k-35k depending on property values)
#
# **Cultural site protection:**
# - Physical relocation of moveable artifacts/structures: $200M
# - Sacred site protocol: If site cannot be moved and area becomes uninhabitable:
#   - Maintain access via elevated pathways/boats as long as physically possible
#   - Ceremonial compensation process co-designed with Cultural Heritage Commission
#   - Establish inland memorial sites with blessing of traditional owners
#   - **Non-negotiable**: Indigenous communities decide which sites qualify for maximum protection effort (may exceed $50M per site)
#
# **Social cohesion metrics:**
# - Community satisfaction surveys (target: >60% approve of process)
# - Protest intensity (trigger for pause if sustained civil disobedience >5,000 people)
# - Indigenous community approval rating (minimum 50% support required)
# - **Major contingency**: If approval falls below thresholds, 12-month pause for plan revision
#
# **Probability assessment:**
# - Orderly retreat achieving 90%+ relocation by Year 15: 50%
# - Delayed/partial (70-85% relocated): 35%
# - Crisis scenario (major unrest, <65% relocated): 15%
#
# ---
#
# ### 2C. Fishing Sector Transformation ($500M)
#
# **Reality**: Traditional near-shore fisheries will be disrupted by:
# - Sea temperature changes (altering fish populations)
# - Coral bleaching (habitat loss)
# - Coastal infrastructure changes
#
# **Strategy:**
# 1. Upgrade to deeper-water capable vessels: $200M (subsidized loans)
# 2. Aquaculture training and startup grants: $150M
# 3. Fisheries monitoring/management tech: $50M
# 4. Safety net fund for transition: $100M (5-year income support)
#
# **Engagement**:
# - Co-design with fishing cooperatives
# - Guarantee: No fisher worse off than baseline for first 5 years
# - Job retraining if leaving sector
#
# **Metrics:**
# - Fishing income maintained >80% of baseline
# - Stock sustainability scores
# - **Trigger**: If >40% of fishers reject transition by Year 5, shift toward pure income support + alternative jobs
#
# ---
#
# ## Phase 3: Long-term Resilience (Years 15-30)
# **Budget: Remaining bonds + international aid + economic returns from Phase 2**
#
# ### 3A. Adaptive Infrastructure ($3B)
#
# **Speculative component**: Technology and climate trajectory will evolve significantly by Year 15. Strategy must remain flexible.
#
# **Pre-committed decisions:**
# - Retreat boundaries finalized by Year 10 (no further inland development restrictions)
# - Critical infrastructure hardened to Year 2070 projections + 30% safety margin
#
# **Adaptive decisions (await better data):**
# - Extent of nature-based solutions (mangrove restoration, coral gardening): Efficacy uncertain, $500M provisional
# - Floating/amphibious architecture: Unproven at scale, but preserve $800M option value
# - Regional migration agreements: Negotiate safety valve for worst-case population overflow
#
# ### 3B. Plan Update Protocol
#
# **Mandatory comprehensive reviews:**
# - Year 5: Adjust timeline based on observed sea-level rise rate
# - Year 10: Major economic strategy pivot if needed
# - Year 15, 20, 25: Full reassessment
#
# **Annual monitoring:**
# - Sea-level benchmarks (±5cm from projections triggers review)
# - Economic indicators (GDP, employment, inequality)
# - Social cohesion (survey data, election results, protest activity)
# - Cultural heritage preservation status
#
# **Trigger for fundamental strategy change:**
# - Sea-level rise >15cm ahead of central projection: Accelerate retreat, reduce defense spending
# - Economic collapse (GDP down >20%): Prioritize immediate welfare over long-term projects
# - Governance failure: International administration option
# - Major breakthrough (fusion energy, carbon removal): Consider holding more land
#
# ---
#
# ## Financial Structure
#
# **Initial 5-year budget ($7.5B total):**
# - Data & Planning: $200M (3%)
# - Governance: $50M (0.7%)
# - Critical infrastructure defense: $2B (27%)
# - Economic transition seed: $1B (13%)
# - Managed retreat start: $1.5B (20%)
# - Reserve fund: $750M (10%)
# - Ongoing government operations + social services: $2B (27%)
#
# **Risk management:**
# - Reserve fund for emergencies (natural disasters, economic shocks)
# - Bond issuance conditional on maintaining investment-grade rating
# - If aid fails to materialize: Reduce voluntary buyout prices to 100% market value, slower retreat timeline
# - Debt sustainability: Cap total borrowing at 70% GDP
#
# ---
#
# ## Evidence vs. Speculation
#
# **Evidence-based components:**
# - Engineering costs and success rates (extensive precedent)
# - Basic climate projections (IPCC consensus)
# - Governance failure modes (historical analysis)
# - Buyout program participation rates (empirical studies)
#
# **Speculative components:**
# - Exact timing of sea-level impacts (±5-10 year uncertainty)
# - New economic model success (blue economy unproven)
# - International aid amounts and consistency
# - Social cohesion maintenance through mass relocation (limited precedent at this scale)
# - Technology availability after Year 15
#
# **Most uncertain/highest impact:**
# The interaction between economic stress and social cohesion during Years 8-15. Historical precedent (post-disaster relocations, austerity programs) suggests 20-35% chance of political instability severe enough to derail managed retreat. This is the **critical vulnerability** requiring maximum monitoring and adaptive capacity.
#
# ---
#
# ## Ethical Framework for Impossible Choices
#
# **When economic, safety, and cultural priorities conflict irreconcilably:**
#
# 1. **Immediate safety > all**: If lives threatened, temporary overrides permitted (with compensation)
#
# 2. **Cultural survival**: Indigenous communities get veto over sacred sites + right to equivalent alternatives
#    - Exception: Cannot veto safety measures for others' lives
#    - Can accept financial compensation if community decides (their choice, not imposed)
#
# 3. **Economic efficiency secondary**: Will accept 10-15% cost premium to preserve social cohesion and cultural heritage
#
# 4. **Transparency paramount**: All decisions published with full reasoning, minority opinions recorded
#
# **Example hard case:**
# Major port generates 8% of GDP but expansion would destroy sacred burial ground. Indigenous community splits 60-40 against.
# - **Process**:
#   - Offer alternative port location (cost +$200M)
#   - If truly no alternative: Citizens' Assembly decides
#   - Winning margin must exceed 60% for irreversible action
#   - Losing community receives permanent trust fund ($100M) for cultural preservation
#   - Decision recorded as "tragic choice" acknowledging harm
#
# ---
#
# ## Summary: Theory of Success
#
# **This plan succeeds if:**
# 1. Aggressive early action buys time (Years 0-5)
# 2. Economic transition begins showing results by Year 8 (provides hope + funding)
# 3. Voluntary retreat achieves critical mass (reduces coercion needed later)
# 4. Governance maintains legitimacy through transparency and power-sharing
# 5. International community provides modest but sustained support
#
# **Success probability: 45-55%** (speculative estimate)
#
# **Most likely failure mode**: Economic transition underperforms → bond markets close → forced to choose between inadequate defense or coerced relocation without compensation → political instability → state failure
#
# **Mitigation**: Maintain reserve fund, preserve international migration options as safety valve, front-load most expensive infrastructure to early years when funds available.
#
# This is not a plan that "solves" the crisis—that's impossible with these constraints. It's a plan to **preserve community identity and democratic governance through managed decline**, avoiding the worst outcomes while acknowledging some painful losses are unavoidable.
#
# # Response from competitor 3
#
# ## 30-Year Adaptation Strategy for the Island Nation: Navigating the Tides of Change (Speculative elements marked with *)
#
# **Assumptions:**
#
# *   **Political Stability:** The government maintains sufficient stability to implement long-term strategies.
# *   **Competent Governance:** There is a baseline level of governmental capacity to execute complex projects.
# *   **Global Warming Trajectory:** The 40% loss of habitable land within 30 years is based on current climate models and trends, acknowledging potential for both faster and slower rates.
# *   **Tourism Demand:** While vulnerable, tourism will remain a viable, if transformed, economic sector for at least part of the 30-year horizon.
# *   **International Cooperation:** Acknowledgment that international aid, even if modest, is a critical component of the financial strategy.
# *   **Social Cohesion:** Despite polarization, a shared sense of urgency regarding national survival can be leveraged for unity.
# *   **Indigenous Resilience:** The indigenous population possesses strong cultural attachment and a willingness to participate in solutions, not just protest.
#
# **Key Uncertainties:**
#
# *   **Pace of Sea-Level Rise:** While 40% in 30 years is projected, the exact rate and regional variations are highly uncertain, impacting the timeline for managed retreat.
# *   **Effectiveness of Engineered Defenses:** The long-term efficacy and maintenance costs of various hard and soft defenses against accelerating sea-level rise are subject to uncertainty.
# *   **Global Market Appetite for Bonds:** Geopolitical events and global economic downturns could significantly impact the ability to raise $1 billion annually.
# *   **Level and Consistency of International Aid:** "Modest" is vague. The timing, conditions, and amount of aid are highly unpredictable.
# *   **Social Acceptance of Managed Retreat:** The willingness of affected populations to relocate, even with incentives, is a major unknown.
# *   **Economic Diversification Success:** The speed and scale at which new economic sectors can be developed and mature.
# *   **Technological Breakthroughs:** Unexpected advancements in climate engineering, sustainable energy, or resilient infrastructure could alter the cost-benefit analysis.
#
# ---
#
# ### Overarching Strategy & Guiding Principles:
#
# Our strategy adopts a **"Defend, Adapt, Diversify, and Unify"** approach, prioritizing rapid, decisive action while fostering long-term resilience. It acknowledges that a full "save-all-land" strategy is financially and physically impossible, necessitating difficult choices.
#
# **Guiding Principles:**
#
# 1.  **Safety First:** Prioritize the safety and well-being of all citizens.
# 2.  **Equity and Justice:** Ensure no community is left behind, paying particular attention to vulnerable populations and indigenous rights.
# 3.  **Cultural Preservation:** Protect and integrate indigenous knowledge and sacred sites into adaptation plans.
# 4.  **Economic Resilience:** Transition towards a diversified, knowledge-based economy less vulnerable to climate shocks.
# 5.  **Data-Driven Decisions:** Continuously monitor, adapt, and refine the plan based on new information.
# 6.  **Transparency and Participation:** Foster trust and shared ownership through open communication and broad stakeholder engagement.
#
# ---
#
# ### Phase 1: Immediate Action & Planning (Years 1-5)
#
# **Financial Allocation:**
#
# *   **Initial $5 Billion:** Allocated as follows:
#     *   **$1.5 Billion:** Immediate Engineered Defenses & Early Warning Systems (Critical Infrastructure Protection)
#     *   **$1 Billion:** Managed Retreat Pilot Programs & Resettlement Infrastructure Acquisition
#     *   **$1 Billion:** Economic Diversification Seed Fund & Workforce Training
#     *   **$1 Billion:** Social Cohesion & Cultural Preservation Programs (including indigenous land mapping)
#     *   **$0.5 Billion:** Research, Monitoring, & Governance (Data collection, modeling, institutional strengthening)
# *   **Annual $1 Billion Bonds & Modest International Aid (if received):** Primarily for scaling up Phase 1 initiatives and preparing for Phase 2.
#
# **A. ENGINEERED DEFENSES: Targeted Protection of Critical Assets**
#
# ...
# | **E / S** | E (performance standards based on Dutch and Caribbean best‑practice). |
#
# ---
#
# ### 4.6 Decision 6 – Voluntary Managed‑Retreat Pilot (2 km², ≈ 8 000 people)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $310 M (land purchase, new housing, infrastructure, compensation). |
# | **Benefit** | Demonstrates feasible “exit‑option” for 0.7 % of total population; avoids future $1.2 bn damages on the relocated area (if SLR continues). |
# | **Success Probability** | **Success** 0.65 – depends on achieving **FPIC** and delivering compensation > 115 % of market value.<br>**Failure** 0.35 – could stall due to community dissent or cost overruns. |
# | **Metrics** | • % of affected households signing FPIC (target ≥ 80 %).<br>• Post‑relocation satisfaction index (≥ 70 %). |
# | **Stakeholder Process** | • Dedicated “Retreat Mediation Panel” (legal experts, Indigenous leaders, civil‑society NGOs).<br>• Independent third‑party audit of compensation packages. |
# | **Data Needed** | • Precise elevation maps of pilot area (sub‑meter).<br>• Social‑impact baseline survey (household income, education). |
# | **Adaptive Loop** | If FPIC threshold not met after 18 mo, pause and redesign incentive package (e.g., add community‑owned renewable‑energy micro‑grid). |
# | **E / S** | S (social acceptance estimated from small‑scale studies; financial assumptions contingent on market data). |
#
# ---
#
# ### 4.7 Decision 7 – Full‑Scale Managed‑Retreat Program (≈ 150 000 people)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $2.8 bn (land acquisition, new districts, infrastructure, compensation). |
# | **Benefit** | Avoids an estimated $5.9 bn in future flood & adaptation losses (life‑safety value + economic). |
# | **Success Probability** | **Success** 0.55 – high uncertainty in scaling social consent and financing.<br>**Failure** 0.45 – could result in “partial” retreat, leaving high‑risk pockets. |
# | **Metrics** | • Annual relocation rate (target ≥ 12 000 people/yr after Year 6).<br>• Compliance with **FPIC** for each community (≥ 85 %). |
# | **Stakeholder Process** | • National “Retreat‑Negotiation Forum” (government, Indigenous councils, private developers).<br>• Transparent “benefit‑sharing fund” financed by a tourism levy (2 % of ticket sales). |
# | **Data Needed** | • Updated SLR maps for 2035, 2050, 2070 (to delineate “no‑go” zones).<br>• Comprehensive household asset registers. |
# | **Adaptive Loop** | Review every 3 y; if relocation rate < 50 % of target, shift funds to “in‑situ adaptation” (e.g., elevated houses) for those areas. |
# | **E / S** | S (financial and social scaling risk). |
#
# ---
#
# ### 4.8 Decision 8 – Economic Transition Fund (ETF)
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $420 M (re‑skilling, seed‑capital for green‑tourism, renewable‑energy pilot projects). |
# | **Benefit** | Diversifies GDP: + 3 % annual growth in non‑tourism sectors; creates 12 000 new jobs (reducing tourism‑sector vulnerability). |
# | **Success Probability** | 0.72 – based on similar “just‑transition” programmes in Small Island Developing States (SIDS). |
# | **Metrics** | • Number of participants completing certified training (target ≥ 10 000).<br>• Share of GDP from renewable‑energy/eco‑tourism (target ≥ 15 % by Year 20). |
# | **Stakeholder Process** | • Co‑design with labor unions, Indigenous women’s groups, private sector (tourism operators).<br>• Independent advisory board to avoid capture. |
# | **Data Needed** | • Labor‑market skill gaps analysis.<br>• Market feasibility study for renewable‑energy export (e.g., solar‑to‑hydrogen). |
# | **Adaptive Loop** | Quarterly monitoring; re‑allocate up to 15 % of unused ETF budget toward “digital‑nomad” incentives if job creation lags. |
# | **E / S** | E (economic modeling from World Bank’s “SIDS transition” reports). |
#
# ---
#
# ### 4.9 Decision 9 – Protection & Legal Safeguarding of Sacred Coastal Sites
#
# | Item | Detail |
# |------|--------|
# | **Cost** | $95 M (land purchase/easement, archaeological documentation, offshore buffer zones). |
# | **Benefit** | Guarantees cultural continuity; avoids irreversible loss valued at $2 bn in intangible cultural heritage (UNESCO valuation method). |
# | **Success Probability** | 0.88 – if early FPIC and legal registration are done; risk of political reversal (12 %). |
# | **Metrics** | • Number of sites under legal protection (target = 100 % of identified sites).<br>• Annual patrols preventing illegal encroachment (≥ 95 % compliance). |
# | **Stakeholder Process** | • Indigenous Cultural Heritage Committee (ICHC) leads site identification.<br>• Government‑run “Cultural Impact Fund” pays for community‑led stewardship. |
# | **Data Needed** | • High‑resolution GIS of all cultural sites (including oral‑history locations). |
# | **Adaptive Loop** | If any protected site is damaged (detected by satellite or community report), trigger emergency response fund ($5 M) and revise buffer zones. |
# | **E / S** | E (costs based on land‑acquisition prices; benefit valuation from UNESCO). |
#
# ---
#
# ## 5.  Financing Schedule & Contingency Logic
#
# | Year | Core Expenditure | Funding Source | Contingency Trigger |
# |------|----------------|----------------|--------------------|
# | **0‑5** | Mapping, Pilot mangroves, CAC/CRT set‑up, initial data collection | $5 bn cash (≈ 70 % of initial fund) | If **U2** (bond markets) deteriorates > 2 % yield, postpone Phase 2 until market improves. |
# | **5‑10** | CPZ seawalls, flood‑gate upgrades, voluntary retreat pilot | $1 bn/year bonds (expected) + $0.3 bn aid (if secured) | If **U1** shows SLR > 0.8 m by 2035, accelerate seawall heightening (add $150 M). |
# | **10‑15** | Managed‑retreat pilot scaling, nature‑based expansion, ETF launch | Same as above; start “climate‑bond” issuance (green‑label) | If **U3** (aid) does not materialise, raise climate‑bond volume by 30 % and re‑allocate a portion to retreat. |
# | **15‑20** | Full‑scale retreat, large‑scale cultural‑site protection | Bonds + revenue from tourism levy (2 % of tickets) + aid (if any) | If relocation rate < 50 % of target, shift 15 % of retreat budget to “elevated housing” in place (short‑term safety). |
# | **20‑30** | Maintenance of CPZs, final retreat corridors, long‑term monitoring | Bonds (re‑financed at lower rates), modest aid, small “maintenance levy” (0.3 % of tourism receipts) | If **U4** (tourism demand) drops > 30 %, re‑prioritise funds toward renewable‑energy export projects to offset revenue loss. |
#
# *All “contingency triggers” are defined as **hard thresholds** (e.g., SLR > 0.8 m) that automatically launch a pre‑approved “contingency fund” (5 % of the total budget, i.e., $250 M) to cover redesign or acceleration.*
#
# ---
#
# ## 6.  Stakeholder‑Engagement Framework (how conflicts are adjudicated)
#
# 1. **Institutional Layer – Climate‑Adaptation Council (CAC)**
#    *Mandate:* Review all major adaptation projects, ensure FPIC, balance cost‑benefit across sectors.
#    *Decision rule:* Qualified majority (≥ 66 %) of members; if no consensus, an independent **Arbitration Panel** (3 external experts) makes the final call.
#
# 2. **Community‑Level Layer – Village‑Level Advisory Boards (VLABs)**
#    *Composition:* elected local leaders, Indigenous elders, women’s representatives, youth delegate.
#    *Function:* Provide ground‑truth data, voice concerns early, co‑design local mitigation (e.g., mangrove planting).
#
# 3. **Economic‑Sector Layer – Tourism‑Industry Forum (TIF)**
#    *Participants:* hotel chains, local tour operators, Ministry of Tourism, NGOs.
#    *Role:* Develop “tourism‑resilience levy”, propose alternative “eco‑tourism” packages, monitor revenue metrics.
#
# 4. **Cultural‑Heritage Layer – Indigenous Cultural Heritage Committee (ICHC)**
#    *Authority:* Must approve any project that impacts sacred sites (FPIC).
#    *Conflict resolution:* If a development proposal threatens a site, the CAC can approve a **Mitigation‑Exchange** (e.g., funding for a cultural center elsewhere) **only** if ICHC signs a written waiver after a formal impact‑assessment.
#
# 5. **Legal Oversight – Environmental & Heritage Courts**
#    *Fast‑track* (≤ 90 days) jurisdiction over disputes involving safety vs. cultural values, with the possibility of injunctions.
#
# **Adjudication Example:**
# - *Scenario:* A proposed seawall would require seabed dredging that encroaches on a sacred fishing ground.
# - *Process:* VLAB raises objection → CAC commissions a joint **Socio‑Environmental Impact Assessment** → ICHC evaluates cultural loss → If mitigation (e.g., co‑managed marine protected area) is acceptable, CAC approves with conditional monitoring; otherwise, the project is re‑designed or moved.
#
# ---
#
# ## 7.  Data Gaps – What We Must Acquire Before “Irreversible” Actions
#
# | Data Gap | Why Critical | How to Obtain | Timing |
# |----------|--------------|---------------|--------|
# | **High‑resolution (≤ 0.5 m) DEM of entire coastline** | Determines which areas need hard defenses vs. retreat. | Air‑borne LiDAR + satellite interferometry (contract with regional university). | Year 1 (complete before seawall design). |
# | **Updated SLR & storm‑surge probability distributions** (including climate‑model ensembles) | Sets design water levels for defenses. | Collaboration with IPCC‑affiliated climate labs; local tide‑gauge network upgrade. | Year 2 (baseline for Phase 2). |
# | **Comprehensive Indigenous cultural‑site GIS** (including oral‑history coordinates) | Ensures FPIC and legal protection. | Community‑led participatory mapping workshops, digitised archives. | Year 1‑2 (before any coastal construction). |
# | **Socio‑economic baseline of households in high‑risk zones** (assets, income, health) | Basis for fair compensation in retreat. | Household surveys, tax‑record linkage, mobile‑phone data analytics. | Year 2‑3 (before the voluntary retreat pilot). |
# | **Cost‑effectiveness of nature‑based solutions vs. hard walls under future climate scenarios** | Avoids over‑investment in possibly premature hard infrastructure. | Pilot monitoring + Monte‑Carlo benefit‑cost modelling (partner with UNDP). | Year 3 (inform Phase 2 decision). |
# | **Tourism demand elasticity to climate‑risk perception** | Determines ROI of protecting tourism assets. | Visitor‐survey data, econometric analysis of past events (e.g., 2020 cyclone). | Year 4 (inform CPZ sizing). |
# | **Debt‑servicing capacity under different bond‑yield scenarios** | Guarantees fiscal sustainability. | IMF/World Bank debt‑sustainability analysis, multi‑scenario modelling. | Year 5 (pre‑bond issuance). |
#
# *Only after these data sets reach a **minimum‑confidence threshold** (e.g., 95 % CI for SLR) will the government move to “commit‑ment” phases (e.g., full‑scale seawall construction, mass relocation).*
#
# ---
#
# ## 8.  Updating the Plan – Adaptive‑Management Cycle
#
# 1. **Annual Review (Year 1‑30)** – CAC publishes a **State‑of‑Adaptation Report** (SAR) covering all metrics.
#    *If any metric deviates > 20 % from target* → trigger a **Decision‑Adjustment Workshop**.
#
# 2. **Three‑Year “Strategic Check‑point”** – Re‑run cost‑benefit models with the latest data (SLR, economic, social).
#    *If projected net‑present‑value (NPV) of a major component falls below 0* → re‑prioritise (e.g., shift from seawall to mangrove expansion).
#
# 3. **Mid‑Term “Retreat Feasibility Survey” (Year 12 & 22)** – Re‑assess community willingness, demographic shifts, and land‑availability.
#
# 4. **External Audits (Every 5 y)** – Independent auditors evaluate financial integrity, governance compliance, and social‑impact outcomes. Recommendations become binding if **≥ 70 %** of CAC votes for them.
#
# 5. **Learning Loop** – All lessons feed into the **National Climate‑Adaptation Knowledge Base** (open‑source platform) to inform future SIDS worldwide.
#
# ---
#
# ## 9.  Summary of Prioritization (Why this ordering makes sense)
#
# | Rank | Action | Rationale (risk‑reduction + value creation) |
# |------|--------|----------------------------------------------|
# | **1** | Mapping & Institutional set‑up (Dec 1‑3) | *Low cost, high information return; creates decision‑making backbone.* |
# | **2** | Pilot nature‑based solutions (Dec 2) | *No‑regret, improves ecosystem services while buying time.* |
# | **3** | Flood‑gate upgrades (Dec 5) | *High‑impact, protects large residential zones; relatively cheap.* |
# | **4** | Hybrid seawalls in core tourism (Dec 4) | *Protects the economic engine; justified only after we know exactly where sea‑level will hit.* |
# | **5** | Voluntary retreat pilot (Dec 6) | *Proof‑of‑concept for larger retreat; respects FPIC.* |
# | **6** | Managed‑retreat scale‑up (Dec 7) | *Only after pilot demonstrates feasibility & financing path.* |
# | **7** | Economic transition fund (Dec 8) | *Diversifies income, reduces future exposure; can run in parallel with retreat.* |
# | **8** | Cultural‑site protection (Dec 9) | *Legal requirement; relatively low cost; must be locked‑in early to avoid irreversible loss.* |
# | **9** | Maintenance & post‑30 y “exit” decisions (Dec 10) | *Ensures long‑term sustainability; informed by all prior monitoring.* |
#
# ---
#
# ## 10.  What Is Speculative vs. Evidence‑Based?
#
# | Area | Evidence‑Based (E) | Speculative (S) |
# |------|-------------------|-----------------|
# | Sea‑level projections (U1) | IPCC AR6 ensembles (E) | Local amplification due to subsidence (S) |
# | Cost of seawall (Dec 4) | Similar projects in Maldives, Seychelles (E) | Exact design height needed for 2080 scenario (S) |
# | Success rate of mangrove restoration (Dec 2) | Meta‑analysis of tropical mangrove projects (E) | Survival in the nation’s specific salinity regime (S) |
# | Public willingness for managed retreat (Dec 6‑7) | Survey data from other SIDS (E) | Local cultural attachment levels (S) |
# | Tourism elasticity to climate risk (U4) | Global tourism‑risk literature (E) | Nation‑specific branding effect (S) |
# | Debt‑service capacity under bond‑yield swing (U2) | IMF debt‑sustainability models (E) | Future global interest‑rate trajectories (S) |
# | Effectiveness of “green levy” for funding ETF (Dec 8) | Examples from Costa Rica, Belize (E) | Exact revenue generation for this nation (S) |
# | Cultural‑heritage valuation (Dec 9) | UNESCO guidelines (E) | Community’s internal valuation metrics (S) |
#
# The **core of the plan** (mapping, institutional setup, pilot green actions, flood‑gate upgrades) rests on **high‑confidence evidence**. The **large‑scale retreat and economic transition** are **moderately speculative**, requiring continuous monitoring and the ability to pivot.
#
# ---
#
# ## 11.  Final Recommendation to the Government
#
# 1. **Allocate the immediate $5 bn** as follows (see Phase 0‑5 table).
# 2. **Issue the first $1 bn bond tranche** within 12 months, earmarking 70 % for CPZs & flood‑gate upgrades; keep 30 % as a “contingency reserve”.
# 3. **Secure the 60 % aid probability** by submitting a joint “Island Climate Resilience” proposal to the Green Climate Fund (GCF) and the World Bank’s Small Island Adaptation Program (SIAP) **by the end of Year 2**.
# 4. **Activate the Climate‑Adaptation Council** immediately; its first mandate is to approve the detailed design criteria for seawalls **once the SLR model reaches > 0.6 m by 2035** (U1 trigger).
# 5. **Begin the voluntary retreat pilot** only after the **FPIC** process for the target village is completed (expected by Year 4).
#
# By following the **adaptive‑management cycle** (annual SAR, 3‑year strategic checkpoints, and mid‑term retreat feasibility surveys), the nation can **stay within its fiscal envelope**, **protect its most vulnerable communities and cultural heritage**, and **maintain the economic lifeline of tourism** while **building a more diversified, resilient future**.
#
# ---
#
# *Prepared for the Government of the Island Nation – 30‑Year Climate‑Adaptation Strategy (2026‑2056).*
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI(base_url=OPENROUTER_BASE_URL, api_key=openrouter_api_key)
response = openai.chat.completions.create(
    model="openai/gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["5", "1", "2", "3", "4"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: openai/gpt-oss-120b
# Rank 2: openai/gpt-5-nano
# Rank 3: anthropic/claude-sonnet-4.5
# Rank 4: google/gemini-2.5-flash
# Rank 5: deepseek/deepseek-chat

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
